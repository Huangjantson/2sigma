# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
import re
import string

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    

    return street
    
#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column,minimum_size=5):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    return df1, df2

def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

#encoded by sorted value
def hcc_sorting(train_df,test_df,feature,label=None,randomize=None):
    """
    sort the hcc feature by their prior on label then encode
    the train df should be with its labels get dummied
    
    return the list of all the possible features in order
    """
    if label ==None:
        train_df['tempScore'] = 2*train_df['high']+train_df['medium']
    
    label = 'tempScore'
    #get dummies for the 
    grouped  = train_df.groupby(feature)[label].agg({'size':'size','mean':'mean'})
    #unrankedMean = grouped.ix[grouped['size']<unrank_threshold,'mean'].mean()
    #grouped.ix[grouped['size']<unrank_threshold,'mean'] = unrankedMean
    grouped = grouped.reset_index()

    #get the values for the test set
    test_groupBy=test_df[feature].value_counts().to_frame().reset_index()
    test_groupBy.columns = [feature,'testSize']

    #merge together and reset the mean
    totalFeature = grouped.merge(test_groupBy,on = feature, how='outer').fillna(0)

    rankedMean = np.mean(grouped['mean'])

    #reset those train size 0 to the ranked mean
    totalFeature.ix[totalFeature['size']==0,'mean']=rankedMean
    
    #add some random 
    if randomize : 
        totalFeature['mean'] *= np.random.uniform(1 - randomize, 1 + randomize, len(totalFeature))

    return list(totalFeature.sort('mean')[feature])

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

# %%
#dealing feature with categorical features 
"""
display_address 8826    
building_id        7585   =》many zeros in this feature
manager_id   3481
street_address 15358 =》will be 3800 if no numbers in it 
"""
train_df =train_df.join(pd.get_dummies(train_df[u'interest_level']).astype(int))

categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
for f in categorical:
    #fill substitute the small size values by their mean
    train_df,test_df  = singleValueConvert(train_df,test_df,f)
    if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(hcc_sorting(train_df,test_df,f,randomize = 0.05))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)
# Out:
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:35: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
#running and getting the cv from xgboost
cv_scores = []
#K-FOLD already defined.If not ,use
#KF=KFold(len(train_X),5,shuffle=True,random_state = 42)
features_to_use.append('manager_skill')

for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #apply the function for createing some featues
        dev_set, val_set =manager_skill_eval(dev_set,val_set)
        #features_to_use.extend(['ManHigh','ManLow', 'ManMedium','manager_skill'])
        
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# [0]	train-mlogloss:1.03273	test-mlogloss:1.0357
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.979968	test-mlogloss:0.984391
# [2]	train-mlogloss:0.930786	test-mlogloss:0.937526
# [3]	train-mlogloss:0.890052	test-mlogloss:0.898769
# [4]	train-mlogloss:0.856223	test-mlogloss:0.866336
# [5]	train-mlogloss:0.8254	test-mlogloss:0.837309
# [6]	train-mlogloss:0.797004	test-mlogloss:0.810489
# [7]	train-mlogloss:0.772129	test-mlogloss:0.787366
# [8]	train-mlogloss:0.749256	test-mlogloss:0.766133
# [9]	train-mlogloss:0.730434	test-mlogloss:0.748586
# [10]	train-mlogloss:0.712667	test-mlogloss:0.73226
# [11]	train-mlogloss:0.696732	test-mlogloss:0.717829
# [12]	train-mlogloss:0.6829	test-mlogloss:0.705298
# [13]	train-mlogloss:0.669572	test-mlogloss:0.693593
# [14]	train-mlogloss:0.658108	test-mlogloss:0.683345
# [15]	train-mlogloss:0.647764	test-mlogloss:0.674056
# [16]	train-mlogloss:0.638843	test-mlogloss:0.66572
# [17]	train-mlogloss:0.630446	test-mlogloss:0.658391
# [18]	train-mlogloss:0.622541	test-mlogloss:0.651482
# [19]	train-mlogloss:0.616019	test-mlogloss:0.645562
# [20]	train-mlogloss:0.609558	test-mlogloss:0.640066
# [21]	train-mlogloss:0.603641	test-mlogloss:0.634884
# [22]	train-mlogloss:0.598374	test-mlogloss:0.630318
# [23]	train-mlogloss:0.593325	test-mlogloss:0.62598
# [24]	train-mlogloss:0.588288	test-mlogloss:0.622138
# [25]	train-mlogloss:0.583439	test-mlogloss:0.618379
# [26]	train-mlogloss:0.579381	test-mlogloss:0.615046
# [27]	train-mlogloss:0.575578	test-mlogloss:0.612407
# [28]	train-mlogloss:0.572139	test-mlogloss:0.609838
# [29]	train-mlogloss:0.568827	test-mlogloss:0.607347
# [30]	train-mlogloss:0.565771	test-mlogloss:0.605047
# [31]	train-mlogloss:0.562692	test-mlogloss:0.60284
# [32]	train-mlogloss:0.559821	test-mlogloss:0.60085
# [33]	train-mlogloss:0.557166	test-mlogloss:0.598918
# [34]	train-mlogloss:0.554393	test-mlogloss:0.597173
# [35]	train-mlogloss:0.551841	test-mlogloss:0.595534
# [36]	train-mlogloss:0.549703	test-mlogloss:0.594089
# [37]	train-mlogloss:0.547365	test-mlogloss:0.592575
# [38]	train-mlogloss:0.545425	test-mlogloss:0.591188
# [39]	train-mlogloss:0.543304	test-mlogloss:0.589855
# [40]	train-mlogloss:0.54134	test-mlogloss:0.588651
# [41]	train-mlogloss:0.539394	test-mlogloss:0.587551
# [42]	train-mlogloss:0.537575	test-mlogloss:0.586592
# [43]	train-mlogloss:0.535831	test-mlogloss:0.585463
# [44]	train-mlogloss:0.534267	test-mlogloss:0.584383
# [45]	train-mlogloss:0.532939	test-mlogloss:0.583868
# [46]	train-mlogloss:0.531299	test-mlogloss:0.582878
# [47]	train-mlogloss:0.529833	test-mlogloss:0.582154
# [48]	train-mlogloss:0.528664	test-mlogloss:0.581568
# [49]	train-mlogloss:0.527303	test-mlogloss:0.580786
# [50]	train-mlogloss:0.526156	test-mlogloss:0.580317
# [51]	train-mlogloss:0.524811	test-mlogloss:0.579656
# [52]	train-mlogloss:0.523096	test-mlogloss:0.578632
# [53]	train-mlogloss:0.522064	test-mlogloss:0.578155
# [54]	train-mlogloss:0.520945	test-mlogloss:0.577599
# [55]	train-mlogloss:0.519364	test-mlogloss:0.576733
# [56]	train-mlogloss:0.518204	test-mlogloss:0.576105
# [57]	train-mlogloss:0.516826	test-mlogloss:0.575479
# [58]	train-mlogloss:0.515943	test-mlogloss:0.575141
# [59]	train-mlogloss:0.514693	test-mlogloss:0.574586
# [60]	train-mlogloss:0.513335	test-mlogloss:0.573996
# [61]	train-mlogloss:0.512353	test-mlogloss:0.573498
# [62]	train-mlogloss:0.511049	test-mlogloss:0.572979
# [63]	train-mlogloss:0.510015	test-mlogloss:0.572487
# [64]	train-mlogloss:0.508392	test-mlogloss:0.571758
# [65]	train-mlogloss:0.507203	test-mlogloss:0.571326
# [66]	train-mlogloss:0.505935	test-mlogloss:0.570895
# [67]	train-mlogloss:0.504836	test-mlogloss:0.570372
# [68]	train-mlogloss:0.503629	test-mlogloss:0.569944
# [69]	train-mlogloss:0.502372	test-mlogloss:0.569506
# [70]	train-mlogloss:0.501261	test-mlogloss:0.569133
# [71]	train-mlogloss:0.500063	test-mlogloss:0.568718
# [72]	train-mlogloss:0.499003	test-mlogloss:0.568408
# [73]	train-mlogloss:0.497987	test-mlogloss:0.568011
# [74]	train-mlogloss:0.496835	test-mlogloss:0.567772
# [75]	train-mlogloss:0.496163	test-mlogloss:0.567578
# [76]	train-mlogloss:0.495045	test-mlogloss:0.567384
# [77]	train-mlogloss:0.493888	test-mlogloss:0.567092
# [78]	train-mlogloss:0.493111	test-mlogloss:0.566821
# [79]	train-mlogloss:0.492555	test-mlogloss:0.566759
# [80]	train-mlogloss:0.491545	test-mlogloss:0.566502
# [81]	train-mlogloss:0.490552	test-mlogloss:0.566114
# [82]	train-mlogloss:0.489713	test-mlogloss:0.566081
# [83]	train-mlogloss:0.488495	test-mlogloss:0.565568
# [84]	train-mlogloss:0.487654	test-mlogloss:0.565339
# [85]	train-mlogloss:0.486423	test-mlogloss:0.564946
# [86]	train-mlogloss:0.485441	test-mlogloss:0.56459
# [87]	train-mlogloss:0.48461	test-mlogloss:0.564293
# [88]	train-mlogloss:0.483794	test-mlogloss:0.564022
# [89]	train-mlogloss:0.483086	test-mlogloss:0.563705
# [90]	train-mlogloss:0.482259	test-mlogloss:0.563626
# [91]	train-mlogloss:0.481181	test-mlogloss:0.563326
# [92]	train-mlogloss:0.480058	test-mlogloss:0.563048
# [93]	train-mlogloss:0.479093	test-mlogloss:0.562822
# [94]	train-mlogloss:0.477862	test-mlogloss:0.562365
# [95]	train-mlogloss:0.476833	test-mlogloss:0.562119
# [96]	train-mlogloss:0.476052	test-mlogloss:0.561956
# [97]	train-mlogloss:0.475034	test-mlogloss:0.561686
# [98]	train-mlogloss:0.474168	test-mlogloss:0.561446
# [99]	train-mlogloss:0.473347	test-mlogloss:0.561443
# [100]	train-mlogloss:0.472246	test-mlogloss:0.561112
# [101]	train-mlogloss:0.471439	test-mlogloss:0.561006
# [102]	train-mlogloss:0.470483	test-mlogloss:0.560501
# [103]	train-mlogloss:0.469683	test-mlogloss:0.560145
# [104]	train-mlogloss:0.468963	test-mlogloss:0.560085
# [105]	train-mlogloss:0.468212	test-mlogloss:0.559979
# [106]	train-mlogloss:0.467504	test-mlogloss:0.559808
# [107]	train-mlogloss:0.466965	test-mlogloss:0.559814
# [108]	train-mlogloss:0.466369	test-mlogloss:0.559717
# [109]	train-mlogloss:0.465394	test-mlogloss:0.559398
# [110]	train-mlogloss:0.464548	test-mlogloss:0.559208
# [111]	train-mlogloss:0.464093	test-mlogloss:0.55902
# [112]	train-mlogloss:0.463333	test-mlogloss:0.558956
# [113]	train-mlogloss:0.462495	test-mlogloss:0.558642
# [114]	train-mlogloss:0.461858	test-mlogloss:0.558605
# [115]	train-mlogloss:0.460949	test-mlogloss:0.558378
# [116]	train-mlogloss:0.46002	test-mlogloss:0.558194
# [117]	train-mlogloss:0.459157	test-mlogloss:0.557911
# [118]	train-mlogloss:0.458397	test-mlogloss:0.557746
# [119]	train-mlogloss:0.457534	test-mlogloss:0.557512
# [120]	train-mlogloss:0.457016	test-mlogloss:0.557336
# [121]	train-mlogloss:0.456573	test-mlogloss:0.557258
# [122]	train-mlogloss:0.45595	test-mlogloss:0.557114
# [123]	train-mlogloss:0.455384	test-mlogloss:0.557113
# [124]	train-mlogloss:0.454385	test-mlogloss:0.557
# [125]	train-mlogloss:0.453682	test-mlogloss:0.556906
# [126]	train-mlogloss:0.453048	test-mlogloss:0.556835
# [127]	train-mlogloss:0.452148	test-mlogloss:0.556617
# [128]	train-mlogloss:0.451807	test-mlogloss:0.556548
# [129]	train-mlogloss:0.451283	test-mlogloss:0.556367
# [130]	train-mlogloss:0.450413	test-mlogloss:0.556303
# [131]	train-mlogloss:0.449712	test-mlogloss:0.556133
# [132]	train-mlogloss:0.449015	test-mlogloss:0.555953
# [133]	train-mlogloss:0.448165	test-mlogloss:0.555884
# [134]	train-mlogloss:0.44746	test-mlogloss:0.555681
# [135]	train-mlogloss:0.446952	test-mlogloss:0.555513
# [136]	train-mlogloss:0.446393	test-mlogloss:0.555432
# [137]	train-mlogloss:0.445609	test-mlogloss:0.555268
# [138]	train-mlogloss:0.44511	test-mlogloss:0.555284
# [139]	train-mlogloss:0.444469	test-mlogloss:0.555294
# [140]	train-mlogloss:0.443663	test-mlogloss:0.555225
# [141]	train-mlogloss:0.442965	test-mlogloss:0.555115
# [142]	train-mlogloss:0.442319	test-mlogloss:0.555044
# [143]	train-mlogloss:0.441825	test-mlogloss:0.554985
# [144]	train-mlogloss:0.441098	test-mlogloss:0.554984
# [145]	train-mlogloss:0.440341	test-mlogloss:0.554858
# [146]	train-mlogloss:0.439951	test-mlogloss:0.554805
# [147]	train-mlogloss:0.439353	test-mlogloss:0.55472
# [148]	train-mlogloss:0.43878	test-mlogloss:0.554666
# [149]	train-mlogloss:0.438102	test-mlogloss:0.554459
# [150]	train-mlogloss:0.437673	test-mlogloss:0.554425
# [151]	train-mlogloss:0.437304	test-mlogloss:0.554352
# [152]	train-mlogloss:0.436659	test-mlogloss:0.554227
# [153]	train-mlogloss:0.435977	test-mlogloss:0.554158
# [154]	train-mlogloss:0.435364	test-mlogloss:0.554229
# [155]	train-mlogloss:0.434635	test-mlogloss:0.554103
# [156]	train-mlogloss:0.434117	test-mlogloss:0.553971
# [157]	train-mlogloss:0.433651	test-mlogloss:0.553997
# [158]	train-mlogloss:0.432924	test-mlogloss:0.554033
# [159]	train-mlogloss:0.432309	test-mlogloss:0.553927
# [160]	train-mlogloss:0.431678	test-mlogloss:0.553845
# [161]	train-mlogloss:0.431119	test-mlogloss:0.553613
# [162]	train-mlogloss:0.430574	test-mlogloss:0.553498
# [163]	train-mlogloss:0.430039	test-mlogloss:0.553382
# [164]	train-mlogloss:0.429342	test-mlogloss:0.55332
# [165]	train-mlogloss:0.428539	test-mlogloss:0.553174
# [166]	train-mlogloss:0.427783	test-mlogloss:0.553234
# [167]	train-mlogloss:0.42714	test-mlogloss:0.553149
# [168]	train-mlogloss:0.426363	test-mlogloss:0.553019
# [169]	train-mlogloss:0.425729	test-mlogloss:0.553042
# [170]	train-mlogloss:0.425338	test-mlogloss:0.552983
# [171]	train-mlogloss:0.424896	test-mlogloss:0.552853
# [172]	train-mlogloss:0.424267	test-mlogloss:0.552895
# [173]	train-mlogloss:0.423753	test-mlogloss:0.552803
# [174]	train-mlogloss:0.423095	test-mlogloss:0.55272
# [175]	train-mlogloss:0.422746	test-mlogloss:0.552761
# [176]	train-mlogloss:0.422253	test-mlogloss:0.552685
# [177]	train-mlogloss:0.421783	test-mlogloss:0.552692
# [178]	train-mlogloss:0.421101	test-mlogloss:0.552638
# [179]	train-mlogloss:0.420435	test-mlogloss:0.552653
# [180]	train-mlogloss:0.419769	test-mlogloss:0.552612
# [181]	train-mlogloss:0.418978	test-mlogloss:0.552554
# [182]	train-mlogloss:0.418407	test-mlogloss:0.552538
# [183]	train-mlogloss:0.417744	test-mlogloss:0.552402
# [184]	train-mlogloss:0.417039	test-mlogloss:0.552356
# [185]	train-mlogloss:0.416274	test-mlogloss:0.552462
# [186]	train-mlogloss:0.415704	test-mlogloss:0.55239
# [187]	train-mlogloss:0.415283	test-mlogloss:0.552414
# [188]	train-mlogloss:0.414781	test-mlogloss:0.552431
# [189]	train-mlogloss:0.414217	test-mlogloss:0.552417
# [190]	train-mlogloss:0.413518	test-mlogloss:0.552422
# [191]	train-mlogloss:0.412996	test-mlogloss:0.552455
# [192]	train-mlogloss:0.412563	test-mlogloss:0.552429
# [193]	train-mlogloss:0.412088	test-mlogloss:0.552416
# [194]	train-mlogloss:0.41158	test-mlogloss:0.55225
# [195]	train-mlogloss:0.41096	test-mlogloss:0.552236
# [196]	train-mlogloss:0.410406	test-mlogloss:0.552065
# [197]	train-mlogloss:0.409613	test-mlogloss:0.551977
# [198]	train-mlogloss:0.40909	test-mlogloss:0.551871
# [199]	train-mlogloss:0.408488	test-mlogloss:0.551923
# [200]	train-mlogloss:0.407853	test-mlogloss:0.551825
# [201]	train-mlogloss:0.407314	test-mlogloss:0.551713
# [202]	train-mlogloss:0.406739	test-mlogloss:0.551743
# [203]	train-mlogloss:0.406252	test-mlogloss:0.551741
# [204]	train-mlogloss:0.405729	test-mlogloss:0.551812
# [205]	train-mlogloss:0.405127	test-mlogloss:0.55171
# [206]	train-mlogloss:0.404436	test-mlogloss:0.551818
# [207]	train-mlogloss:0.403883	test-mlogloss:0.551718
# [208]	train-mlogloss:0.403184	test-mlogloss:0.551646
# [209]	train-mlogloss:0.402545	test-mlogloss:0.551632
# [210]	train-mlogloss:0.402056	test-mlogloss:0.551593
# [211]	train-mlogloss:0.401395	test-mlogloss:0.551507
# [212]	train-mlogloss:0.400757	test-mlogloss:0.551394
# [213]	train-mlogloss:0.40022	test-mlogloss:0.551453
# [214]	train-mlogloss:0.399712	test-mlogloss:0.551415
# [215]	train-mlogloss:0.399077	test-mlogloss:0.551348
# [216]	train-mlogloss:0.398655	test-mlogloss:0.551432
# [217]	train-mlogloss:0.3982	test-mlogloss:0.551413
# [218]	train-mlogloss:0.397872	test-mlogloss:0.551409
# [219]	train-mlogloss:0.397335	test-mlogloss:0.551457
# [220]	train-mlogloss:0.396988	test-mlogloss:0.551402
# [221]	train-mlogloss:0.396442	test-mlogloss:0.551243
# [222]	train-mlogloss:0.395806	test-mlogloss:0.5511
# [223]	train-mlogloss:0.395224	test-mlogloss:0.551135
# [224]	train-mlogloss:0.394654	test-mlogloss:0.551185
# [225]	train-mlogloss:0.394132	test-mlogloss:0.551139
# [226]	train-mlogloss:0.393541	test-mlogloss:0.551068
# [227]	train-mlogloss:0.392969	test-mlogloss:0.550994
# [228]	train-mlogloss:0.392467	test-mlogloss:0.550991
# [229]	train-mlogloss:0.391889	test-mlogloss:0.551092
# [230]	train-mlogloss:0.39131	test-mlogloss:0.550961
# [231]	train-mlogloss:0.390793	test-mlogloss:0.550974
# [232]	train-mlogloss:0.390452	test-mlogloss:0.550916
# [233]	train-mlogloss:0.389907	test-mlogloss:0.550824
# [234]	train-mlogloss:0.389446	test-mlogloss:0.550804
# [235]	train-mlogloss:0.388916	test-mlogloss:0.550869
# [236]	train-mlogloss:0.388278	test-mlogloss:0.550824
# [237]	train-mlogloss:0.387866	test-mlogloss:0.550766
# [238]	train-mlogloss:0.387454	test-mlogloss:0.550866
# [239]	train-mlogloss:0.386882	test-mlogloss:0.550911
# [240]	train-mlogloss:0.386475	test-mlogloss:0.550968
# [241]	train-mlogloss:0.385978	test-mlogloss:0.550973
# [242]	train-mlogloss:0.385399	test-mlogloss:0.550926
# [243]	train-mlogloss:0.384974	test-mlogloss:0.550944
# [244]	train-mlogloss:0.384496	test-mlogloss:0.551043
# [245]	train-mlogloss:0.383824	test-mlogloss:0.55095
# [246]	train-mlogloss:0.383202	test-mlogloss:0.550803
# [247]	train-mlogloss:0.382681	test-mlogloss:0.550798
# [248]	train-mlogloss:0.382269	test-mlogloss:0.550787
# [249]	train-mlogloss:0.381635	test-mlogloss:0.550866
# [250]	train-mlogloss:0.381147	test-mlogloss:0.550927
# [251]	train-mlogloss:0.380596	test-mlogloss:0.55091
# [252]	train-mlogloss:0.380032	test-mlogloss:0.55085
# [253]	train-mlogloss:0.37942	test-mlogloss:0.550805
# [254]	train-mlogloss:0.378979	test-mlogloss:0.55089
# [255]	train-mlogloss:0.378344	test-mlogloss:0.550919
# [256]	train-mlogloss:0.377945	test-mlogloss:0.550953
# [257]	train-mlogloss:0.377322	test-mlogloss:0.550887
# [258]	train-mlogloss:0.376973	test-mlogloss:0.550923
# [259]	train-mlogloss:0.376408	test-mlogloss:0.551022
# [260]	train-mlogloss:0.375967	test-mlogloss:0.550999
# [261]	train-mlogloss:0.375548	test-mlogloss:0.550971
# [262]	train-mlogloss:0.375038	test-mlogloss:0.550864
# [263]	train-mlogloss:0.374458	test-mlogloss:0.550735
# [264]	train-mlogloss:0.373936	test-mlogloss:0.550719
# [265]	train-mlogloss:0.373505	test-mlogloss:0.550794
# [266]	train-mlogloss:0.372968	test-mlogloss:0.550798
# [267]	train-mlogloss:0.372465	test-mlogloss:0.550877
# [268]	train-mlogloss:0.371876	test-mlogloss:0.550776
# [269]	train-mlogloss:0.371453	test-mlogloss:0.550797
# [270]	train-mlogloss:0.370988	test-mlogloss:0.550751
# [271]	train-mlogloss:0.370409	test-mlogloss:0.550704
# [272]	train-mlogloss:0.370041	test-mlogloss:0.550727
# [273]	train-mlogloss:0.369589	test-mlogloss:0.550739
# [274]	train-mlogloss:0.369051	test-mlogloss:0.550772
# [275]	train-mlogloss:0.368539	test-mlogloss:0.5508
# [276]	train-mlogloss:0.368115	test-mlogloss:0.550722
# [277]	train-mlogloss:0.367583	test-mlogloss:0.550734
# [278]	train-mlogloss:0.367184	test-mlogloss:0.550675
# [279]	train-mlogloss:0.366742	test-mlogloss:0.550687
# [280]	train-mlogloss:0.366264	test-mlogloss:0.550657
# [281]	train-mlogloss:0.365847	test-mlogloss:0.550604
# [282]	train-mlogloss:0.365434	test-mlogloss:0.55055
# [283]	train-mlogloss:0.364959	test-mlogloss:0.550592
# [284]	train-mlogloss:0.364408	test-mlogloss:0.550565
# [285]	train-mlogloss:0.364044	test-mlogloss:0.550637
# [286]	train-mlogloss:0.363651	test-mlogloss:0.550694
# [287]	train-mlogloss:0.363084	test-mlogloss:0.550637
# [288]	train-mlogloss:0.362632	test-mlogloss:0.550634
# [289]	train-mlogloss:0.362212	test-mlogloss:0.55059
# [290]	train-mlogloss:0.36164	test-mlogloss:0.550654
# [291]	train-mlogloss:0.361065	test-mlogloss:0.550733
# [292]	train-mlogloss:0.360616	test-mlogloss:0.550722
# [293]	train-mlogloss:0.360328	test-mlogloss:0.550635
# [294]	train-mlogloss:0.359815	test-mlogloss:0.5506
# [295]	train-mlogloss:0.359346	test-mlogloss:0.550694
# [296]	train-mlogloss:0.358909	test-mlogloss:0.550803
# [297]	train-mlogloss:0.358453	test-mlogloss:0.550693
# [298]	train-mlogloss:0.358021	test-mlogloss:0.550741
# [299]	train-mlogloss:0.357553	test-mlogloss:0.550787
# [300]	train-mlogloss:0.357284	test-mlogloss:0.550867
# [301]	train-mlogloss:0.356838	test-mlogloss:0.550839
# [302]	train-mlogloss:0.356332	test-mlogloss:0.550927
# [303]	train-mlogloss:0.35593	test-mlogloss:0.5508
# [304]	train-mlogloss:0.355536	test-mlogloss:0.550884
# [305]	train-mlogloss:0.355081	test-mlogloss:0.55089
# [306]	train-mlogloss:0.354641	test-mlogloss:0.550963
# [307]	train-mlogloss:0.354158	test-mlogloss:0.551019
# [308]	train-mlogloss:0.353677	test-mlogloss:0.550959
# [309]	train-mlogloss:0.353116	test-mlogloss:0.551105
# [310]	train-mlogloss:0.35263	test-mlogloss:0.551226
# [311]	train-mlogloss:0.352176	test-mlogloss:0.551278
# [312]	train-mlogloss:0.35158	test-mlogloss:0.551197
# [313]	train-mlogloss:0.351139	test-mlogloss:0.551281
# [314]	train-mlogloss:0.350661	test-mlogloss:0.551416
# [315]	train-mlogloss:0.350367	test-mlogloss:0.551436
# [316]	train-mlogloss:0.349994	test-mlogloss:0.551388
# [317]	train-mlogloss:0.349731	test-mlogloss:0.55145
# [318]	train-mlogloss:0.349295	test-mlogloss:0.55153
# [319]	train-mlogloss:0.348879	test-mlogloss:0.55158
# [320]	train-mlogloss:0.348555	test-mlogloss:0.551535
# [321]	train-mlogloss:0.348172	test-mlogloss:0.551495
# [322]	train-mlogloss:0.347742	test-mlogloss:0.551547
# [323]	train-mlogloss:0.34735	test-mlogloss:0.551582
# [324]	train-mlogloss:0.346936	test-mlogloss:0.55163
# [325]	train-mlogloss:0.346507	test-mlogloss:0.551648
# [326]	train-mlogloss:0.346157	test-mlogloss:0.5517
# [327]	train-mlogloss:0.34572	test-mlogloss:0.55166
# [328]	train-mlogloss:0.345297	test-mlogloss:0.551567
# [329]	train-mlogloss:0.344791	test-mlogloss:0.551614
# [330]	train-mlogloss:0.344245	test-mlogloss:0.551726
# [331]	train-mlogloss:0.343774	test-mlogloss:0.551766
# [332]	train-mlogloss:0.343289	test-mlogloss:0.551685
# [333]	train-mlogloss:0.342822	test-mlogloss:0.551819
# [334]	train-mlogloss:0.342271	test-mlogloss:0.55174
# [335]	train-mlogloss:0.341799	test-mlogloss:0.55177
# [336]	train-mlogloss:0.341413	test-mlogloss:0.551773
# [337]	train-mlogloss:0.340995	test-mlogloss:0.551782
# [338]	train-mlogloss:0.340519	test-mlogloss:0.551759
# [339]	train-mlogloss:0.340089	test-mlogloss:0.551628
# [340]	train-mlogloss:0.33959	test-mlogloss:0.551768
# [341]	train-mlogloss:0.339179	test-mlogloss:0.551808
# [342]	train-mlogloss:0.338733	test-mlogloss:0.551813
# [343]	train-mlogloss:0.338418	test-mlogloss:0.551887
# [344]	train-mlogloss:0.338117	test-mlogloss:0.551844
# [345]	train-mlogloss:0.337706	test-mlogloss:0.551888
# [346]	train-mlogloss:0.33731	test-mlogloss:0.551814
# [347]	train-mlogloss:0.336744	test-mlogloss:0.55191
# [348]	train-mlogloss:0.336358	test-mlogloss:0.55193
# [349]	train-mlogloss:0.33606	test-mlogloss:0.551989
# [350]	train-mlogloss:0.335576	test-mlogloss:0.551922
# [351]	train-mlogloss:0.335101	test-mlogloss:0.551953
# [352]	train-mlogloss:0.334571	test-mlogloss:0.551976
# [353]	train-mlogloss:0.334128	test-mlogloss:0.551837
# [354]	train-mlogloss:0.333716	test-mlogloss:0.551949
# [355]	train-mlogloss:0.333311	test-mlogloss:0.551877
# [356]	train-mlogloss:0.332835	test-mlogloss:0.551875
# [357]	train-mlogloss:0.332379	test-mlogloss:0.551949
# [358]	train-mlogloss:0.331958	test-mlogloss:0.551986
# [359]	train-mlogloss:0.331685	test-mlogloss:0.551947
# [360]	train-mlogloss:0.33124	test-mlogloss:0.552061
# [361]	train-mlogloss:0.330857	test-mlogloss:0.552108
# [362]	train-mlogloss:0.33043	test-mlogloss:0.552185
# [363]	train-mlogloss:0.329909	test-mlogloss:0.552213
# [364]	train-mlogloss:0.32958	test-mlogloss:0.552267
# [365]	train-mlogloss:0.329187	test-mlogloss:0.55233
# [366]	train-mlogloss:0.328763	test-mlogloss:0.552221
# [367]	train-mlogloss:0.328455	test-mlogloss:0.552286
# [368]	train-mlogloss:0.327988	test-mlogloss:0.552568
# [369]	train-mlogloss:0.327665	test-mlogloss:0.552614
# [370]	train-mlogloss:0.32719	test-mlogloss:0.552609
# [371]	train-mlogloss:0.326689	test-mlogloss:0.552799
# [372]	train-mlogloss:0.326353	test-mlogloss:0.55288
# [373]	train-mlogloss:0.32587	test-mlogloss:0.552934
# [374]	train-mlogloss:0.325511	test-mlogloss:0.552962
# [375]	train-mlogloss:0.325023	test-mlogloss:0.552905
# [376]	train-mlogloss:0.32456	test-mlogloss:0.553011
# [377]	train-mlogloss:0.324302	test-mlogloss:0.553142
# [378]	train-mlogloss:0.32398	test-mlogloss:0.553153
# [379]	train-mlogloss:0.323479	test-mlogloss:0.553265
# [380]	train-mlogloss:0.323082	test-mlogloss:0.553391
# [381]	train-mlogloss:0.32276	test-mlogloss:0.55343
# [382]	train-mlogloss:0.32247	test-mlogloss:0.553423
# Stopping. Best iteration:
# [282]	train-mlogloss:0.365434	test-mlogloss:0.55055
#
# [0.55342346230891126]

# %%
#output the outcome - using xgboost
train_set, test_set =manager_skill_eval(train_df,test_df)
features_to_use.append('manager_skill')

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=285)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point2withHccSorted.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
