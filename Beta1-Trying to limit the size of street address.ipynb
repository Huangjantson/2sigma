# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold

import re
import string

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    #nth -> n
    #nst -> n
    #nrd -> n
    #nnd -> n
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    

    return street
    
def getStreetNumber(address):
    #get building id in the front, return -1 if their isn't
    pattern = re.compile('^([\d-]*)([\s]+)')
    try:
        number = pattern.search(address).group(1)
        return int(number)
    except:
        return -1

#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    return df1, df2

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

train_df["street_number"] = train_df["street_address"].apply(getStreetNumber)
test_df["street_number"] = test_df["street_address"].apply(getStreetNumber)

#features_to_use.append("street_number")

# %%
#dealing feature with categorical features 
#used street name instead of the original one 
"""
display_address 8826    
building_id        7585   =》many zeros in this feature
manager_id   3481
street_address 15358 =》will be 3800 if no numbers in it 
"""

"""
notice the encoding here, the latter using of the mse might have some leakage here
"""
categorical = ["display_address", "manager_id", "building_id", "street_name","street_address"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f) singleValueConvert
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_X = train_df[features_to_use]
test_X = test_df[features_to_use]

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_X),5,shuffle=True,random_state = 42)

# %%
#running and getting the cv from xgboost
cv_scores = []
#K-FOLD already defined.If not ,use
#KF=KFold(len(train_X),5,shuffle=True,random_state = 42)
for dev_index, val_index in KF:
        #apply the 
        dev_X, val_X = singleValueConvert(train_X.iloc[dev_index,:], train_X.iloc[val_index,:],"street_name")
        dev_X, val_X = dev_X.as_matrix(), val_X.as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=list(list(train_X.columns)))
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# C:\Users\dell\Anaconda2\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# [0]	train-mlogloss:1.04023	test-mlogloss:1.04166
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.989301	test-mlogloss:0.992057
# [2]	train-mlogloss:0.948296	test-mlogloss:0.952305
# [3]	train-mlogloss:0.912601	test-mlogloss:0.91761
# [4]	train-mlogloss:0.881667	test-mlogloss:0.887873
# [5]	train-mlogloss:0.854977	test-mlogloss:0.862252
# [6]	train-mlogloss:0.830246	test-mlogloss:0.838474
# [7]	train-mlogloss:0.807561	test-mlogloss:0.816734
# [8]	train-mlogloss:0.787538	test-mlogloss:0.797688
# [9]	train-mlogloss:0.769792	test-mlogloss:0.780715
# [10]	train-mlogloss:0.7532	test-mlogloss:0.765174
# [11]	train-mlogloss:0.738002	test-mlogloss:0.750977
# [12]	train-mlogloss:0.723967	test-mlogloss:0.737607
# [13]	train-mlogloss:0.712004	test-mlogloss:0.72644
# [14]	train-mlogloss:0.702339	test-mlogloss:0.717478
# [15]	train-mlogloss:0.694389	test-mlogloss:0.710228
# [16]	train-mlogloss:0.686341	test-mlogloss:0.702974
# [17]	train-mlogloss:0.678281	test-mlogloss:0.69562
# [18]	train-mlogloss:0.671091	test-mlogloss:0.689113
# [19]	train-mlogloss:0.663863	test-mlogloss:0.682615
# [20]	train-mlogloss:0.65857	test-mlogloss:0.67794
# [21]	train-mlogloss:0.653098	test-mlogloss:0.673051
# [22]	train-mlogloss:0.648476	test-mlogloss:0.669217
# [23]	train-mlogloss:0.643466	test-mlogloss:0.66468
# [24]	train-mlogloss:0.638092	test-mlogloss:0.660078
# [25]	train-mlogloss:0.634628	test-mlogloss:0.657146
# [26]	train-mlogloss:0.630511	test-mlogloss:0.65351
# [27]	train-mlogloss:0.626646	test-mlogloss:0.650472
# [28]	train-mlogloss:0.622113	test-mlogloss:0.646677
# [29]	train-mlogloss:0.618768	test-mlogloss:0.644004
# [30]	train-mlogloss:0.615877	test-mlogloss:0.641837
# [31]	train-mlogloss:0.612731	test-mlogloss:0.639506
# [32]	train-mlogloss:0.608964	test-mlogloss:0.63656
# [33]	train-mlogloss:0.605299	test-mlogloss:0.633795
# [34]	train-mlogloss:0.602617	test-mlogloss:0.631952
# [35]	train-mlogloss:0.600122	test-mlogloss:0.630298
# [36]	train-mlogloss:0.59742	test-mlogloss:0.628091
# [37]	train-mlogloss:0.595157	test-mlogloss:0.626471
# [38]	train-mlogloss:0.592134	test-mlogloss:0.624378
# [39]	train-mlogloss:0.590136	test-mlogloss:0.623044
# [40]	train-mlogloss:0.587889	test-mlogloss:0.62129
# [41]	train-mlogloss:0.58555	test-mlogloss:0.619766
# [42]	train-mlogloss:0.583254	test-mlogloss:0.618025
# [43]	train-mlogloss:0.581413	test-mlogloss:0.616845
# [44]	train-mlogloss:0.57925	test-mlogloss:0.615794
# [45]	train-mlogloss:0.577228	test-mlogloss:0.61456
# [46]	train-mlogloss:0.575793	test-mlogloss:0.613626
# [47]	train-mlogloss:0.573907	test-mlogloss:0.612494
# [48]	train-mlogloss:0.572698	test-mlogloss:0.611728
# [49]	train-mlogloss:0.570789	test-mlogloss:0.610633
# [50]	train-mlogloss:0.569439	test-mlogloss:0.609664
# [51]	train-mlogloss:0.568047	test-mlogloss:0.609045
# [52]	train-mlogloss:0.566673	test-mlogloss:0.608493
# [53]	train-mlogloss:0.56541	test-mlogloss:0.607808
# [54]	train-mlogloss:0.563904	test-mlogloss:0.606998
# [55]	train-mlogloss:0.561838	test-mlogloss:0.605856
# [56]	train-mlogloss:0.560004	test-mlogloss:0.604884
# [57]	train-mlogloss:0.55833	test-mlogloss:0.603855
# [58]	train-mlogloss:0.556954	test-mlogloss:0.603376
# [59]	train-mlogloss:0.555369	test-mlogloss:0.602603
# [60]	train-mlogloss:0.553878	test-mlogloss:0.601854
# [61]	train-mlogloss:0.552273	test-mlogloss:0.600964
# [62]	train-mlogloss:0.550755	test-mlogloss:0.60028
# [63]	train-mlogloss:0.548961	test-mlogloss:0.599108
# [64]	train-mlogloss:0.547436	test-mlogloss:0.598288
# [65]	train-mlogloss:0.546238	test-mlogloss:0.597822
# [66]	train-mlogloss:0.544559	test-mlogloss:0.59724
# [67]	train-mlogloss:0.543312	test-mlogloss:0.596919
# [68]	train-mlogloss:0.541818	test-mlogloss:0.596121
# [69]	train-mlogloss:0.540541	test-mlogloss:0.595675
# [70]	train-mlogloss:0.539414	test-mlogloss:0.595318
# [71]	train-mlogloss:0.53798	test-mlogloss:0.594682
# [72]	train-mlogloss:0.537012	test-mlogloss:0.594481
# [73]	train-mlogloss:0.535477	test-mlogloss:0.593754
# [74]	train-mlogloss:0.534421	test-mlogloss:0.593361
# [75]	train-mlogloss:0.533443	test-mlogloss:0.592953
# [76]	train-mlogloss:0.531898	test-mlogloss:0.592294
# [77]	train-mlogloss:0.531033	test-mlogloss:0.591812
# [78]	train-mlogloss:0.52996	test-mlogloss:0.591414
# [79]	train-mlogloss:0.528867	test-mlogloss:0.590784
# [80]	train-mlogloss:0.527635	test-mlogloss:0.590381
# [81]	train-mlogloss:0.526453	test-mlogloss:0.589894
# [82]	train-mlogloss:0.525339	test-mlogloss:0.589458
# [83]	train-mlogloss:0.524128	test-mlogloss:0.58908
# [84]	train-mlogloss:0.522714	test-mlogloss:0.588477
# [85]	train-mlogloss:0.521832	test-mlogloss:0.58821
# [86]	train-mlogloss:0.520619	test-mlogloss:0.587771
# [87]	train-mlogloss:0.519698	test-mlogloss:0.587335
# [88]	train-mlogloss:0.518845	test-mlogloss:0.587041
# [89]	train-mlogloss:0.517709	test-mlogloss:0.586558
# [90]	train-mlogloss:0.516971	test-mlogloss:0.586202
# [91]	train-mlogloss:0.516021	test-mlogloss:0.585877
# [92]	train-mlogloss:0.515053	test-mlogloss:0.585612
# [93]	train-mlogloss:0.514293	test-mlogloss:0.585319
# [94]	train-mlogloss:0.513394	test-mlogloss:0.585044
# [95]	train-mlogloss:0.512435	test-mlogloss:0.584968
# [96]	train-mlogloss:0.511277	test-mlogloss:0.584787
# [97]	train-mlogloss:0.510482	test-mlogloss:0.58436
# [98]	train-mlogloss:0.509616	test-mlogloss:0.584073
# [99]	train-mlogloss:0.508673	test-mlogloss:0.583843
# [100]	train-mlogloss:0.507426	test-mlogloss:0.583463
# [101]	train-mlogloss:0.506469	test-mlogloss:0.583175
# [102]	train-mlogloss:0.505913	test-mlogloss:0.583118
# [103]	train-mlogloss:0.505068	test-mlogloss:0.583007
# [104]	train-mlogloss:0.504006	test-mlogloss:0.582705
# [105]	train-mlogloss:0.503104	test-mlogloss:0.582577
# [106]	train-mlogloss:0.502267	test-mlogloss:0.582234
# [107]	train-mlogloss:0.501309	test-mlogloss:0.581887
# [108]	train-mlogloss:0.500492	test-mlogloss:0.581453
# [109]	train-mlogloss:0.499476	test-mlogloss:0.581101
# [110]	train-mlogloss:0.49867	test-mlogloss:0.580917
# [111]	train-mlogloss:0.49786	test-mlogloss:0.580613
# [112]	train-mlogloss:0.497068	test-mlogloss:0.580576
# [113]	train-mlogloss:0.496102	test-mlogloss:0.580229
# [114]	train-mlogloss:0.495316	test-mlogloss:0.580039
# [115]	train-mlogloss:0.494314	test-mlogloss:0.579806
# [116]	train-mlogloss:0.493725	test-mlogloss:0.57966
# [117]	train-mlogloss:0.493046	test-mlogloss:0.579449
# [118]	train-mlogloss:0.492037	test-mlogloss:0.579084
# [119]	train-mlogloss:0.491102	test-mlogloss:0.578769
# [120]	train-mlogloss:0.490065	test-mlogloss:0.578502
# [121]	train-mlogloss:0.489165	test-mlogloss:0.578286
# [122]	train-mlogloss:0.48832	test-mlogloss:0.577994
# [123]	train-mlogloss:0.487366	test-mlogloss:0.577724
# [124]	train-mlogloss:0.486571	test-mlogloss:0.5775
# [125]	train-mlogloss:0.485758	test-mlogloss:0.577248
# [126]	train-mlogloss:0.485101	test-mlogloss:0.577123
# [127]	train-mlogloss:0.484242	test-mlogloss:0.576921
# [128]	train-mlogloss:0.483542	test-mlogloss:0.576698
# [129]	train-mlogloss:0.483049	test-mlogloss:0.576536
# [130]	train-mlogloss:0.482044	test-mlogloss:0.576389
# [131]	train-mlogloss:0.481724	test-mlogloss:0.576233
# [132]	train-mlogloss:0.48093	test-mlogloss:0.575958
# [133]	train-mlogloss:0.479888	test-mlogloss:0.575848
# [134]	train-mlogloss:0.478911	test-mlogloss:0.575677
# [135]	train-mlogloss:0.478229	test-mlogloss:0.575463
# [136]	train-mlogloss:0.47764	test-mlogloss:0.575236
# [137]	train-mlogloss:0.476774	test-mlogloss:0.575099
# [138]	train-mlogloss:0.476127	test-mlogloss:0.57483
# [139]	train-mlogloss:0.475381	test-mlogloss:0.574555
# [140]	train-mlogloss:0.474509	test-mlogloss:0.574499
# [141]	train-mlogloss:0.473719	test-mlogloss:0.574381
# [142]	train-mlogloss:0.472982	test-mlogloss:0.574284
# [143]	train-mlogloss:0.472342	test-mlogloss:0.574137
# [144]	train-mlogloss:0.471602	test-mlogloss:0.574012
# [145]	train-mlogloss:0.470891	test-mlogloss:0.573937
# [146]	train-mlogloss:0.469932	test-mlogloss:0.573721
# [147]	train-mlogloss:0.469327	test-mlogloss:0.573576
# [148]	train-mlogloss:0.468526	test-mlogloss:0.573472
# [149]	train-mlogloss:0.467734	test-mlogloss:0.573199
# [150]	train-mlogloss:0.466949	test-mlogloss:0.572982
# [151]	train-mlogloss:0.466468	test-mlogloss:0.572913
# [152]	train-mlogloss:0.465888	test-mlogloss:0.572683
# [153]	train-mlogloss:0.465196	test-mlogloss:0.572584
# [154]	train-mlogloss:0.464428	test-mlogloss:0.572316
# [155]	train-mlogloss:0.463811	test-mlogloss:0.572136
# [156]	train-mlogloss:0.463228	test-mlogloss:0.572024
# [157]	train-mlogloss:0.462644	test-mlogloss:0.571901
# [158]	train-mlogloss:0.461926	test-mlogloss:0.571868
# [159]	train-mlogloss:0.461018	test-mlogloss:0.571669
# [160]	train-mlogloss:0.460258	test-mlogloss:0.571616
# [161]	train-mlogloss:0.459288	test-mlogloss:0.571487
# [162]	train-mlogloss:0.458816	test-mlogloss:0.571442
# [163]	train-mlogloss:0.458466	test-mlogloss:0.571359
# [164]	train-mlogloss:0.457784	test-mlogloss:0.571283
# [165]	train-mlogloss:0.45717	test-mlogloss:0.571231
# [166]	train-mlogloss:0.456412	test-mlogloss:0.571217
# [167]	train-mlogloss:0.455941	test-mlogloss:0.57106
# [168]	train-mlogloss:0.455408	test-mlogloss:0.571
# [169]	train-mlogloss:0.454747	test-mlogloss:0.570871
# [170]	train-mlogloss:0.454032	test-mlogloss:0.570734
# [171]	train-mlogloss:0.453458	test-mlogloss:0.570566
# [172]	train-mlogloss:0.452836	test-mlogloss:0.570381
# [173]	train-mlogloss:0.452279	test-mlogloss:0.5704
# [174]	train-mlogloss:0.45165	test-mlogloss:0.570228
# [175]	train-mlogloss:0.451049	test-mlogloss:0.570063
# [176]	train-mlogloss:0.450466	test-mlogloss:0.569886
# [177]	train-mlogloss:0.449914	test-mlogloss:0.569775
# [178]	train-mlogloss:0.44926	test-mlogloss:0.569575
# [179]	train-mlogloss:0.448541	test-mlogloss:0.569449
# [180]	train-mlogloss:0.448064	test-mlogloss:0.569425
# [181]	train-mlogloss:0.447405	test-mlogloss:0.569366
# [182]	train-mlogloss:0.44695	test-mlogloss:0.569243
# [183]	train-mlogloss:0.446321	test-mlogloss:0.569159
# [184]	train-mlogloss:0.445713	test-mlogloss:0.569099
# [185]	train-mlogloss:0.445198	test-mlogloss:0.568923
# [186]	train-mlogloss:0.444581	test-mlogloss:0.568724
# [187]	train-mlogloss:0.443992	test-mlogloss:0.568624
# [188]	train-mlogloss:0.443366	test-mlogloss:0.568697
# [189]	train-mlogloss:0.442853	test-mlogloss:0.568639
# [190]	train-mlogloss:0.442307	test-mlogloss:0.568533
# [191]	train-mlogloss:0.441584	test-mlogloss:0.568388
# [192]	train-mlogloss:0.440885	test-mlogloss:0.568437
# [193]	train-mlogloss:0.440316	test-mlogloss:0.56839
# [194]	train-mlogloss:0.439833	test-mlogloss:0.568379
# [195]	train-mlogloss:0.439261	test-mlogloss:0.568319
# [196]	train-mlogloss:0.438662	test-mlogloss:0.568246
# [197]	train-mlogloss:0.438225	test-mlogloss:0.568111
# [198]	train-mlogloss:0.43767	test-mlogloss:0.568057
# [199]	train-mlogloss:0.437087	test-mlogloss:0.567989
# [200]	train-mlogloss:0.436597	test-mlogloss:0.567868
# [201]	train-mlogloss:0.436139	test-mlogloss:0.567816
# [202]	train-mlogloss:0.435582	test-mlogloss:0.567778
# [203]	train-mlogloss:0.435227	test-mlogloss:0.567727
# [204]	train-mlogloss:0.434748	test-mlogloss:0.567636
# [205]	train-mlogloss:0.434057	test-mlogloss:0.567469
# [206]	train-mlogloss:0.433642	test-mlogloss:0.567413
# [207]	train-mlogloss:0.43308	test-mlogloss:0.567436
# [208]	train-mlogloss:0.432593	test-mlogloss:0.567338
# [209]	train-mlogloss:0.432065	test-mlogloss:0.567342
# [210]	train-mlogloss:0.431577	test-mlogloss:0.56726
# [211]	train-mlogloss:0.430961	test-mlogloss:0.567068
# [212]	train-mlogloss:0.430329	test-mlogloss:0.5669
# [213]	train-mlogloss:0.429857	test-mlogloss:0.566841
# [214]	train-mlogloss:0.429297	test-mlogloss:0.566809
# [215]	train-mlogloss:0.428576	test-mlogloss:0.566592
# [216]	train-mlogloss:0.42807	test-mlogloss:0.56657
# [217]	train-mlogloss:0.427578	test-mlogloss:0.566459
# [218]	train-mlogloss:0.427006	test-mlogloss:0.566306
# [219]	train-mlogloss:0.426582	test-mlogloss:0.566215
# [220]	train-mlogloss:0.425804	test-mlogloss:0.566137
# [221]	train-mlogloss:0.425178	test-mlogloss:0.566249
# [222]	train-mlogloss:0.424616	test-mlogloss:0.566279
# [223]	train-mlogloss:0.424124	test-mlogloss:0.566242
# [224]	train-mlogloss:0.423696	test-mlogloss:0.566238
# [225]	train-mlogloss:0.423326	test-mlogloss:0.566199
# [226]	train-mlogloss:0.422747	test-mlogloss:0.566198
# [227]	train-mlogloss:0.422205	test-mlogloss:0.566205
# [228]	train-mlogloss:0.42173	test-mlogloss:0.566027
# [229]	train-mlogloss:0.421109	test-mlogloss:0.565842
# [230]	train-mlogloss:0.420341	test-mlogloss:0.565659
# [231]	train-mlogloss:0.419792	test-mlogloss:0.565657
# [232]	train-mlogloss:0.419302	test-mlogloss:0.565567
# [233]	train-mlogloss:0.418713	test-mlogloss:0.565521
# [234]	train-mlogloss:0.41823	test-mlogloss:0.56539
# [235]	train-mlogloss:0.417616	test-mlogloss:0.565285
# [236]	train-mlogloss:0.417016	test-mlogloss:0.565382
# [237]	train-mlogloss:0.416548	test-mlogloss:0.565444
# [238]	train-mlogloss:0.415961	test-mlogloss:0.565324
# [239]	train-mlogloss:0.415636	test-mlogloss:0.565294
# [240]	train-mlogloss:0.415016	test-mlogloss:0.565222
# [241]	train-mlogloss:0.414626	test-mlogloss:0.565194
# [242]	train-mlogloss:0.414154	test-mlogloss:0.565088
# [243]	train-mlogloss:0.413732	test-mlogloss:0.565073
# [244]	train-mlogloss:0.413263	test-mlogloss:0.565058
# [245]	train-mlogloss:0.412714	test-mlogloss:0.565206
# [246]	train-mlogloss:0.412295	test-mlogloss:0.565143
# [247]	train-mlogloss:0.411856	test-mlogloss:0.565087
# [248]	train-mlogloss:0.411336	test-mlogloss:0.564959
# [249]	train-mlogloss:0.410894	test-mlogloss:0.564925
# [250]	train-mlogloss:0.410403	test-mlogloss:0.564893
# [251]	train-mlogloss:0.409928	test-mlogloss:0.56488
# [252]	train-mlogloss:0.409511	test-mlogloss:0.564822
# [253]	train-mlogloss:0.409045	test-mlogloss:0.564829
# [254]	train-mlogloss:0.408432	test-mlogloss:0.564745
# [255]	train-mlogloss:0.407971	test-mlogloss:0.564665
# [256]	train-mlogloss:0.407548	test-mlogloss:0.56472
# [257]	train-mlogloss:0.406943	test-mlogloss:0.564544
# [258]	train-mlogloss:0.406475	test-mlogloss:0.56456
# [259]	train-mlogloss:0.405902	test-mlogloss:0.564522
# [260]	train-mlogloss:0.40543	test-mlogloss:0.564479
# [261]	train-mlogloss:0.404988	test-mlogloss:0.564383
# [262]	train-mlogloss:0.404397	test-mlogloss:0.564378
# [263]	train-mlogloss:0.404056	test-mlogloss:0.564363
# [264]	train-mlogloss:0.403688	test-mlogloss:0.564357
# [265]	train-mlogloss:0.403216	test-mlogloss:0.564339
# [266]	train-mlogloss:0.402843	test-mlogloss:0.564363
# [267]	train-mlogloss:0.402169	test-mlogloss:0.564358
# [268]	train-mlogloss:0.401688	test-mlogloss:0.564332
# [269]	train-mlogloss:0.401168	test-mlogloss:0.564372
# [270]	train-mlogloss:0.400833	test-mlogloss:0.564349
# [271]	train-mlogloss:0.40035	test-mlogloss:0.564359
# [272]	train-mlogloss:0.399832	test-mlogloss:0.564334
# [273]	train-mlogloss:0.399371	test-mlogloss:0.564327
# [274]	train-mlogloss:0.398933	test-mlogloss:0.564228
# [275]	train-mlogloss:0.398505	test-mlogloss:0.564234
# [276]	train-mlogloss:0.397871	test-mlogloss:0.564154
# [277]	train-mlogloss:0.397227	test-mlogloss:0.564089
# [278]	train-mlogloss:0.396778	test-mlogloss:0.564066
# [279]	train-mlogloss:0.39616	test-mlogloss:0.564066
# [280]	train-mlogloss:0.395775	test-mlogloss:0.564089
# [281]	train-mlogloss:0.395329	test-mlogloss:0.564197
# [282]	train-mlogloss:0.394952	test-mlogloss:0.564208
# [283]	train-mlogloss:0.394434	test-mlogloss:0.564159
# [284]	train-mlogloss:0.393912	test-mlogloss:0.564134
# [285]	train-mlogloss:0.393386	test-mlogloss:0.564041
# [286]	train-mlogloss:0.392857	test-mlogloss:0.563927
# [287]	train-mlogloss:0.39238	test-mlogloss:0.563951
# [288]	train-mlogloss:0.391819	test-mlogloss:0.56387
# [289]	train-mlogloss:0.391535	test-mlogloss:0.563772
# [290]	train-mlogloss:0.391214	test-mlogloss:0.563761
# [291]	train-mlogloss:0.390655	test-mlogloss:0.563782
# [292]	train-mlogloss:0.390296	test-mlogloss:0.563778
# [293]	train-mlogloss:0.389863	test-mlogloss:0.563868
# [294]	train-mlogloss:0.389443	test-mlogloss:0.563865
# [295]	train-mlogloss:0.388911	test-mlogloss:0.563785
# [296]	train-mlogloss:0.3884	test-mlogloss:0.563599
# [297]	train-mlogloss:0.387931	test-mlogloss:0.563669
# [298]	train-mlogloss:0.387472	test-mlogloss:0.563639
# [299]	train-mlogloss:0.387099	test-mlogloss:0.56357
# [300]	train-mlogloss:0.38646	test-mlogloss:0.56339
# [301]	train-mlogloss:0.386009	test-mlogloss:0.563424
# [302]	train-mlogloss:0.385484	test-mlogloss:0.563387
# [303]	train-mlogloss:0.385085	test-mlogloss:0.563284
# [304]	train-mlogloss:0.38473	test-mlogloss:0.563279
# [305]	train-mlogloss:0.384297	test-mlogloss:0.563315
# [306]	train-mlogloss:0.383796	test-mlogloss:0.563399
# [307]	train-mlogloss:0.383406	test-mlogloss:0.563291
# [308]	train-mlogloss:0.382939	test-mlogloss:0.563205
# [309]	train-mlogloss:0.382599	test-mlogloss:0.563293
# [310]	train-mlogloss:0.382184	test-mlogloss:0.563319
# [311]	train-mlogloss:0.38182	test-mlogloss:0.563247
# [312]	train-mlogloss:0.381327	test-mlogloss:0.563166
# [313]	train-mlogloss:0.380883	test-mlogloss:0.56321
# [314]	train-mlogloss:0.380432	test-mlogloss:0.563266
# [315]	train-mlogloss:0.379896	test-mlogloss:0.563214
# [316]	train-mlogloss:0.379357	test-mlogloss:0.563117
# [317]	train-mlogloss:0.379025	test-mlogloss:0.563124
# [318]	train-mlogloss:0.378667	test-mlogloss:0.5632
# [319]	train-mlogloss:0.378293	test-mlogloss:0.563188
# [320]	train-mlogloss:0.378016	test-mlogloss:0.563251
# [321]	train-mlogloss:0.377514	test-mlogloss:0.56316
# [322]	train-mlogloss:0.377076	test-mlogloss:0.563069
# [323]	train-mlogloss:0.376698	test-mlogloss:0.563125
# [324]	train-mlogloss:0.37629	test-mlogloss:0.563225
# [325]	train-mlogloss:0.375851	test-mlogloss:0.563276
# [326]	train-mlogloss:0.375463	test-mlogloss:0.563272
# [327]	train-mlogloss:0.375138	test-mlogloss:0.563309
# [328]	train-mlogloss:0.374884	test-mlogloss:0.56324
# [329]	train-mlogloss:0.374414	test-mlogloss:0.563171
# [330]	train-mlogloss:0.374083	test-mlogloss:0.563174
# [331]	train-mlogloss:0.373685	test-mlogloss:0.56311
# [332]	train-mlogloss:0.373279	test-mlogloss:0.563215
# [333]	train-mlogloss:0.37294	test-mlogloss:0.563221
# [334]	train-mlogloss:0.372594	test-mlogloss:0.563183
# [335]	train-mlogloss:0.372221	test-mlogloss:0.563234
# [336]	train-mlogloss:0.371817	test-mlogloss:0.563237
# [337]	train-mlogloss:0.371384	test-mlogloss:0.563256
# [338]	train-mlogloss:0.371018	test-mlogloss:0.563176
# [339]	train-mlogloss:0.370515	test-mlogloss:0.563132
# [340]	train-mlogloss:0.370052	test-mlogloss:0.56318
# [341]	train-mlogloss:0.369545	test-mlogloss:0.56311
# [342]	train-mlogloss:0.369116	test-mlogloss:0.56313
# [343]	train-mlogloss:0.368659	test-mlogloss:0.56309
# [344]	train-mlogloss:0.368288	test-mlogloss:0.56303
# [345]	train-mlogloss:0.367894	test-mlogloss:0.562869
# [346]	train-mlogloss:0.367497	test-mlogloss:0.562888
# [347]	train-mlogloss:0.367202	test-mlogloss:0.562911
# [348]	train-mlogloss:0.366881	test-mlogloss:0.562882
# [349]	train-mlogloss:0.366639	test-mlogloss:0.562872
# [350]	train-mlogloss:0.366268	test-mlogloss:0.562891
# [351]	train-mlogloss:0.365806	test-mlogloss:0.562906
# [352]	train-mlogloss:0.365437	test-mlogloss:0.562939
# [353]	train-mlogloss:0.365135	test-mlogloss:0.562886
# [354]	train-mlogloss:0.364798	test-mlogloss:0.562966
# [355]	train-mlogloss:0.364443	test-mlogloss:0.562913
# [356]	train-mlogloss:0.36406	test-mlogloss:0.562921
# [357]	train-mlogloss:0.36356	test-mlogloss:0.562857
# [358]	train-mlogloss:0.36319	test-mlogloss:0.562885
# [359]	train-mlogloss:0.362649	test-mlogloss:0.562919
# [360]	train-mlogloss:0.362222	test-mlogloss:0.562948
# [361]	train-mlogloss:0.361847	test-mlogloss:0.56284
# [362]	train-mlogloss:0.361387	test-mlogloss:0.562827
# [363]	train-mlogloss:0.360916	test-mlogloss:0.562865
# [364]	train-mlogloss:0.360453	test-mlogloss:0.562833
# [365]	train-mlogloss:0.360007	test-mlogloss:0.562717
# [366]	train-mlogloss:0.359685	test-mlogloss:0.562601
# [367]	train-mlogloss:0.359293	test-mlogloss:0.562639
# [368]	train-mlogloss:0.358988	test-mlogloss:0.562673
# [369]	train-mlogloss:0.358578	test-mlogloss:0.562659
# [370]	train-mlogloss:0.35812	test-mlogloss:0.56271
# [371]	train-mlogloss:0.35777	test-mlogloss:0.562765
# [372]	train-mlogloss:0.357389	test-mlogloss:0.562781
# [373]	train-mlogloss:0.356973	test-mlogloss:0.562759
# [374]	train-mlogloss:0.356533	test-mlogloss:0.562715
# [375]	train-mlogloss:0.356232	test-mlogloss:0.562693
# [376]	train-mlogloss:0.355778	test-mlogloss:0.562782
# [377]	train-mlogloss:0.35546	test-mlogloss:0.562757
# [378]	train-mlogloss:0.354967	test-mlogloss:0.562797
# [379]	train-mlogloss:0.35447	test-mlogloss:0.562705
# [380]	train-mlogloss:0.354081	test-mlogloss:0.562566
# [381]	train-mlogloss:0.353659	test-mlogloss:0.562625
# [382]	train-mlogloss:0.353167	test-mlogloss:0.562578
# [383]	train-mlogloss:0.352742	test-mlogloss:0.562635
# [384]	train-mlogloss:0.352352	test-mlogloss:0.562572
# [385]	train-mlogloss:0.351879	test-mlogloss:0.562547
# [386]	train-mlogloss:0.351448	test-mlogloss:0.562569
# [387]	train-mlogloss:0.350989	test-mlogloss:0.562524
# [388]	train-mlogloss:0.350779	test-mlogloss:0.562422
# [389]	train-mlogloss:0.350406	test-mlogloss:0.562396
# [390]	train-mlogloss:0.350053	test-mlogloss:0.56236
# [391]	train-mlogloss:0.349578	test-mlogloss:0.562348
# [392]	train-mlogloss:0.349218	test-mlogloss:0.562317
# [393]	train-mlogloss:0.348865	test-mlogloss:0.562345
# [394]	train-mlogloss:0.348523	test-mlogloss:0.562365
# [395]	train-mlogloss:0.348211	test-mlogloss:0.562328
# [396]	train-mlogloss:0.347863	test-mlogloss:0.56226
# [397]	train-mlogloss:0.347613	test-mlogloss:0.562279
# [398]	train-mlogloss:0.347287	test-mlogloss:0.562278
# [399]	train-mlogloss:0.34687	test-mlogloss:0.56221
# [400]	train-mlogloss:0.346499	test-mlogloss:0.562208
# [401]	train-mlogloss:0.346147	test-mlogloss:0.562119
# [402]	train-mlogloss:0.345805	test-mlogloss:0.562175
# [403]	train-mlogloss:0.345459	test-mlogloss:0.562112
# [404]	train-mlogloss:0.345016	test-mlogloss:0.56216
# [405]	train-mlogloss:0.344658	test-mlogloss:0.56207
# [406]	train-mlogloss:0.344331	test-mlogloss:0.562125
# [407]	train-mlogloss:0.343911	test-mlogloss:0.562073
# [408]	train-mlogloss:0.343637	test-mlogloss:0.562004
# [409]	train-mlogloss:0.343137	test-mlogloss:0.561936
# [410]	train-mlogloss:0.342774	test-mlogloss:0.561933
# [411]	train-mlogloss:0.342463	test-mlogloss:0.561985
# [412]	train-mlogloss:0.34203	test-mlogloss:0.562029
# [413]	train-mlogloss:0.341686	test-mlogloss:0.56209
# [414]	train-mlogloss:0.341285	test-mlogloss:0.56205
# [415]	train-mlogloss:0.340897	test-mlogloss:0.562066
# [416]	train-mlogloss:0.340649	test-mlogloss:0.562061
# [417]	train-mlogloss:0.340329	test-mlogloss:0.562118
# [418]	train-mlogloss:0.339903	test-mlogloss:0.562109
# [419]	train-mlogloss:0.339535	test-mlogloss:0.562168
# [420]	train-mlogloss:0.339312	test-mlogloss:0.56214
# [421]	train-mlogloss:0.338955	test-mlogloss:0.562238
# [422]	train-mlogloss:0.338576	test-mlogloss:0.562176
# [423]	train-mlogloss:0.338142	test-mlogloss:0.562146
# [424]	train-mlogloss:0.33779	test-mlogloss:0.56211
# [425]	train-mlogloss:0.337358	test-mlogloss:0.562061
# [426]	train-mlogloss:0.337018	test-mlogloss:0.562074
# [427]	train-mlogloss:0.336537	test-mlogloss:0.562221
# [428]	train-mlogloss:0.336169	test-mlogloss:0.562351
# [429]	train-mlogloss:0.335799	test-mlogloss:0.562403
# [430]	train-mlogloss:0.335489	test-mlogloss:0.562378
# [431]	train-mlogloss:0.335137	test-mlogloss:0.562464
# [432]	train-mlogloss:0.334721	test-mlogloss:0.562524
# [433]	train-mlogloss:0.334266	test-mlogloss:0.562606
# [434]	train-mlogloss:0.333741	test-mlogloss:0.562478
# [435]	train-mlogloss:0.333445	test-mlogloss:0.562471
# [436]	train-mlogloss:0.333037	test-mlogloss:0.562365
# [437]	train-mlogloss:0.332657	test-mlogloss:0.562401
# [438]	train-mlogloss:0.332236	test-mlogloss:0.562412
# [439]	train-mlogloss:0.331952	test-mlogloss:0.562427
# [440]	train-mlogloss:0.331622	test-mlogloss:0.562382
# [441]	train-mlogloss:0.331245	test-mlogloss:0.562486
# [442]	train-mlogloss:0.330754	test-mlogloss:0.562647
# [443]	train-mlogloss:0.330418	test-mlogloss:0.562576
# [444]	train-mlogloss:0.330073	test-mlogloss:0.56269
# [445]	train-mlogloss:0.329671	test-mlogloss:0.562696
# [446]	train-mlogloss:0.329252	test-mlogloss:0.562819
# [447]	train-mlogloss:0.328933	test-mlogloss:0.562878
# [448]	train-mlogloss:0.328524	test-mlogloss:0.562882
# [449]	train-mlogloss:0.328123	test-mlogloss:0.562932
# [450]	train-mlogloss:0.327692	test-mlogloss:0.563016
# [451]	train-mlogloss:0.327227	test-mlogloss:0.563088
# [452]	train-mlogloss:0.326867	test-mlogloss:0.563093
# [453]	train-mlogloss:0.326504	test-mlogloss:0.563142
# [454]	train-mlogloss:0.32615	test-mlogloss:0.563119
# [455]	train-mlogloss:0.325844	test-mlogloss:0.563049
# [456]	train-mlogloss:0.325547	test-mlogloss:0.563066
# [457]	train-mlogloss:0.325282	test-mlogloss:0.563158
# [458]	train-mlogloss:0.324862	test-mlogloss:0.563243
# [459]	train-mlogloss:0.324455	test-mlogloss:0.563341
# [460]	train-mlogloss:0.324172	test-mlogloss:0.563332
# [461]	train-mlogloss:0.32374	test-mlogloss:0.563405
# [462]	train-mlogloss:0.323366	test-mlogloss:0.563425
# [463]	train-mlogloss:0.322989	test-mlogloss:0.563447
# [464]	train-mlogloss:0.322599	test-mlogloss:0.563447
# [465]	train-mlogloss:0.322368	test-mlogloss:0.563421
# [466]	train-mlogloss:0.322104	test-mlogloss:0.563497
# [467]	train-mlogloss:0.321805	test-mlogloss:0.563596
# [468]	train-mlogloss:0.321551	test-mlogloss:0.563588
# [469]	train-mlogloss:0.321176	test-mlogloss:0.563508
# [470]	train-mlogloss:0.320767	test-mlogloss:0.563574
# [471]	train-mlogloss:0.320386	test-mlogloss:0.563633
# [472]	train-mlogloss:0.320148	test-mlogloss:0.563763
# [473]	train-mlogloss:0.319808	test-mlogloss:0.563718
# [474]	train-mlogloss:0.319477	test-mlogloss:0.563789
# [475]	train-mlogloss:0.319142	test-mlogloss:0.563788
# [476]	train-mlogloss:0.318787	test-mlogloss:0.563934
# [477]	train-mlogloss:0.31845	test-mlogloss:0.563915
# [478]	train-mlogloss:0.318108	test-mlogloss:0.564003
# [479]	train-mlogloss:0.317691	test-mlogloss:0.564099
# [480]	train-mlogloss:0.317382	test-mlogloss:0.564234
# [481]	train-mlogloss:0.317081	test-mlogloss:0.564245
# [482]	train-mlogloss:0.316754	test-mlogloss:0.564225
# [483]	train-mlogloss:0.316487	test-mlogloss:0.564259
# [484]	train-mlogloss:0.316157	test-mlogloss:0.564301
# [485]	train-mlogloss:0.315777	test-mlogloss:0.564314
# [486]	train-mlogloss:0.315414	test-mlogloss:0.564336
# [487]	train-mlogloss:0.315105	test-mlogloss:0.564341
# [488]	train-mlogloss:0.314837	test-mlogloss:0.564335
# [489]	train-mlogloss:0.314428	test-mlogloss:0.564343
# [490]	train-mlogloss:0.314132	test-mlogloss:0.564387
# [491]	train-mlogloss:0.313864	test-mlogloss:0.56435
# [492]	train-mlogloss:0.313631	test-mlogloss:0.564369
# [493]	train-mlogloss:0.313237	test-mlogloss:0.564419
# [494]	train-mlogloss:0.312911	test-mlogloss:0.564477
# [495]	train-mlogloss:0.312587	test-mlogloss:0.564501
# [496]	train-mlogloss:0.312306	test-mlogloss:0.564565
# [497]	train-mlogloss:0.312031	test-mlogloss:0.564555
# [498]	train-mlogloss:0.311799	test-mlogloss:0.56465
# [499]	train-mlogloss:0.311363	test-mlogloss:0.564619
# [500]	train-mlogloss:0.311057	test-mlogloss:0.564662
# [501]	train-mlogloss:0.310801	test-mlogloss:0.56466
# [502]	train-mlogloss:0.310457	test-mlogloss:0.564676
# [503]	train-mlogloss:0.310128	test-mlogloss:0.564639
# [504]	train-mlogloss:0.309758	test-mlogloss:0.564616
# [505]	train-mlogloss:0.309552	test-mlogloss:0.564568
# [506]	train-mlogloss:0.309199	test-mlogloss:0.564607
# [507]	train-mlogloss:0.308921	test-mlogloss:0.564699
# [508]	train-mlogloss:0.308561	test-mlogloss:0.564643
# [509]	train-mlogloss:0.308191	test-mlogloss:0.564737
# [510]	train-mlogloss:0.307866	test-mlogloss:0.564647
# Stopping. Best iteration:
# [410]	train-mlogloss:0.342774	test-mlogloss:0.561933
#
# [0.5646470955728331]

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.009726033007084647,
#  'bedrooms': 0.03134854007125599,
#  'building_id': 0.0631680248986445,
#  'created_day': 0.04344977271796552,
#  'created_hour': 0.04060362832220812,
#  'created_month': 0.004402309676890945,
#  'display_address': 0.0681231827675171,
#  'latitude': 0.08544575944960892,
#  'listing_id': 0.09801793685245096,
#  'longitude': 0.07838158810762111,
#  'manager_id': 0.09347229616282403,
#  'num_description_words': 0.07682542282648758,
#  'num_features': 0.04471927597362709,
#  'num_photos': 0.0371636840165445,
#  'price': 0.09797698513452639,
#  'street_address': 0.0709693271632745,
#  'street_name': 0.05620623285146812}

# %%
#ananlysis by the feature importance by gain(totalgain)
gain = model.get_score(importance_type='gain')
for key in gain:
    gain[key] = gain[key]*1.0*weight[key]
#nomalization
total = sum(gain.values())
for key in gain:
    gain[key] = gain[key]/total
# Out:
# {'bathrooms': 0.01561773881543633,
#  'bedrooms': 0.06306273987282299,
#  'building_id': 0.08936735374733595,
#  'created_day': 0.02479431084778622,
#  'created_hour': 0.04818489496080039,
#  'created_month': 0.0022583931002279605,
#  'display_address': 0.04904422976286214,
#  'latitude': 0.08126442059297162,
#  'listing_id': 0.06747384894889424,
#  'longitude': 0.0737795193043773,
#  'manager_id': 0.07419525000016156,
#  'num_description_words': 0.05830242075268398,
#  'num_features': 0.042606638430017205,
#  'num_photos': 0.04099400630463816,
#  'price': 0.1786693356528965,
#  'street_address': 0.050279983782891294,
#  'street_name': 0.0401049151231962}

# %%
sorted_gain = []
for key in gain:
    sorted_gain.append((key,gain[key]))
sorted_gain = sorted(sorted_gain,key = lambda x:x[1])

# %%
sorted_gain
# Out:
# [('created_month', 0.0022583931002279605),
#  ('bathrooms', 0.01561773881543633),
#  ('created_day', 0.02479431084778622),
#  ('street_name', 0.0401049151231962),
#  ('num_photos', 0.04099400630463816),
#  ('num_features', 0.042606638430017205),
#  ('created_hour', 0.04818489496080039),
#  ('display_address', 0.04904422976286214),
#  ('street_address', 0.050279983782891294),
#  ('num_description_words', 0.05830242075268398),
#  ('bedrooms', 0.06306273987282299),
#  ('listing_id', 0.06747384894889424),
#  ('longitude', 0.0737795193043773),
#  ('manager_id', 0.07419525000016156),
#  ('latitude', 0.08126442059297162),
#  ('building_id', 0.08936735374733595),
#  ('price', 0.1786693356528965)]
