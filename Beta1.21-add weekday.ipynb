# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
import re
import string

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    #nth -> n
    #nst -> n
    #nrd -> n
    #nnd -> n
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    

    return street
    
def getStreetNumber(address):
    #get building id in the front, return -1 if their isn't
    pattern = re.compile('^([\d-]*)([\s]+)')
    try:
        number = pattern.search(address).group(1)
        return int(number)
    except:
        return -1

#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    return df1, df2

# %%
def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour
train_df["created_weekday"] = train_df["created"].dt.dayofweek
test_df["created_weekday"] = test_df["created"].dt.dayofweek

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words",\
                        "created_year","listing_id", "created_month", "created_day", "created_hour","created_weekday"])

# %%
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

train_df["street_number"] = train_df["street_address"].apply(getStreetNumber)
test_df["street_number"] = test_df["street_address"].apply(getStreetNumber)

#features_to_use.append("street_number")

# %%
#dealing feature with categorical features 
"""
display_address 8826    
building_id        7585   =》many zeros in this feature
manager_id   3481
street_address 15358 =》will be 3800 if no numbers in it 
"""
categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
#output the outcome - using xgboost
train_set, test_set =manager_skill_eval(train_df,test_df)

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=260)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point3addweekday.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')

# %%
#running and getting the cv from xgboost
cv_scores = []
#K-FOLD already defined.If not ,use
#KF=KFold(len(train_X),5,shuffle=True,random_state = 42)
for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #apply the function for createing some featues
        dev_set, val_set =manager_skill_eval(dev_set,val_set)
        #features_to_use.extend(['ManHigh','ManLow', 'ManMedium','manager_skill'])
        features_to_use.append('manager_skill')
        
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# [0]	train-mlogloss:1.03149	test-mlogloss:1.03406
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.977464	test-mlogloss:0.981437
# [2]	train-mlogloss:0.928978	test-mlogloss:0.935789
# [3]	train-mlogloss:0.886479	test-mlogloss:0.895325
# [4]	train-mlogloss:0.852527	test-mlogloss:0.86253
# [5]	train-mlogloss:0.821112	test-mlogloss:0.833139
# [6]	train-mlogloss:0.792769	test-mlogloss:0.806585
# [7]	train-mlogloss:0.76922	test-mlogloss:0.784254
# [8]	train-mlogloss:0.747695	test-mlogloss:0.764359
# [9]	train-mlogloss:0.727559	test-mlogloss:0.74585
# [10]	train-mlogloss:0.711745	test-mlogloss:0.731076
# [11]	train-mlogloss:0.695776	test-mlogloss:0.716449
# [12]	train-mlogloss:0.681773	test-mlogloss:0.703763
# [13]	train-mlogloss:0.668532	test-mlogloss:0.69177
# [14]	train-mlogloss:0.657036	test-mlogloss:0.68137
# [15]	train-mlogloss:0.646593	test-mlogloss:0.672
# [16]	train-mlogloss:0.637344	test-mlogloss:0.663774
# [17]	train-mlogloss:0.628903	test-mlogloss:0.656469
# [18]	train-mlogloss:0.621042	test-mlogloss:0.649806
# [19]	train-mlogloss:0.614219	test-mlogloss:0.644181
# [20]	train-mlogloss:0.608091	test-mlogloss:0.638903
# [21]	train-mlogloss:0.60193	test-mlogloss:0.633789
# [22]	train-mlogloss:0.596664	test-mlogloss:0.629518
# [23]	train-mlogloss:0.591428	test-mlogloss:0.625422
# [24]	train-mlogloss:0.586745	test-mlogloss:0.621833
# [25]	train-mlogloss:0.582339	test-mlogloss:0.618163
# [26]	train-mlogloss:0.578575	test-mlogloss:0.615195
# [27]	train-mlogloss:0.574662	test-mlogloss:0.612172
# [28]	train-mlogloss:0.571207	test-mlogloss:0.609597
# [29]	train-mlogloss:0.567859	test-mlogloss:0.606999
# [30]	train-mlogloss:0.564579	test-mlogloss:0.604515
# [31]	train-mlogloss:0.561728	test-mlogloss:0.602476
# [32]	train-mlogloss:0.558579	test-mlogloss:0.600145
# [33]	train-mlogloss:0.555744	test-mlogloss:0.598178
# [34]	train-mlogloss:0.553296	test-mlogloss:0.596383
# [35]	train-mlogloss:0.551178	test-mlogloss:0.594845
# [36]	train-mlogloss:0.549045	test-mlogloss:0.593469
# [37]	train-mlogloss:0.546947	test-mlogloss:0.592266
# [38]	train-mlogloss:0.545241	test-mlogloss:0.591389
# [39]	train-mlogloss:0.543448	test-mlogloss:0.590358
# [40]	train-mlogloss:0.541137	test-mlogloss:0.588872
# [41]	train-mlogloss:0.539346	test-mlogloss:0.587677
# [42]	train-mlogloss:0.537792	test-mlogloss:0.58694
# [43]	train-mlogloss:0.53587	test-mlogloss:0.585944
# [44]	train-mlogloss:0.53455	test-mlogloss:0.585292
# [45]	train-mlogloss:0.532512	test-mlogloss:0.584057
# [46]	train-mlogloss:0.530726	test-mlogloss:0.582953
# [47]	train-mlogloss:0.529121	test-mlogloss:0.582058
# [48]	train-mlogloss:0.527532	test-mlogloss:0.581417
# [49]	train-mlogloss:0.526177	test-mlogloss:0.580553
# [50]	train-mlogloss:0.524615	test-mlogloss:0.579798
# [51]	train-mlogloss:0.523551	test-mlogloss:0.579348
# [52]	train-mlogloss:0.522026	test-mlogloss:0.578662
# [53]	train-mlogloss:0.521033	test-mlogloss:0.578229
# [54]	train-mlogloss:0.519495	test-mlogloss:0.577721
# [55]	train-mlogloss:0.51791	test-mlogloss:0.57717
# [56]	train-mlogloss:0.516601	test-mlogloss:0.576572
# [57]	train-mlogloss:0.515083	test-mlogloss:0.576042
# [58]	train-mlogloss:0.513561	test-mlogloss:0.575285
# [59]	train-mlogloss:0.512319	test-mlogloss:0.574797
# [60]	train-mlogloss:0.511311	test-mlogloss:0.574338
# [61]	train-mlogloss:0.509827	test-mlogloss:0.573743
# [62]	train-mlogloss:0.508789	test-mlogloss:0.573166
# [63]	train-mlogloss:0.50768	test-mlogloss:0.572754
# [64]	train-mlogloss:0.506536	test-mlogloss:0.572315
# [65]	train-mlogloss:0.505442	test-mlogloss:0.571678
# [66]	train-mlogloss:0.504513	test-mlogloss:0.571585
# [67]	train-mlogloss:0.503609	test-mlogloss:0.571257
# [68]	train-mlogloss:0.502855	test-mlogloss:0.570931
# [69]	train-mlogloss:0.502164	test-mlogloss:0.570753
# [70]	train-mlogloss:0.501101	test-mlogloss:0.570417
# [71]	train-mlogloss:0.499831	test-mlogloss:0.569853
# [72]	train-mlogloss:0.498306	test-mlogloss:0.569083
# [73]	train-mlogloss:0.497052	test-mlogloss:0.568623
# [74]	train-mlogloss:0.495985	test-mlogloss:0.568182
# [75]	train-mlogloss:0.495121	test-mlogloss:0.568044
# [76]	train-mlogloss:0.494003	test-mlogloss:0.567664
# [77]	train-mlogloss:0.492895	test-mlogloss:0.567263
# [78]	train-mlogloss:0.491869	test-mlogloss:0.567062
# [79]	train-mlogloss:0.490783	test-mlogloss:0.566739
# [80]	train-mlogloss:0.489959	test-mlogloss:0.566343
# [81]	train-mlogloss:0.489245	test-mlogloss:0.566115
# [82]	train-mlogloss:0.488194	test-mlogloss:0.56577
# [83]	train-mlogloss:0.487147	test-mlogloss:0.565291
# [84]	train-mlogloss:0.486373	test-mlogloss:0.564949
# [85]	train-mlogloss:0.485238	test-mlogloss:0.56464
# [86]	train-mlogloss:0.484141	test-mlogloss:0.564431
# [87]	train-mlogloss:0.483179	test-mlogloss:0.564068
# [88]	train-mlogloss:0.482515	test-mlogloss:0.563953
# [89]	train-mlogloss:0.481342	test-mlogloss:0.563599
# [90]	train-mlogloss:0.480476	test-mlogloss:0.563424
# [91]	train-mlogloss:0.479507	test-mlogloss:0.56301
# [92]	train-mlogloss:0.478604	test-mlogloss:0.56272
# [93]	train-mlogloss:0.477465	test-mlogloss:0.562527
# [94]	train-mlogloss:0.476463	test-mlogloss:0.562404
# [95]	train-mlogloss:0.475542	test-mlogloss:0.561991
# [96]	train-mlogloss:0.474607	test-mlogloss:0.561781
# [97]	train-mlogloss:0.473778	test-mlogloss:0.561512
# [98]	train-mlogloss:0.4731	test-mlogloss:0.561433
# [99]	train-mlogloss:0.47229	test-mlogloss:0.56133
# [100]	train-mlogloss:0.471789	test-mlogloss:0.561317
# [101]	train-mlogloss:0.470903	test-mlogloss:0.561107
# [102]	train-mlogloss:0.470141	test-mlogloss:0.560962
# [103]	train-mlogloss:0.469374	test-mlogloss:0.560742
# [104]	train-mlogloss:0.468517	test-mlogloss:0.56043
# [105]	train-mlogloss:0.467692	test-mlogloss:0.560365
# [106]	train-mlogloss:0.466848	test-mlogloss:0.560175
# [107]	train-mlogloss:0.466092	test-mlogloss:0.560002
# [108]	train-mlogloss:0.46519	test-mlogloss:0.559567
# [109]	train-mlogloss:0.464475	test-mlogloss:0.559492
# [110]	train-mlogloss:0.463547	test-mlogloss:0.559321
# [111]	train-mlogloss:0.462775	test-mlogloss:0.559171
# [112]	train-mlogloss:0.462084	test-mlogloss:0.559076
# [113]	train-mlogloss:0.461326	test-mlogloss:0.558736
# [114]	train-mlogloss:0.460475	test-mlogloss:0.558513
# [115]	train-mlogloss:0.459688	test-mlogloss:0.558379
# [116]	train-mlogloss:0.459073	test-mlogloss:0.55829
# [117]	train-mlogloss:0.458374	test-mlogloss:0.558153
# [118]	train-mlogloss:0.457804	test-mlogloss:0.558164
# [119]	train-mlogloss:0.457225	test-mlogloss:0.558052
# [120]	train-mlogloss:0.456266	test-mlogloss:0.557818
# [121]	train-mlogloss:0.455541	test-mlogloss:0.55763
# [122]	train-mlogloss:0.454708	test-mlogloss:0.557456
# [123]	train-mlogloss:0.453925	test-mlogloss:0.557367
# [124]	train-mlogloss:0.453184	test-mlogloss:0.557333
# [125]	train-mlogloss:0.452503	test-mlogloss:0.557057
# [126]	train-mlogloss:0.451896	test-mlogloss:0.557066
# [127]	train-mlogloss:0.451247	test-mlogloss:0.55685
# [128]	train-mlogloss:0.450506	test-mlogloss:0.556729
# [129]	train-mlogloss:0.449877	test-mlogloss:0.556669
# [130]	train-mlogloss:0.449121	test-mlogloss:0.556483
# [131]	train-mlogloss:0.448261	test-mlogloss:0.556275
# [132]	train-mlogloss:0.44768	test-mlogloss:0.556185
# [133]	train-mlogloss:0.447012	test-mlogloss:0.556193
# [134]	train-mlogloss:0.446258	test-mlogloss:0.556083
# [135]	train-mlogloss:0.445637	test-mlogloss:0.556093
# [136]	train-mlogloss:0.44504	test-mlogloss:0.556076
# [137]	train-mlogloss:0.444201	test-mlogloss:0.555857
# [138]	train-mlogloss:0.443595	test-mlogloss:0.555775
# [139]	train-mlogloss:0.442965	test-mlogloss:0.555622
# [140]	train-mlogloss:0.442506	test-mlogloss:0.555609
# [141]	train-mlogloss:0.441768	test-mlogloss:0.555452
# [142]	train-mlogloss:0.441133	test-mlogloss:0.555278
# [143]	train-mlogloss:0.440627	test-mlogloss:0.555214
# [144]	train-mlogloss:0.440055	test-mlogloss:0.555112
# [145]	train-mlogloss:0.43935	test-mlogloss:0.554976
# [146]	train-mlogloss:0.438549	test-mlogloss:0.554872
# [147]	train-mlogloss:0.437816	test-mlogloss:0.554837
# [148]	train-mlogloss:0.437117	test-mlogloss:0.554802
# [149]	train-mlogloss:0.43624	test-mlogloss:0.554644
# [150]	train-mlogloss:0.435611	test-mlogloss:0.554612
# [151]	train-mlogloss:0.434851	test-mlogloss:0.55456
# [152]	train-mlogloss:0.434122	test-mlogloss:0.554531
# [153]	train-mlogloss:0.433591	test-mlogloss:0.554499
# [154]	train-mlogloss:0.432991	test-mlogloss:0.554311
# [155]	train-mlogloss:0.432447	test-mlogloss:0.554197
# [156]	train-mlogloss:0.43194	test-mlogloss:0.554098
# [157]	train-mlogloss:0.431388	test-mlogloss:0.553909
# [158]	train-mlogloss:0.430798	test-mlogloss:0.553868
# [159]	train-mlogloss:0.430302	test-mlogloss:0.553934
# [160]	train-mlogloss:0.429629	test-mlogloss:0.553832
# [161]	train-mlogloss:0.428762	test-mlogloss:0.553542
# [162]	train-mlogloss:0.428032	test-mlogloss:0.55344
# [163]	train-mlogloss:0.42743	test-mlogloss:0.553326
# [164]	train-mlogloss:0.426544	test-mlogloss:0.55324
# [165]	train-mlogloss:0.42582	test-mlogloss:0.553194
# [166]	train-mlogloss:0.425313	test-mlogloss:0.553289
# [167]	train-mlogloss:0.424682	test-mlogloss:0.553237
# [168]	train-mlogloss:0.424092	test-mlogloss:0.553045
# [169]	train-mlogloss:0.42334	test-mlogloss:0.552922
# [170]	train-mlogloss:0.423035	test-mlogloss:0.552899
# [171]	train-mlogloss:0.422442	test-mlogloss:0.552733
# [172]	train-mlogloss:0.421696	test-mlogloss:0.55267
# [173]	train-mlogloss:0.420946	test-mlogloss:0.552592
# [174]	train-mlogloss:0.420436	test-mlogloss:0.55256
# [175]	train-mlogloss:0.419728	test-mlogloss:0.552603
# [176]	train-mlogloss:0.419048	test-mlogloss:0.552559
# [177]	train-mlogloss:0.418465	test-mlogloss:0.552526
# [178]	train-mlogloss:0.417713	test-mlogloss:0.552465
# [179]	train-mlogloss:0.417406	test-mlogloss:0.552505
# [180]	train-mlogloss:0.416594	test-mlogloss:0.552429
# [181]	train-mlogloss:0.415909	test-mlogloss:0.552323
# [182]	train-mlogloss:0.41524	test-mlogloss:0.552354
# [183]	train-mlogloss:0.414608	test-mlogloss:0.552404
# [184]	train-mlogloss:0.413895	test-mlogloss:0.552286
# [185]	train-mlogloss:0.413453	test-mlogloss:0.552179
# [186]	train-mlogloss:0.412919	test-mlogloss:0.552145
# [187]	train-mlogloss:0.412321	test-mlogloss:0.552231
# [188]	train-mlogloss:0.411902	test-mlogloss:0.552206
# [189]	train-mlogloss:0.411319	test-mlogloss:0.552144
# [190]	train-mlogloss:0.410634	test-mlogloss:0.552072
# [191]	train-mlogloss:0.410106	test-mlogloss:0.552061
# [192]	train-mlogloss:0.409593	test-mlogloss:0.552001
# [193]	train-mlogloss:0.409194	test-mlogloss:0.552
# [194]	train-mlogloss:0.408556	test-mlogloss:0.551992
# [195]	train-mlogloss:0.407963	test-mlogloss:0.551848
# [196]	train-mlogloss:0.407401	test-mlogloss:0.551889
# [197]	train-mlogloss:0.407071	test-mlogloss:0.551939
# [198]	train-mlogloss:0.40645	test-mlogloss:0.551903
# [199]	train-mlogloss:0.405998	test-mlogloss:0.551831
# [200]	train-mlogloss:0.405446	test-mlogloss:0.551972
# [201]	train-mlogloss:0.405039	test-mlogloss:0.551959
# [202]	train-mlogloss:0.404401	test-mlogloss:0.551822
# [203]	train-mlogloss:0.403873	test-mlogloss:0.551725
# [204]	train-mlogloss:0.403316	test-mlogloss:0.551691
# [205]	train-mlogloss:0.402906	test-mlogloss:0.551703
# [206]	train-mlogloss:0.402142	test-mlogloss:0.551771
# [207]	train-mlogloss:0.401571	test-mlogloss:0.551706
# [208]	train-mlogloss:0.400987	test-mlogloss:0.551741
# [209]	train-mlogloss:0.40042	test-mlogloss:0.551693
# [210]	train-mlogloss:0.399869	test-mlogloss:0.551668
# [211]	train-mlogloss:0.399168	test-mlogloss:0.551717
# [212]	train-mlogloss:0.398491	test-mlogloss:0.551736
# [213]	train-mlogloss:0.397975	test-mlogloss:0.551692
# [214]	train-mlogloss:0.39732	test-mlogloss:0.551663
# [215]	train-mlogloss:0.396904	test-mlogloss:0.551717
# [216]	train-mlogloss:0.39642	test-mlogloss:0.551633
# [217]	train-mlogloss:0.395822	test-mlogloss:0.551665
# [218]	train-mlogloss:0.395161	test-mlogloss:0.551798
# [219]	train-mlogloss:0.394594	test-mlogloss:0.55176
# [220]	train-mlogloss:0.394085	test-mlogloss:0.551813
# [221]	train-mlogloss:0.393616	test-mlogloss:0.551799
# [222]	train-mlogloss:0.393171	test-mlogloss:0.551703
# [223]	train-mlogloss:0.392478	test-mlogloss:0.551774
# [224]	train-mlogloss:0.391934	test-mlogloss:0.551722
# [225]	train-mlogloss:0.391578	test-mlogloss:0.551789
# [226]	train-mlogloss:0.391076	test-mlogloss:0.551763
# [227]	train-mlogloss:0.390488	test-mlogloss:0.551558
# [228]	train-mlogloss:0.389873	test-mlogloss:0.551435
# [229]	train-mlogloss:0.389184	test-mlogloss:0.551327
# [230]	train-mlogloss:0.388594	test-mlogloss:0.551268
# [231]	train-mlogloss:0.38799	test-mlogloss:0.551129
# [232]	train-mlogloss:0.387417	test-mlogloss:0.551041
# [233]	train-mlogloss:0.38687	test-mlogloss:0.551086
# [234]	train-mlogloss:0.386325	test-mlogloss:0.551043
# [235]	train-mlogloss:0.385684	test-mlogloss:0.551154
# [236]	train-mlogloss:0.385115	test-mlogloss:0.551035
# [237]	train-mlogloss:0.384521	test-mlogloss:0.551023
# [238]	train-mlogloss:0.384072	test-mlogloss:0.551102
# [239]	train-mlogloss:0.383418	test-mlogloss:0.551046
# [240]	train-mlogloss:0.382957	test-mlogloss:0.55092
# [241]	train-mlogloss:0.38248	test-mlogloss:0.550833
# [242]	train-mlogloss:0.382131	test-mlogloss:0.550776
# [243]	train-mlogloss:0.381713	test-mlogloss:0.550751
# [244]	train-mlogloss:0.381068	test-mlogloss:0.550656
# [245]	train-mlogloss:0.380588	test-mlogloss:0.550692
# [246]	train-mlogloss:0.379956	test-mlogloss:0.550641
# [247]	train-mlogloss:0.379607	test-mlogloss:0.550728
# [248]	train-mlogloss:0.379089	test-mlogloss:0.550786
# [249]	train-mlogloss:0.378444	test-mlogloss:0.550727
# [250]	train-mlogloss:0.377876	test-mlogloss:0.550643
# [251]	train-mlogloss:0.377464	test-mlogloss:0.550728
# [252]	train-mlogloss:0.376949	test-mlogloss:0.550728
# [253]	train-mlogloss:0.376262	test-mlogloss:0.55069
# [254]	train-mlogloss:0.375767	test-mlogloss:0.550637
# [255]	train-mlogloss:0.375122	test-mlogloss:0.550715
# [256]	train-mlogloss:0.374633	test-mlogloss:0.550589
# [257]	train-mlogloss:0.374143	test-mlogloss:0.55063
# [258]	train-mlogloss:0.373522	test-mlogloss:0.55048
# [259]	train-mlogloss:0.373066	test-mlogloss:0.550526
# [260]	train-mlogloss:0.37252	test-mlogloss:0.550482
# [261]	train-mlogloss:0.371876	test-mlogloss:0.550583
# [262]	train-mlogloss:0.371523	test-mlogloss:0.550531
# [263]	train-mlogloss:0.371019	test-mlogloss:0.550556
# [264]	train-mlogloss:0.370446	test-mlogloss:0.550639
# [265]	train-mlogloss:0.369915	test-mlogloss:0.550581
# [266]	train-mlogloss:0.369435	test-mlogloss:0.550595
# [267]	train-mlogloss:0.369004	test-mlogloss:0.550573
# [268]	train-mlogloss:0.368578	test-mlogloss:0.550577
# [269]	train-mlogloss:0.368055	test-mlogloss:0.550546
# [270]	train-mlogloss:0.367574	test-mlogloss:0.55064
# [271]	train-mlogloss:0.367037	test-mlogloss:0.550654
# [272]	train-mlogloss:0.366371	test-mlogloss:0.550698
# [273]	train-mlogloss:0.365831	test-mlogloss:0.550639
# [274]	train-mlogloss:0.365396	test-mlogloss:0.550623
# [275]	train-mlogloss:0.364937	test-mlogloss:0.550678
# [276]	train-mlogloss:0.364465	test-mlogloss:0.550705
# [277]	train-mlogloss:0.363943	test-mlogloss:0.550675
# [278]	train-mlogloss:0.36351	test-mlogloss:0.550665
# [279]	train-mlogloss:0.362953	test-mlogloss:0.550584
# [280]	train-mlogloss:0.362506	test-mlogloss:0.550579
# [281]	train-mlogloss:0.362141	test-mlogloss:0.550592
# [282]	train-mlogloss:0.361647	test-mlogloss:0.550539
# [283]	train-mlogloss:0.361166	test-mlogloss:0.550547
# [284]	train-mlogloss:0.36085	test-mlogloss:0.55058
# [285]	train-mlogloss:0.360295	test-mlogloss:0.550678
# [286]	train-mlogloss:0.359874	test-mlogloss:0.550752
# [287]	train-mlogloss:0.359264	test-mlogloss:0.550736
# [288]	train-mlogloss:0.358754	test-mlogloss:0.550831
# [289]	train-mlogloss:0.358413	test-mlogloss:0.550786
# [290]	train-mlogloss:0.357987	test-mlogloss:0.550785
# [291]	train-mlogloss:0.357751	test-mlogloss:0.550681
# [292]	train-mlogloss:0.357424	test-mlogloss:0.550675
# [293]	train-mlogloss:0.356985	test-mlogloss:0.550687
# [294]	train-mlogloss:0.356489	test-mlogloss:0.550645
# [295]	train-mlogloss:0.356118	test-mlogloss:0.550593
# [296]	train-mlogloss:0.355621	test-mlogloss:0.550617
# [297]	train-mlogloss:0.355135	test-mlogloss:0.550699
# [298]	train-mlogloss:0.354653	test-mlogloss:0.550748
# [299]	train-mlogloss:0.35416	test-mlogloss:0.55056
# [300]	train-mlogloss:0.35365	test-mlogloss:0.550569
# [301]	train-mlogloss:0.353242	test-mlogloss:0.550742
# [302]	train-mlogloss:0.352739	test-mlogloss:0.550742
# [303]	train-mlogloss:0.352296	test-mlogloss:0.550777
# [304]	train-mlogloss:0.351895	test-mlogloss:0.550765
# [305]	train-mlogloss:0.351465	test-mlogloss:0.550692
# [306]	train-mlogloss:0.350866	test-mlogloss:0.550696
# [307]	train-mlogloss:0.350327	test-mlogloss:0.550763
# [308]	train-mlogloss:0.349918	test-mlogloss:0.550821
# [309]	train-mlogloss:0.349607	test-mlogloss:0.550959
# [310]	train-mlogloss:0.349291	test-mlogloss:0.550914
# [311]	train-mlogloss:0.348816	test-mlogloss:0.550882
# [312]	train-mlogloss:0.348463	test-mlogloss:0.550876
# [313]	train-mlogloss:0.348059	test-mlogloss:0.550913
# [314]	train-mlogloss:0.347512	test-mlogloss:0.550875
# [315]	train-mlogloss:0.347099	test-mlogloss:0.55088
# [316]	train-mlogloss:0.346583	test-mlogloss:0.550869
# [317]	train-mlogloss:0.346189	test-mlogloss:0.550852
# [318]	train-mlogloss:0.345767	test-mlogloss:0.55093
# [319]	train-mlogloss:0.345333	test-mlogloss:0.550898
# [320]	train-mlogloss:0.344827	test-mlogloss:0.550865
# [321]	train-mlogloss:0.344393	test-mlogloss:0.550903
# [322]	train-mlogloss:0.343851	test-mlogloss:0.550871
# [323]	train-mlogloss:0.343561	test-mlogloss:0.550882
# [324]	train-mlogloss:0.34304	test-mlogloss:0.550971
# [325]	train-mlogloss:0.342583	test-mlogloss:0.550993
# [326]	train-mlogloss:0.342198	test-mlogloss:0.551016
# [327]	train-mlogloss:0.34181	test-mlogloss:0.551033
# [328]	train-mlogloss:0.341427	test-mlogloss:0.551072
# [329]	train-mlogloss:0.340942	test-mlogloss:0.551033
# [330]	train-mlogloss:0.340557	test-mlogloss:0.551052
# [331]	train-mlogloss:0.340094	test-mlogloss:0.551069
# [332]	train-mlogloss:0.339587	test-mlogloss:0.550953
# [333]	train-mlogloss:0.339172	test-mlogloss:0.551048
# [334]	train-mlogloss:0.338773	test-mlogloss:0.551094
# [335]	train-mlogloss:0.338339	test-mlogloss:0.551106
# [336]	train-mlogloss:0.337981	test-mlogloss:0.551189
# [337]	train-mlogloss:0.337671	test-mlogloss:0.551187
# [338]	train-mlogloss:0.337208	test-mlogloss:0.551176
# [339]	train-mlogloss:0.33669	test-mlogloss:0.551146
# [340]	train-mlogloss:0.336366	test-mlogloss:0.551207
# [341]	train-mlogloss:0.336036	test-mlogloss:0.551197
# [342]	train-mlogloss:0.335515	test-mlogloss:0.551291
# [343]	train-mlogloss:0.335136	test-mlogloss:0.55138
# [344]	train-mlogloss:0.334778	test-mlogloss:0.55136
# [345]	train-mlogloss:0.334322	test-mlogloss:0.551345
# [346]	train-mlogloss:0.333809	test-mlogloss:0.551441
# [347]	train-mlogloss:0.333487	test-mlogloss:0.551473
# [348]	train-mlogloss:0.333198	test-mlogloss:0.551411
# [349]	train-mlogloss:0.332798	test-mlogloss:0.551482
# [350]	train-mlogloss:0.332347	test-mlogloss:0.551497
# [351]	train-mlogloss:0.332052	test-mlogloss:0.55153
# [352]	train-mlogloss:0.33166	test-mlogloss:0.55154
# [353]	train-mlogloss:0.331214	test-mlogloss:0.55152
# [354]	train-mlogloss:0.330705	test-mlogloss:0.551468
# [355]	train-mlogloss:0.330284	test-mlogloss:0.551377
# [356]	train-mlogloss:0.329892	test-mlogloss:0.551275
# [357]	train-mlogloss:0.329525	test-mlogloss:0.551315
# [358]	train-mlogloss:0.329067	test-mlogloss:0.551324
# Stopping. Best iteration:
# [258]	train-mlogloss:0.373522	test-mlogloss:0.55048
#
# [0.55132449263964389]

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
