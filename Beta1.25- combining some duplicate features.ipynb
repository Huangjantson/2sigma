# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
import re
import string
from collections import defaultdict, Counter

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    
    return street
    
#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column,minimum_size=5):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    return df1, df2

def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

#encoded by sorted value
def hcc_sorting(train_df,test_df,feature,label=None,randomize=None):
    """
    sort the hcc feature by their prior on label then encode
    the train df should be with its labels get dummied
    
    return the list of all the possible features in order
    """
    if label ==None:
        train_df['tempScore'] = 2*train_df['high']+train_df['medium']
    
    label = 'tempScore'
    #get dummies for the 
    grouped  = train_df.groupby(feature)[label].agg({'size':'size','mean':'mean'})
    #unrankedMean = grouped.ix[grouped['size']<unrank_threshold,'mean'].mean()
    #grouped.ix[grouped['size']<unrank_threshold,'mean'] = unrankedMean
    grouped = grouped.reset_index()

    #get the values for the test set
    test_groupBy=test_df[feature].value_counts().to_frame().reset_index()
    test_groupBy.columns = [feature,'testSize']

    #merge together and reset the mean
    totalFeature = grouped.merge(test_groupBy,on = feature, how='outer').fillna(0)

    rankedMean = np.mean(grouped['mean'])

    #reset those train size 0 to the ranked mean
    totalFeature.ix[totalFeature['size']==0,'mean']=rankedMean
    
    #add some random 
    if randomize : 
        totalFeature['mean'] *= np.random.uniform(1 - randomize, 1 + randomize, len(totalFeature))

    return list(totalFeature.sort('mean')[feature])

# %%
#functions for features
def featureList(train_df,test_df,limit = 0.01):
    #acquiring the feature lists
    features_in_train = train_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    features_in_train.sort(ascending  = False)
    features_in_test = test_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    features_in_test.sort(ascending  = False)
    
    filtered_features_in_train = features_in_train[features_in_train > limit*len(train_df)]
    filtered_features_in_test = features_in_test[features_in_test > limit*len(test_df)]
    accept_list = set(filtered_features_in_train.index).union(set(filtered_features_in_test.index))
    return accept_list

def featureMapping(train_df,test_df,feature_list):
    for feature in feature_list:
        #add the feature column for both
        #if feature in the row, then set the value for (row,feature) to 1
        train_df['with_'+feature]=train_df['features'].apply(lambda x : 1 if feature in x else 0)
        test_df['with_'+feature]=test_df['features'].apply(lambda x : 1 if feature in x else 0)
    return

def clean(s):
    x = s.replace("-", "")
    x = x.replace(" ", "")
    x = x.replace("twenty four hour", "24")
    x = x.replace("24/7", "24")
    x = x.replace("24hr", "24")
    x = x.replace("24-hour", "24")
    x = x.replace("24hour", "24")
    x = x.replace("24 hour", "24")
    
    x = x.replace("common", "cm")
    x = x.replace("concierge", "doorman")
    x = x.replace("bicycle", "bike")
    x = x.replace("private", "pv")
    x = x.replace("deco", "dc")
    x = x.replace("decorative", "dc")
    x = x.replace("onsite", "os")
    x = x.replace("outdoor", "od")
    x = x.replace("ss appliances", "stainless")
    
    x = x.replace("high_",'hi')
    x = x.replace("high",'hi')
    x = x.replace("hi_",'hi')
   
    x = x.replace("live","lv")
    x = x.replace("pre_","pre")
    x = x.replace("all","al")
    x = x.replace("flex","fl")
    x = x.replace("residents","rs")
    x = x.replace("close","cl")
    x = x.replace("duplex","dp")
    x = x.replace("share","sh")
    x = x.replace("newly","new")
    x = x.replace("on_site","os")
    
    x = x.replace("24_hour","24")
    x = x.replace("full_time","24")


    return x

def feature_hash(x):
    cleaned = clean(x, uniq)
    key = cleaned[:4].strip()
    return key

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
"""
new categorical data append and converting label dummies for future use
"""
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

train_df =train_df.join(pd.get_dummies(train_df[u'interest_level']).astype(int))

# %%
#dealing with features

#preprocessing for features
train_df["features"] = train_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_') \
                                                            for i in x])
test_df["features"] = test_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_')\
                                                          for i in x])

preaccept_list = list(featureList(train_df,test_df,limit = 0.0001))

key2original = defaultdict(list)
origin2key =  {}
k = 4
for f in preaccept_list:
    cleaned = clean(f)
    key = cleaned[:k].strip()
    key2original[key].append(f)
    origin2key[f] = key

#combine some of the features
train_df["features"] = train_df["features"].apply(lambda x : [origin2key[i] if i in origin2key else i for i in x ])
test_df["features"] = test_df["features"].apply(lambda x : [origin2key[i] if i in origin2key else i for i in x ])

#create the accept list
accept_list = list(featureList(train_df,test_df,limit = 0.05))

#map the feature to dummy slots
featureMapping(train_df,test_df,accept_list)
features_to_use.extend(map(lambda x : 'with_'+x,accept_list))
# Out:
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
features_to_use.append('manager_skill')
categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
features_to_use.extend(categorical)
cv_scores = []

mini_ranking = 5

for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #special feature engineering for the trainset
        
        
#====================================================================        
        """feature engineerings for the categorical features"""
        
        dev_set, val_set =manager_skill_eval(dev_set,val_set,\
        unrank_threshold = mini_ranking)
        
        
        #fill substitute the small size values by their mean
        for f in categorical:
            dev_set,val_set  = singleValueConvert(dev_set,val_set,f,mini_ranking)
        
            if dev_set[f].dtype=='object':
                #print(f)
                lbl = preprocessing.LabelEncoder()
                lbl.fit(hcc_sorting(dev_set,val_set,f,randomize = 0.05))
                dev_set[f] = lbl.transform(list(dev_set[f].values))
                val_set[f] = lbl.transform(list(val_set[f].values))
                
#===================================================================
                
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        break
print cv_scores
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:123: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# [0]	train-mlogloss:1.03474	test-mlogloss:1.03697
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.978176	test-mlogloss:0.983631
# [2]	train-mlogloss:0.928243	test-mlogloss:0.936457
# [3]	train-mlogloss:0.887767	test-mlogloss:0.897732
# [4]	train-mlogloss:0.852994	test-mlogloss:0.86467
# [5]	train-mlogloss:0.81932	test-mlogloss:0.833134
# [6]	train-mlogloss:0.790797	test-mlogloss:0.806268
# [7]	train-mlogloss:0.765371	test-mlogloss:0.782569
# [8]	train-mlogloss:0.742752	test-mlogloss:0.761434
# [9]	train-mlogloss:0.723071	test-mlogloss:0.743145
# [10]	train-mlogloss:0.7054	test-mlogloss:0.727129
# [11]	train-mlogloss:0.68977	test-mlogloss:0.712671
# [12]	train-mlogloss:0.6746	test-mlogloss:0.699203
# [13]	train-mlogloss:0.660928	test-mlogloss:0.687289
# [14]	train-mlogloss:0.648821	test-mlogloss:0.676808
# [15]	train-mlogloss:0.637933	test-mlogloss:0.667692
# [16]	train-mlogloss:0.628807	test-mlogloss:0.659431
# [17]	train-mlogloss:0.61975	test-mlogloss:0.651893
# [18]	train-mlogloss:0.612301	test-mlogloss:0.645435
# [19]	train-mlogloss:0.604798	test-mlogloss:0.639392
# [20]	train-mlogloss:0.598141	test-mlogloss:0.633838
# [21]	train-mlogloss:0.592002	test-mlogloss:0.628985
# [22]	train-mlogloss:0.586136	test-mlogloss:0.624442
# [23]	train-mlogloss:0.580925	test-mlogloss:0.620328
# [24]	train-mlogloss:0.576116	test-mlogloss:0.616457
# [25]	train-mlogloss:0.571938	test-mlogloss:0.613227
# [26]	train-mlogloss:0.567609	test-mlogloss:0.610147
# [27]	train-mlogloss:0.563826	test-mlogloss:0.607386
# [28]	train-mlogloss:0.560755	test-mlogloss:0.605051
# [29]	train-mlogloss:0.557264	test-mlogloss:0.602425
# [30]	train-mlogloss:0.554036	test-mlogloss:0.599919
# [31]	train-mlogloss:0.550554	test-mlogloss:0.597578
# [32]	train-mlogloss:0.547732	test-mlogloss:0.595997
# [33]	train-mlogloss:0.544628	test-mlogloss:0.594042
# [34]	train-mlogloss:0.542008	test-mlogloss:0.592104
# [35]	train-mlogloss:0.539427	test-mlogloss:0.5903
# [36]	train-mlogloss:0.537014	test-mlogloss:0.588664
# [37]	train-mlogloss:0.534813	test-mlogloss:0.587508
# [38]	train-mlogloss:0.532346	test-mlogloss:0.585626
# [39]	train-mlogloss:0.530489	test-mlogloss:0.584552
# [40]	train-mlogloss:0.528149	test-mlogloss:0.583035
# [41]	train-mlogloss:0.526072	test-mlogloss:0.581864
# [42]	train-mlogloss:0.523931	test-mlogloss:0.580544
# [43]	train-mlogloss:0.522286	test-mlogloss:0.579671
# [44]	train-mlogloss:0.520409	test-mlogloss:0.578518
# [45]	train-mlogloss:0.518881	test-mlogloss:0.577784
# [46]	train-mlogloss:0.51734	test-mlogloss:0.576907
# [47]	train-mlogloss:0.515971	test-mlogloss:0.576261
# [48]	train-mlogloss:0.51465	test-mlogloss:0.575753
# [49]	train-mlogloss:0.512931	test-mlogloss:0.574718
# [50]	train-mlogloss:0.511511	test-mlogloss:0.573864
# [51]	train-mlogloss:0.510072	test-mlogloss:0.573188
# [52]	train-mlogloss:0.50891	test-mlogloss:0.572868
# [53]	train-mlogloss:0.50769	test-mlogloss:0.57256
# [54]	train-mlogloss:0.506522	test-mlogloss:0.572293
# [55]	train-mlogloss:0.505096	test-mlogloss:0.571708
# [56]	train-mlogloss:0.503508	test-mlogloss:0.570985
# [57]	train-mlogloss:0.502316	test-mlogloss:0.570609
# [58]	train-mlogloss:0.501227	test-mlogloss:0.570239
# [59]	train-mlogloss:0.500171	test-mlogloss:0.56986
# [60]	train-mlogloss:0.499176	test-mlogloss:0.569735
# [61]	train-mlogloss:0.497701	test-mlogloss:0.569235
# [62]	train-mlogloss:0.49658	test-mlogloss:0.569008
# [63]	train-mlogloss:0.495451	test-mlogloss:0.568566
# [64]	train-mlogloss:0.494682	test-mlogloss:0.568318
# [65]	train-mlogloss:0.493663	test-mlogloss:0.567968
# [66]	train-mlogloss:0.492451	test-mlogloss:0.567567
# [67]	train-mlogloss:0.491613	test-mlogloss:0.567406
# [68]	train-mlogloss:0.490782	test-mlogloss:0.56717
# [69]	train-mlogloss:0.489856	test-mlogloss:0.56697
# [70]	train-mlogloss:0.488639	test-mlogloss:0.56659
# [71]	train-mlogloss:0.487731	test-mlogloss:0.566403
# [72]	train-mlogloss:0.486767	test-mlogloss:0.566334
# [73]	train-mlogloss:0.485745	test-mlogloss:0.566172
# [74]	train-mlogloss:0.484386	test-mlogloss:0.565662
# [75]	train-mlogloss:0.483378	test-mlogloss:0.565572
# [76]	train-mlogloss:0.482558	test-mlogloss:0.565452
# [77]	train-mlogloss:0.481398	test-mlogloss:0.564952
# [78]	train-mlogloss:0.480399	test-mlogloss:0.564543
# [79]	train-mlogloss:0.479588	test-mlogloss:0.564367
# [80]	train-mlogloss:0.479038	test-mlogloss:0.564372
# [81]	train-mlogloss:0.478385	test-mlogloss:0.564279
# [82]	train-mlogloss:0.477328	test-mlogloss:0.56387
# [83]	train-mlogloss:0.476097	test-mlogloss:0.56352
# [84]	train-mlogloss:0.47505	test-mlogloss:0.56314
# [85]	train-mlogloss:0.474194	test-mlogloss:0.562867
# [86]	train-mlogloss:0.473377	test-mlogloss:0.562671
# [87]	train-mlogloss:0.47271	test-mlogloss:0.562585
# [88]	train-mlogloss:0.471857	test-mlogloss:0.562345
# [89]	train-mlogloss:0.471018	test-mlogloss:0.56223
# [90]	train-mlogloss:0.470037	test-mlogloss:0.562219
# [91]	train-mlogloss:0.468986	test-mlogloss:0.561896
# [92]	train-mlogloss:0.46842	test-mlogloss:0.561736
# [93]	train-mlogloss:0.467312	test-mlogloss:0.561291
# [94]	train-mlogloss:0.466303	test-mlogloss:0.561015
# [95]	train-mlogloss:0.465574	test-mlogloss:0.560793
# [96]	train-mlogloss:0.464399	test-mlogloss:0.560474
# [97]	train-mlogloss:0.463461	test-mlogloss:0.560282
# [98]	train-mlogloss:0.462921	test-mlogloss:0.560221
# [99]	train-mlogloss:0.462064	test-mlogloss:0.560076
# [100]	train-mlogloss:0.4611	test-mlogloss:0.559853
# [101]	train-mlogloss:0.460109	test-mlogloss:0.559585
# [102]	train-mlogloss:0.458933	test-mlogloss:0.559344
# [103]	train-mlogloss:0.458248	test-mlogloss:0.559195
# [104]	train-mlogloss:0.457425	test-mlogloss:0.559008
# [105]	train-mlogloss:0.456565	test-mlogloss:0.558818
# [106]	train-mlogloss:0.455926	test-mlogloss:0.558779
# [107]	train-mlogloss:0.454911	test-mlogloss:0.558461
# [108]	train-mlogloss:0.454051	test-mlogloss:0.558255
# [109]	train-mlogloss:0.453031	test-mlogloss:0.558113
# [110]	train-mlogloss:0.452188	test-mlogloss:0.557862
# [111]	train-mlogloss:0.451256	test-mlogloss:0.557505
# [112]	train-mlogloss:0.450796	test-mlogloss:0.557484
# [113]	train-mlogloss:0.449985	test-mlogloss:0.557449
# [114]	train-mlogloss:0.449202	test-mlogloss:0.55735
# [115]	train-mlogloss:0.448348	test-mlogloss:0.557161
# [116]	train-mlogloss:0.447674	test-mlogloss:0.557067
# [117]	train-mlogloss:0.446867	test-mlogloss:0.557013
# [118]	train-mlogloss:0.446297	test-mlogloss:0.556917
# [119]	train-mlogloss:0.445607	test-mlogloss:0.556958
# [120]	train-mlogloss:0.445017	test-mlogloss:0.556879
# [121]	train-mlogloss:0.444155	test-mlogloss:0.55663
# [122]	train-mlogloss:0.443561	test-mlogloss:0.556836
# [123]	train-mlogloss:0.442797	test-mlogloss:0.556623
# [124]	train-mlogloss:0.442122	test-mlogloss:0.556494
# [125]	train-mlogloss:0.441452	test-mlogloss:0.556315
# [126]	train-mlogloss:0.440639	test-mlogloss:0.55619
# [127]	train-mlogloss:0.439832	test-mlogloss:0.555995
# [128]	train-mlogloss:0.439167	test-mlogloss:0.555836
# [129]	train-mlogloss:0.438365	test-mlogloss:0.555745
# [130]	train-mlogloss:0.437649	test-mlogloss:0.55574
# [131]	train-mlogloss:0.436815	test-mlogloss:0.555617
# [132]	train-mlogloss:0.436176	test-mlogloss:0.555513
# [133]	train-mlogloss:0.435375	test-mlogloss:0.555271
# [134]	train-mlogloss:0.434798	test-mlogloss:0.555191
# [135]	train-mlogloss:0.434237	test-mlogloss:0.555112
# [136]	train-mlogloss:0.433742	test-mlogloss:0.555322
# [137]	train-mlogloss:0.432993	test-mlogloss:0.555082
# [138]	train-mlogloss:0.432049	test-mlogloss:0.554872
# [139]	train-mlogloss:0.431154	test-mlogloss:0.554682
# [140]	train-mlogloss:0.430427	test-mlogloss:0.554629
# [141]	train-mlogloss:0.429787	test-mlogloss:0.554573
# [142]	train-mlogloss:0.429147	test-mlogloss:0.554457
# [143]	train-mlogloss:0.428382	test-mlogloss:0.554136
# [144]	train-mlogloss:0.427708	test-mlogloss:0.554033
# [145]	train-mlogloss:0.4271	test-mlogloss:0.553801
# [146]	train-mlogloss:0.426234	test-mlogloss:0.553712
# [147]	train-mlogloss:0.425593	test-mlogloss:0.553646
# [148]	train-mlogloss:0.424921	test-mlogloss:0.553528
# [149]	train-mlogloss:0.424508	test-mlogloss:0.553639
# [150]	train-mlogloss:0.423796	test-mlogloss:0.553575
# [151]	train-mlogloss:0.423189	test-mlogloss:0.553552
# [152]	train-mlogloss:0.422572	test-mlogloss:0.553452
# [153]	train-mlogloss:0.421913	test-mlogloss:0.553426
# [154]	train-mlogloss:0.421304	test-mlogloss:0.55328
# [155]	train-mlogloss:0.420724	test-mlogloss:0.55317
# [156]	train-mlogloss:0.419927	test-mlogloss:0.55297
# [157]	train-mlogloss:0.419051	test-mlogloss:0.552762
# [158]	train-mlogloss:0.418518	test-mlogloss:0.55268
# [159]	train-mlogloss:0.41773	test-mlogloss:0.552746
# [160]	train-mlogloss:0.416977	test-mlogloss:0.552712
# [161]	train-mlogloss:0.416323	test-mlogloss:0.55268
# [162]	train-mlogloss:0.415878	test-mlogloss:0.552656
# [163]	train-mlogloss:0.415217	test-mlogloss:0.552543
# [164]	train-mlogloss:0.414453	test-mlogloss:0.552532
# [165]	train-mlogloss:0.413906	test-mlogloss:0.55246
# [166]	train-mlogloss:0.413374	test-mlogloss:0.552267
# [167]	train-mlogloss:0.412701	test-mlogloss:0.552271
# [168]	train-mlogloss:0.412163	test-mlogloss:0.552208
# [169]	train-mlogloss:0.411435	test-mlogloss:0.551979
# [170]	train-mlogloss:0.410785	test-mlogloss:0.551843
# [171]	train-mlogloss:0.410055	test-mlogloss:0.551893
# [172]	train-mlogloss:0.409731	test-mlogloss:0.551886
# [173]	train-mlogloss:0.409386	test-mlogloss:0.5519
# [174]	train-mlogloss:0.408691	test-mlogloss:0.551833
# [175]	train-mlogloss:0.408163	test-mlogloss:0.551815
# [176]	train-mlogloss:0.407539	test-mlogloss:0.551837
# [177]	train-mlogloss:0.406737	test-mlogloss:0.551821
# [178]	train-mlogloss:0.406211	test-mlogloss:0.551717
# [179]	train-mlogloss:0.405568	test-mlogloss:0.551559
# [180]	train-mlogloss:0.405245	test-mlogloss:0.551513
# [181]	train-mlogloss:0.404726	test-mlogloss:0.551644
# [182]	train-mlogloss:0.404355	test-mlogloss:0.55166
# [183]	train-mlogloss:0.403947	test-mlogloss:0.55155
# [184]	train-mlogloss:0.403182	test-mlogloss:0.551315
# [185]	train-mlogloss:0.402582	test-mlogloss:0.551253
# [186]	train-mlogloss:0.40197	test-mlogloss:0.551277
# [187]	train-mlogloss:0.401329	test-mlogloss:0.55132
# [188]	train-mlogloss:0.400828	test-mlogloss:0.551117
# [189]	train-mlogloss:0.40018	test-mlogloss:0.551079
# [190]	train-mlogloss:0.399483	test-mlogloss:0.550956
# [191]	train-mlogloss:0.398827	test-mlogloss:0.55085
# [192]	train-mlogloss:0.39827	test-mlogloss:0.550759
# [193]	train-mlogloss:0.397635	test-mlogloss:0.550835
# [194]	train-mlogloss:0.397002	test-mlogloss:0.550643
# [195]	train-mlogloss:0.396366	test-mlogloss:0.550627
# [196]	train-mlogloss:0.395813	test-mlogloss:0.550601
# [197]	train-mlogloss:0.395099	test-mlogloss:0.550363
# [198]	train-mlogloss:0.394449	test-mlogloss:0.550426
# [199]	train-mlogloss:0.394067	test-mlogloss:0.550411
# [200]	train-mlogloss:0.393497	test-mlogloss:0.550487
# [201]	train-mlogloss:0.3929	test-mlogloss:0.550433
# [202]	train-mlogloss:0.392558	test-mlogloss:0.550495
# [203]	train-mlogloss:0.392025	test-mlogloss:0.550574
# [204]	train-mlogloss:0.39147	test-mlogloss:0.550643
# [205]	train-mlogloss:0.391096	test-mlogloss:0.55049
# [206]	train-mlogloss:0.390342	test-mlogloss:0.550459
# [207]	train-mlogloss:0.389716	test-mlogloss:0.550381
# [208]	train-mlogloss:0.389012	test-mlogloss:0.550274
# [209]	train-mlogloss:0.388351	test-mlogloss:0.550359
# [210]	train-mlogloss:0.387707	test-mlogloss:0.550337
# [211]	train-mlogloss:0.387277	test-mlogloss:0.550296
# [212]	train-mlogloss:0.38668	test-mlogloss:0.550267
# [213]	train-mlogloss:0.386081	test-mlogloss:0.550242
# [214]	train-mlogloss:0.385393	test-mlogloss:0.550226
# [215]	train-mlogloss:0.384751	test-mlogloss:0.550068
# [216]	train-mlogloss:0.384176	test-mlogloss:0.550147
# [217]	train-mlogloss:0.383529	test-mlogloss:0.55019
# [218]	train-mlogloss:0.383031	test-mlogloss:0.550195
# [219]	train-mlogloss:0.382407	test-mlogloss:0.550208
# [220]	train-mlogloss:0.381983	test-mlogloss:0.55022
# [221]	train-mlogloss:0.381604	test-mlogloss:0.550211
# [222]	train-mlogloss:0.381017	test-mlogloss:0.550267
# [223]	train-mlogloss:0.380427	test-mlogloss:0.550262
# [224]	train-mlogloss:0.379998	test-mlogloss:0.550354
# [225]	train-mlogloss:0.379396	test-mlogloss:0.5503
# [226]	train-mlogloss:0.37899	test-mlogloss:0.550453
# [227]	train-mlogloss:0.378589	test-mlogloss:0.550517
# [228]	train-mlogloss:0.378049	test-mlogloss:0.550497
# [229]	train-mlogloss:0.377622	test-mlogloss:0.550488
# [230]	train-mlogloss:0.377192	test-mlogloss:0.550445
# [231]	train-mlogloss:0.376583	test-mlogloss:0.550422
# [232]	train-mlogloss:0.376215	test-mlogloss:0.550399
# [233]	train-mlogloss:0.375845	test-mlogloss:0.550468
# [234]	train-mlogloss:0.375281	test-mlogloss:0.550435
# [235]	train-mlogloss:0.374844	test-mlogloss:0.550414
# [236]	train-mlogloss:0.374385	test-mlogloss:0.550418
# [237]	train-mlogloss:0.373859	test-mlogloss:0.550361
# [238]	train-mlogloss:0.37327	test-mlogloss:0.550549
# [239]	train-mlogloss:0.372809	test-mlogloss:0.550614
# [240]	train-mlogloss:0.372349	test-mlogloss:0.550595
# [241]	train-mlogloss:0.371612	test-mlogloss:0.550507
# [242]	train-mlogloss:0.371143	test-mlogloss:0.550541
# [243]	train-mlogloss:0.370624	test-mlogloss:0.550653
# [244]	train-mlogloss:0.370289	test-mlogloss:0.550683
# [245]	train-mlogloss:0.369682	test-mlogloss:0.550507
# [246]	train-mlogloss:0.369143	test-mlogloss:0.550346
# [247]	train-mlogloss:0.36854	test-mlogloss:0.550368
# [248]	train-mlogloss:0.367868	test-mlogloss:0.550436
# [249]	train-mlogloss:0.36737	test-mlogloss:0.55049
# [250]	train-mlogloss:0.366947	test-mlogloss:0.550471
# [251]	train-mlogloss:0.366484	test-mlogloss:0.550421
# [252]	train-mlogloss:0.365799	test-mlogloss:0.550451
# [253]	train-mlogloss:0.365166	test-mlogloss:0.550377
# [254]	train-mlogloss:0.364795	test-mlogloss:0.550301
# [255]	train-mlogloss:0.36412	test-mlogloss:0.550354
# [256]	train-mlogloss:0.363609	test-mlogloss:0.550327
# [257]	train-mlogloss:0.363148	test-mlogloss:0.550215
# [258]	train-mlogloss:0.362624	test-mlogloss:0.550213
# [259]	train-mlogloss:0.36219	test-mlogloss:0.55022
# [260]	train-mlogloss:0.361761	test-mlogloss:0.55027
# [261]	train-mlogloss:0.361368	test-mlogloss:0.550233
# [262]	train-mlogloss:0.360857	test-mlogloss:0.550209
# [263]	train-mlogloss:0.360444	test-mlogloss:0.550254
# [264]	train-mlogloss:0.359919	test-mlogloss:0.550212
# [265]	train-mlogloss:0.359452	test-mlogloss:0.550144
# [266]	train-mlogloss:0.35897	test-mlogloss:0.550311
# [267]	train-mlogloss:0.358574	test-mlogloss:0.550213
# [268]	train-mlogloss:0.358052	test-mlogloss:0.550309
# [269]	train-mlogloss:0.357512	test-mlogloss:0.550301
# [270]	train-mlogloss:0.356979	test-mlogloss:0.550211
# [271]	train-mlogloss:0.35636	test-mlogloss:0.550413
# [272]	train-mlogloss:0.355828	test-mlogloss:0.550418
# [273]	train-mlogloss:0.355424	test-mlogloss:0.550436
# [274]	train-mlogloss:0.354887	test-mlogloss:0.550541
# [275]	train-mlogloss:0.354475	test-mlogloss:0.550623
# [276]	train-mlogloss:0.353986	test-mlogloss:0.550708
# [277]	train-mlogloss:0.353659	test-mlogloss:0.550871
# [278]	train-mlogloss:0.353213	test-mlogloss:0.550809
# [279]	train-mlogloss:0.352843	test-mlogloss:0.550773
# [280]	train-mlogloss:0.352505	test-mlogloss:0.550724
# [281]	train-mlogloss:0.352096	test-mlogloss:0.550759
# [282]	train-mlogloss:0.351692	test-mlogloss:0.55075
# [283]	train-mlogloss:0.351185	test-mlogloss:0.55071
# [284]	train-mlogloss:0.350843	test-mlogloss:0.550725
# [285]	train-mlogloss:0.350313	test-mlogloss:0.550755
# [286]	train-mlogloss:0.349758	test-mlogloss:0.550494
# [287]	train-mlogloss:0.349393	test-mlogloss:0.550468
# [288]	train-mlogloss:0.348829	test-mlogloss:0.550446
# [289]	train-mlogloss:0.34833	test-mlogloss:0.550334
# [290]	train-mlogloss:0.34789	test-mlogloss:0.550261
# [291]	train-mlogloss:0.347409	test-mlogloss:0.550218
# [292]	train-mlogloss:0.346891	test-mlogloss:0.550138
# [293]	train-mlogloss:0.346405	test-mlogloss:0.550261
# [294]	train-mlogloss:0.345925	test-mlogloss:0.550093
# [295]	train-mlogloss:0.345474	test-mlogloss:0.550192
# [296]	train-mlogloss:0.345305	test-mlogloss:0.550231
# [297]	train-mlogloss:0.344824	test-mlogloss:0.550172
# [298]	train-mlogloss:0.344273	test-mlogloss:0.550267
# [299]	train-mlogloss:0.34374	test-mlogloss:0.550265
# [300]	train-mlogloss:0.343361	test-mlogloss:0.550288
# [301]	train-mlogloss:0.342847	test-mlogloss:0.550222
# [302]	train-mlogloss:0.342441	test-mlogloss:0.550281
# [303]	train-mlogloss:0.342033	test-mlogloss:0.550382
# [304]	train-mlogloss:0.341576	test-mlogloss:0.550372
# [305]	train-mlogloss:0.341128	test-mlogloss:0.550321
# [306]	train-mlogloss:0.340682	test-mlogloss:0.550296
# [307]	train-mlogloss:0.340259	test-mlogloss:0.550375
# [308]	train-mlogloss:0.339764	test-mlogloss:0.550391
# [309]	train-mlogloss:0.339326	test-mlogloss:0.550406
# [310]	train-mlogloss:0.339056	test-mlogloss:0.550367
# [311]	train-mlogloss:0.338498	test-mlogloss:0.550426
# [312]	train-mlogloss:0.337958	test-mlogloss:0.550457
# [313]	train-mlogloss:0.33755	test-mlogloss:0.550439
# [314]	train-mlogloss:0.337086	test-mlogloss:0.550438
# [315]	train-mlogloss:0.336641	test-mlogloss:0.550405
# Stopping. Best iteration:
# [215]	train-mlogloss:0.384751	test-mlogloss:0.550068
#
# [0.55040475480834061]

# %%
#====================================================================        
"""feature engineerings for the categorical features"""

train_set, test_set =manager_skill_eval(train_df,test_df,\
unrank_threshold = mini_ranking)


#fill substitute the small size values by their mean
for f in categorical:
    train_set,test_set  = singleValueConvert(train_set,test_set,f,mini_ranking)

    if train_set[f].dtype=='object':
        #print(f)
        lbl = preprocessing.LabelEncoder()
        lbl.fit(hcc_sorting(train_set,test_set,f,randomize = 0.05))
        train_set[f] = lbl.transform(list(train_set[f].values))
        test_set[f] = lbl.transform(list(test_set[f].values))
                
#===================================================================

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=290)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point25withSomePreprocessing.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:123: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
