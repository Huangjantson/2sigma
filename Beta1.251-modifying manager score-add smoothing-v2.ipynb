# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss,accuracy_score
from sklearn.cross_validation import KFold,StratifiedKFold
import re
import string
from collections import defaultdict, Counter

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, \
     seed_val=0, early_stop = 20,num_rounds=10000, eta = 0.1, max_depth = 6):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = eta
    param['max_depth'] = max_depth
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist,\
        early_stopping_rounds=early_stop)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    
    return street
    
#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column,minimum_size=5):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    return df1, df2

# %%
"""the old manager skil """
#def manager_skill_eval(train_df,test_df,unrank_threshold = 10):
def manager_skill_eval(train_df,test_df,k,f=1,update_df =None):
    
    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    #temp["lambda"] = 1 / (1 + np.exp((k - temp["count"] )/f))
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']+1
    mean_values = temp.loc[:, 'manager_skill'].mean()
    
    #temp['manager_skill'] = temp["lambda"]*temp['manager_skill_origin']+(1-temp["lambda"])*mean_values    

    value = test_df[['manager_id']].join(temp, on='manager_id', how="left")['manager_skill'].fillna(mean_values)
    
    if update_df is None: update_df = test_df
    if 'manager_skill' not in update_df.columns: update_df['manager_skill'] = np.nan
    update_df.update(value)

# %%
#functions for features
def featureList(train_df,test_df,limit = 0.001):
    #acquiring the feature lists
    features_in_train = train_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    features_in_test = test_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    
    filtered_features_in_train = features_in_train[features_in_train > limit*len(train_df)]
    filtered_features_in_test = features_in_test[features_in_test > limit*len(test_df)]
    accept_list = set(filtered_features_in_train.index).union(set(filtered_features_in_test.index))
    return accept_list

def featureMapping(train_df,test_df,feature_list):
    for feature in feature_list:
        #add the feature column for both
        #if feature in the row, then set the value for (row,feature) to 1
        train_df['with_'+feature]=train_df['features'].apply(lambda x : 1 if feature in x else 0)
        test_df['with_'+feature]=test_df['features'].apply(lambda x : 1 if feature in x else 0)
    return

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  (train_df["price"]*1.0/train_df["bathrooms"]).replace(np.Inf,-1)
train_df["price_per_bed"] = (train_df["price"]*1.0/train_df["bedrooms"]).replace(np.Inf,-1)
train_df["bath_per_bed"] = (train_df["bathrooms"]*1.0/train_df["bedrooms"]).replace(np.Inf,-1)
train_df["price_per_room"] = (train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])).replace(np.Inf,-1)

test_df["price_per_bath"] =  (test_df["price"]*1.0/test_df["bathrooms"]).replace(np.Inf,-1)
test_df["price_per_bed"] = (test_df["price"]*1.0/test_df["bedrooms"]).replace(np.Inf,-1)
test_df["bath_per_bed"] = (test_df["bathrooms"]*1.0/test_df["bedrooms"]).replace(np.Inf,-1)
test_df["price_per_room"] = (test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])).replace(np.Inf,-1)

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
"""
new categorical data append and converting label dummies for future use
"""
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

# %%
#dealing with features

#preprocessing for features
train_df["features"] = train_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_') \
                                                            for i in x])
test_df["features"] = test_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_')\
                                                          for i in x])
#create the accept list
accept_list = list(featureList(train_df,test_df,limit = 0.001))

#map the feature to dummy slots
featureMapping(train_df,test_df,accept_list)
features_to_use.extend(map(lambda x : 'with_'+x,accept_list))

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=StratifiedKFold(train_y,5,shuffle=True,random_state = 42)

train_df = train_df.fillna(-1)
test_df = test_df.fillna(-1)

# %%
features_to_use.append('manager_skill')
categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
features_to_use.extend(categorical)

# %%
cv_scores = []

#mini_ranking = 15

for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
#====================================================================        
        """feature engineerings for the categorical features"""
        #fill substitute the small size values by their mean
        for f in ['display_address','manager_id','building_id','street_name']:
            dev_set,val_set  = singleValueConvert(dev_set,val_set,f,1)
        
        
        #K-FOLD evaluation for the manager skill
        
        skf=StratifiedKFold(dev_set['interest_level'],5,shuffle=True,random_state = 42)
        #dev set adding manager skill
        for train,test in skf:
            manager_skill_eval(dev_set.iloc[train,:],dev_set.iloc[test,:],k=5,f=0.5,update_df = dev_set)
            
        #val set adding manager skill
        manager_skill_eval(dev_set,val_set,k=5,f=0.5)
        
        #dev_set,val_set = manager_skill_eval_old(dev_set,val_set,15)

        for f in categorical:

            if dev_set[f].dtype=='object':
                #print(f)
                lbl = preprocessing.LabelEncoder()
                lbl.fit(list(dev_set[f])+list(val_set[f]))
                dev_set[f] = lbl.transform(list(dev_set[f].values))
                val_set[f] = lbl.transform(list(val_set[f].values))
        
#===================================================================
                
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        """
        runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, \
        seed_val=0, early_stop = 20,num_rounds=10000, eta = 0.1, max_depth = 6)
        """        
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,\
        feature_names=features_to_use,early_stop=20,
        num_rounds = 20000, eta = 0.1,max_depth = 4)
    
        #using rf for feature choosing
        #model = ensemble.RandomForestClassifier(500,random_state = 42,class_weight='balanced')
        #model.fit(dev_X,dev_y)
        #pred_prob = model.predict_proba(val_X)
        #pred = model.predict(val_X)
            
        cv_scores.append(log_loss(val_y, preds))
        
print cv_scores
#print accuracy_score(val_y,pred)
# Out:
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [0]	train-mlogloss:1.0417	test-mlogloss:1.04171
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:0.994227	test-mlogloss:0.994381
# [2]	train-mlogloss:0.953439	test-mlogloss:0.953617
# [3]	train-mlogloss:0.916918	test-mlogloss:0.917368
# [4]	train-mlogloss:0.886424	test-mlogloss:0.887257
# [5]	train-mlogloss:0.858424	test-mlogloss:0.859471
# [6]	train-mlogloss:0.833902	test-mlogloss:0.835189
# [7]	train-mlogloss:0.812493	test-mlogloss:0.814063
# [8]	train-mlogloss:0.793309	test-mlogloss:0.795077
# [9]	train-mlogloss:0.776548	test-mlogloss:0.778578
# [10]	train-mlogloss:0.762263	test-mlogloss:0.764465
# [11]	train-mlogloss:0.748528	test-mlogloss:0.75087
# [12]	train-mlogloss:0.736414	test-mlogloss:0.738976
# [13]	train-mlogloss:0.725889	test-mlogloss:0.728731
# [14]	train-mlogloss:0.716799	test-mlogloss:0.71972
# [15]	train-mlogloss:0.707896	test-mlogloss:0.711043
# [16]	train-mlogloss:0.699995	test-mlogloss:0.703119
# [17]	train-mlogloss:0.69311	test-mlogloss:0.696434
# [18]	train-mlogloss:0.686501	test-mlogloss:0.689933
# [19]	train-mlogloss:0.68085	test-mlogloss:0.684543
# [20]	train-mlogloss:0.675292	test-mlogloss:0.679197
# [21]	train-mlogloss:0.670168	test-mlogloss:0.674158
# [22]	train-mlogloss:0.665034	test-mlogloss:0.669287
# [23]	train-mlogloss:0.6602	test-mlogloss:0.664661
# [24]	train-mlogloss:0.65584	test-mlogloss:0.660414
# [25]	train-mlogloss:0.651916	test-mlogloss:0.656736
# [26]	train-mlogloss:0.648253	test-mlogloss:0.653184
# [27]	train-mlogloss:0.645032	test-mlogloss:0.650169
# [28]	train-mlogloss:0.641568	test-mlogloss:0.646985
# [29]	train-mlogloss:0.638595	test-mlogloss:0.644312
# [30]	train-mlogloss:0.635796	test-mlogloss:0.641742
# [31]	train-mlogloss:0.6329	test-mlogloss:0.638942
# [32]	train-mlogloss:0.630691	test-mlogloss:0.636793
# [33]	train-mlogloss:0.628671	test-mlogloss:0.634899
# [34]	train-mlogloss:0.626366	test-mlogloss:0.632765
# [35]	train-mlogloss:0.624363	test-mlogloss:0.630738
# [36]	train-mlogloss:0.622372	test-mlogloss:0.628813
# [37]	train-mlogloss:0.620381	test-mlogloss:0.627017
# [38]	train-mlogloss:0.618849	test-mlogloss:0.62578
# [39]	train-mlogloss:0.616966	test-mlogloss:0.624052
# [40]	train-mlogloss:0.615305	test-mlogloss:0.622611
# [41]	train-mlogloss:0.61333	test-mlogloss:0.620884
# [42]	train-mlogloss:0.611648	test-mlogloss:0.619476
# [43]	train-mlogloss:0.610267	test-mlogloss:0.618261
# [44]	train-mlogloss:0.608988	test-mlogloss:0.617224
# [45]	train-mlogloss:0.607799	test-mlogloss:0.616237
# [46]	train-mlogloss:0.606472	test-mlogloss:0.615124
# [47]	train-mlogloss:0.605437	test-mlogloss:0.614227
# [48]	train-mlogloss:0.604202	test-mlogloss:0.613177
# [49]	train-mlogloss:0.602884	test-mlogloss:0.612078
# [50]	train-mlogloss:0.601566	test-mlogloss:0.611058
# [51]	train-mlogloss:0.600179	test-mlogloss:0.609973
# [52]	train-mlogloss:0.598712	test-mlogloss:0.608821
# [53]	train-mlogloss:0.59747	test-mlogloss:0.607808
# [54]	train-mlogloss:0.596359	test-mlogloss:0.606798
# [55]	train-mlogloss:0.595328	test-mlogloss:0.605927
# [56]	train-mlogloss:0.594254	test-mlogloss:0.605122
# [57]	train-mlogloss:0.593278	test-mlogloss:0.604348
# [58]	train-mlogloss:0.592554	test-mlogloss:0.603798
# [59]	train-mlogloss:0.591521	test-mlogloss:0.602988
# [60]	train-mlogloss:0.590716	test-mlogloss:0.602296
# [61]	train-mlogloss:0.589602	test-mlogloss:0.601352
# [62]	train-mlogloss:0.588443	test-mlogloss:0.600399
# [63]	train-mlogloss:0.587517	test-mlogloss:0.599612
# [64]	train-mlogloss:0.586644	test-mlogloss:0.598983
# [65]	train-mlogloss:0.585639	test-mlogloss:0.598217
# [66]	train-mlogloss:0.584698	test-mlogloss:0.597463
# [67]	train-mlogloss:0.583991	test-mlogloss:0.596943
# [68]	train-mlogloss:0.58318	test-mlogloss:0.596288
# [69]	train-mlogloss:0.582237	test-mlogloss:0.595582
# [70]	train-mlogloss:0.581569	test-mlogloss:0.594991
# [71]	train-mlogloss:0.580854	test-mlogloss:0.594382
# [72]	train-mlogloss:0.580261	test-mlogloss:0.593931
# [73]	train-mlogloss:0.579618	test-mlogloss:0.593391
# [74]	train-mlogloss:0.578818	test-mlogloss:0.5929
# [75]	train-mlogloss:0.577941	test-mlogloss:0.592278
# [76]	train-mlogloss:0.57724	test-mlogloss:0.59175
# [77]	train-mlogloss:0.576477	test-mlogloss:0.591308
# [78]	train-mlogloss:0.57571	test-mlogloss:0.59071
# [79]	train-mlogloss:0.574954	test-mlogloss:0.590186
# [80]	train-mlogloss:0.574162	test-mlogloss:0.58957
# [81]	train-mlogloss:0.573601	test-mlogloss:0.589126
# [82]	train-mlogloss:0.572907	test-mlogloss:0.588597
# [83]	train-mlogloss:0.572203	test-mlogloss:0.588087
# [84]	train-mlogloss:0.571669	test-mlogloss:0.587777
# [85]	train-mlogloss:0.57096	test-mlogloss:0.58716
# [86]	train-mlogloss:0.570122	test-mlogloss:0.586571
# [87]	train-mlogloss:0.569529	test-mlogloss:0.586196
# [88]	train-mlogloss:0.568952	test-mlogloss:0.585819
# [89]	train-mlogloss:0.568217	test-mlogloss:0.585324
# [90]	train-mlogloss:0.567658	test-mlogloss:0.584945
# [91]	train-mlogloss:0.567102	test-mlogloss:0.584666
# [92]	train-mlogloss:0.566487	test-mlogloss:0.58417
# [93]	train-mlogloss:0.56592	test-mlogloss:0.583746
# [94]	train-mlogloss:0.565219	test-mlogloss:0.583275
# [95]	train-mlogloss:0.564763	test-mlogloss:0.582917
# [96]	train-mlogloss:0.564267	test-mlogloss:0.582467
# [97]	train-mlogloss:0.563681	test-mlogloss:0.582032
# [98]	train-mlogloss:0.563096	test-mlogloss:0.581694
# [99]	train-mlogloss:0.562589	test-mlogloss:0.581446
# [100]	train-mlogloss:0.561984	test-mlogloss:0.581019
# [101]	train-mlogloss:0.561544	test-mlogloss:0.580675
# [102]	train-mlogloss:0.560994	test-mlogloss:0.580228
# [103]	train-mlogloss:0.560611	test-mlogloss:0.579927
# [104]	train-mlogloss:0.56006	test-mlogloss:0.579456
# [105]	train-mlogloss:0.559512	test-mlogloss:0.579109
# [106]	train-mlogloss:0.55892	test-mlogloss:0.578769
# [107]	train-mlogloss:0.558275	test-mlogloss:0.578366
# [108]	train-mlogloss:0.557787	test-mlogloss:0.578174
# [109]	train-mlogloss:0.557283	test-mlogloss:0.577812
# [110]	train-mlogloss:0.556725	test-mlogloss:0.577443
# [111]	train-mlogloss:0.556248	test-mlogloss:0.577185
# [112]	train-mlogloss:0.555755	test-mlogloss:0.576857
# [113]	train-mlogloss:0.555312	test-mlogloss:0.576625
# [114]	train-mlogloss:0.554721	test-mlogloss:0.576204
# [115]	train-mlogloss:0.554274	test-mlogloss:0.575914
# [116]	train-mlogloss:0.553766	test-mlogloss:0.575672
# [117]	train-mlogloss:0.553325	test-mlogloss:0.575426
# [118]	train-mlogloss:0.552642	test-mlogloss:0.575052
# [119]	train-mlogloss:0.552175	test-mlogloss:0.574752
# [120]	train-mlogloss:0.551758	test-mlogloss:0.57446
# [121]	train-mlogloss:0.551242	test-mlogloss:0.574144
# [122]	train-mlogloss:0.550656	test-mlogloss:0.573757
# [123]	train-mlogloss:0.550128	test-mlogloss:0.573466
# [124]	train-mlogloss:0.549608	test-mlogloss:0.573057
# [125]	train-mlogloss:0.549034	test-mlogloss:0.572795
# [126]	train-mlogloss:0.548506	test-mlogloss:0.572615
# [127]	train-mlogloss:0.547939	test-mlogloss:0.572273
# [128]	train-mlogloss:0.547653	test-mlogloss:0.572062
# [129]	train-mlogloss:0.547184	test-mlogloss:0.571821
# [130]	train-mlogloss:0.546567	test-mlogloss:0.571475
# [131]	train-mlogloss:0.546079	test-mlogloss:0.571235
# [132]	train-mlogloss:0.545715	test-mlogloss:0.571095
# [133]	train-mlogloss:0.545297	test-mlogloss:0.570891
# [134]	train-mlogloss:0.544901	test-mlogloss:0.570693
# [135]	train-mlogloss:0.544541	test-mlogloss:0.570558
# [136]	train-mlogloss:0.544064	test-mlogloss:0.570253
# [137]	train-mlogloss:0.54357	test-mlogloss:0.569924
# [138]	train-mlogloss:0.543085	test-mlogloss:0.569659
# [139]	train-mlogloss:0.542654	test-mlogloss:0.569443
# [140]	train-mlogloss:0.542321	test-mlogloss:0.569241
# [141]	train-mlogloss:0.541993	test-mlogloss:0.569121
# [142]	train-mlogloss:0.541553	test-mlogloss:0.568857
# [143]	train-mlogloss:0.541146	test-mlogloss:0.568488
# [144]	train-mlogloss:0.540798	test-mlogloss:0.568297
# [145]	train-mlogloss:0.540362	test-mlogloss:0.568104
# [146]	train-mlogloss:0.539916	test-mlogloss:0.56778
# [147]	train-mlogloss:0.539497	test-mlogloss:0.567611
# [148]	train-mlogloss:0.539094	test-mlogloss:0.567372
# [149]	train-mlogloss:0.538671	test-mlogloss:0.567006
# [150]	train-mlogloss:0.538372	test-mlogloss:0.566893
# [151]	train-mlogloss:0.537955	test-mlogloss:0.566709
# [152]	train-mlogloss:0.537632	test-mlogloss:0.566482
# [153]	train-mlogloss:0.53728	test-mlogloss:0.566332
# [154]	train-mlogloss:0.536938	test-mlogloss:0.566261
# [155]	train-mlogloss:0.536584	test-mlogloss:0.566102
# [156]	train-mlogloss:0.536039	test-mlogloss:0.565721
# [157]	train-mlogloss:0.535713	test-mlogloss:0.565559
# [158]	train-mlogloss:0.53543	test-mlogloss:0.565405
# [159]	train-mlogloss:0.534942	test-mlogloss:0.565075
# [160]	train-mlogloss:0.534558	test-mlogloss:0.564885
# [161]	train-mlogloss:0.534158	test-mlogloss:0.564637
# [162]	train-mlogloss:0.533682	test-mlogloss:0.564332
# [163]	train-mlogloss:0.533278	test-mlogloss:0.564237
# [164]	train-mlogloss:0.532973	test-mlogloss:0.564072
# [165]	train-mlogloss:0.532619	test-mlogloss:0.563865
# [166]	train-mlogloss:0.532286	test-mlogloss:0.563708
# [167]	train-mlogloss:0.531854	test-mlogloss:0.563546
# [168]	train-mlogloss:0.531569	test-mlogloss:0.563441
# [169]	train-mlogloss:0.531331	test-mlogloss:0.563376
# [170]	train-mlogloss:0.530965	test-mlogloss:0.563232
# [171]	train-mlogloss:0.530628	test-mlogloss:0.563076
# [172]	train-mlogloss:0.530215	test-mlogloss:0.562888
# [173]	train-mlogloss:0.529929	test-mlogloss:0.562829
# [174]	train-mlogloss:0.529635	test-mlogloss:0.562714
# [175]	train-mlogloss:0.529346	test-mlogloss:0.562615
# [176]	train-mlogloss:0.528917	test-mlogloss:0.562496
# [177]	train-mlogloss:0.528661	test-mlogloss:0.562255
# [178]	train-mlogloss:0.528286	test-mlogloss:0.562075
# [179]	train-mlogloss:0.52783	test-mlogloss:0.561865
# [180]	train-mlogloss:0.527468	test-mlogloss:0.561694
# [181]	train-mlogloss:0.527022	test-mlogloss:0.561437
# [182]	train-mlogloss:0.526605	test-mlogloss:0.561354
# [183]	train-mlogloss:0.526268	test-mlogloss:0.561165
# [184]	train-mlogloss:0.525996	test-mlogloss:0.560993
# [185]	train-mlogloss:0.525687	test-mlogloss:0.560842
# [186]	train-mlogloss:0.525331	test-mlogloss:0.560693
# [187]	train-mlogloss:0.524945	test-mlogloss:0.560407
# [188]	train-mlogloss:0.524665	test-mlogloss:0.560269
# [189]	train-mlogloss:0.524315	test-mlogloss:0.560062
# [190]	train-mlogloss:0.524065	test-mlogloss:0.559951
# [191]	train-mlogloss:0.523798	test-mlogloss:0.559829
# [192]	train-mlogloss:0.523388	test-mlogloss:0.559595
# [193]	train-mlogloss:0.523015	test-mlogloss:0.55947
# [194]	train-mlogloss:0.522673	test-mlogloss:0.559281
# [195]	train-mlogloss:0.522376	test-mlogloss:0.559217
# [196]	train-mlogloss:0.522038	test-mlogloss:0.559005
# [197]	train-mlogloss:0.52178	test-mlogloss:0.558857
# [198]	train-mlogloss:0.521383	test-mlogloss:0.558632
# [199]	train-mlogloss:0.521046	test-mlogloss:0.558443
# [200]	train-mlogloss:0.520794	test-mlogloss:0.55839
# [201]	train-mlogloss:0.520533	test-mlogloss:0.558356
# [202]	train-mlogloss:0.520225	test-mlogloss:0.558346
# [203]	train-mlogloss:0.519947	test-mlogloss:0.558217
# [204]	train-mlogloss:0.519626	test-mlogloss:0.558127
# [205]	train-mlogloss:0.519358	test-mlogloss:0.557987
# [206]	train-mlogloss:0.519003	test-mlogloss:0.557873
# [207]	train-mlogloss:0.51867	test-mlogloss:0.557717
# [208]	train-mlogloss:0.518346	test-mlogloss:0.557638
# [209]	train-mlogloss:0.518016	test-mlogloss:0.557452
# [210]	train-mlogloss:0.517755	test-mlogloss:0.557404
# [211]	train-mlogloss:0.517543	test-mlogloss:0.557363
# [212]	train-mlogloss:0.517171	test-mlogloss:0.557117
# [213]	train-mlogloss:0.516864	test-mlogloss:0.557011
# [214]	train-mlogloss:0.516531	test-mlogloss:0.556858
# [215]	train-mlogloss:0.516206	test-mlogloss:0.556755
# [216]	train-mlogloss:0.515843	test-mlogloss:0.556632
# [217]	train-mlogloss:0.515574	test-mlogloss:0.55656
# [218]	train-mlogloss:0.515226	test-mlogloss:0.556447
# [219]	train-mlogloss:0.514857	test-mlogloss:0.556347
# [220]	train-mlogloss:0.514595	test-mlogloss:0.556278
# [221]	train-mlogloss:0.514255	test-mlogloss:0.55616
# [222]	train-mlogloss:0.5139	test-mlogloss:0.555955
# [223]	train-mlogloss:0.513612	test-mlogloss:0.555758
# [224]	train-mlogloss:0.513219	test-mlogloss:0.555657
# [225]	train-mlogloss:0.512944	test-mlogloss:0.555533
# [226]	train-mlogloss:0.512713	test-mlogloss:0.55545
# [227]	train-mlogloss:0.512456	test-mlogloss:0.555279
# [228]	train-mlogloss:0.512172	test-mlogloss:0.555207
# [229]	train-mlogloss:0.511838	test-mlogloss:0.55513
# [230]	train-mlogloss:0.511548	test-mlogloss:0.554957
# [231]	train-mlogloss:0.511261	test-mlogloss:0.55491
# [232]	train-mlogloss:0.511075	test-mlogloss:0.554832
# [233]	train-mlogloss:0.510951	test-mlogloss:0.554754
# [234]	train-mlogloss:0.510625	test-mlogloss:0.554588
# [235]	train-mlogloss:0.510335	test-mlogloss:0.554421
# [236]	train-mlogloss:0.510029	test-mlogloss:0.554387
# [237]	train-mlogloss:0.509789	test-mlogloss:0.554262
# [238]	train-mlogloss:0.509443	test-mlogloss:0.554184
# [239]	train-mlogloss:0.509201	test-mlogloss:0.554106
# [240]	train-mlogloss:0.508854	test-mlogloss:0.553895
# [241]	train-mlogloss:0.508499	test-mlogloss:0.553833
# [242]	train-mlogloss:0.50823	test-mlogloss:0.553716
# [243]	train-mlogloss:0.507966	test-mlogloss:0.553605
# [244]	train-mlogloss:0.507623	test-mlogloss:0.553526
# [245]	train-mlogloss:0.507286	test-mlogloss:0.553401
# [246]	train-mlogloss:0.507029	test-mlogloss:0.553321
# [247]	train-mlogloss:0.506813	test-mlogloss:0.553225
# [248]	train-mlogloss:0.506636	test-mlogloss:0.553155
# [249]	train-mlogloss:0.506335	test-mlogloss:0.552926
# [250]	train-mlogloss:0.506156	test-mlogloss:0.55291
# [251]	train-mlogloss:0.505875	test-mlogloss:0.552791
# [252]	train-mlogloss:0.505522	test-mlogloss:0.552683
# [253]	train-mlogloss:0.505203	test-mlogloss:0.552508
# [254]	train-mlogloss:0.50494	test-mlogloss:0.552434
# [255]	train-mlogloss:0.504601	test-mlogloss:0.552269
# [256]	train-mlogloss:0.504292	test-mlogloss:0.552238
# [257]	train-mlogloss:0.504014	test-mlogloss:0.552118
# [258]	train-mlogloss:0.50376	test-mlogloss:0.552126
# [259]	train-mlogloss:0.503486	test-mlogloss:0.551963
# [260]	train-mlogloss:0.5032	test-mlogloss:0.551894
# [261]	train-mlogloss:0.50296	test-mlogloss:0.551768
# [262]	train-mlogloss:0.502744	test-mlogloss:0.551723
# [263]	train-mlogloss:0.502441	test-mlogloss:0.551641
# [264]	train-mlogloss:0.502127	test-mlogloss:0.55157
# [265]	train-mlogloss:0.501876	test-mlogloss:0.551465
# [266]	train-mlogloss:0.50158	test-mlogloss:0.55137
# [267]	train-mlogloss:0.501354	test-mlogloss:0.551315
# [268]	train-mlogloss:0.501046	test-mlogloss:0.551188
# [269]	train-mlogloss:0.500736	test-mlogloss:0.551119
# [270]	train-mlogloss:0.50045	test-mlogloss:0.551072
# [271]	train-mlogloss:0.50018	test-mlogloss:0.551026
# [272]	train-mlogloss:0.499952	test-mlogloss:0.551031
# [273]	train-mlogloss:0.499687	test-mlogloss:0.5509
# [274]	train-mlogloss:0.49936	test-mlogloss:0.550756
# [275]	train-mlogloss:0.499097	test-mlogloss:0.550604
# [276]	train-mlogloss:0.498847	test-mlogloss:0.550538
# [277]	train-mlogloss:0.498603	test-mlogloss:0.550492
# [278]	train-mlogloss:0.498279	test-mlogloss:0.550372
# [279]	train-mlogloss:0.498057	test-mlogloss:0.550303
# [280]	train-mlogloss:0.497825	test-mlogloss:0.550215
# [281]	train-mlogloss:0.497548	test-mlogloss:0.550222
# [282]	train-mlogloss:0.497304	test-mlogloss:0.55015
# [283]	train-mlogloss:0.497035	test-mlogloss:0.550102
# [284]	train-mlogloss:0.496756	test-mlogloss:0.549917
# [285]	train-mlogloss:0.496552	test-mlogloss:0.549846
# [286]	train-mlogloss:0.496295	test-mlogloss:0.549742
# [287]	train-mlogloss:0.496059	test-mlogloss:0.549595
# [288]	train-mlogloss:0.495737	test-mlogloss:0.549522
# [289]	train-mlogloss:0.495475	test-mlogloss:0.549451
# [290]	train-mlogloss:0.495214	test-mlogloss:0.549401
# [291]	train-mlogloss:0.494944	test-mlogloss:0.549273
# [292]	train-mlogloss:0.494693	test-mlogloss:0.549251
# [293]	train-mlogloss:0.494447	test-mlogloss:0.54917
# [294]	train-mlogloss:0.494242	test-mlogloss:0.549152
# [295]	train-mlogloss:0.494074	test-mlogloss:0.549089
# [296]	train-mlogloss:0.493808	test-mlogloss:0.548932
# [297]	train-mlogloss:0.493525	test-mlogloss:0.548786
# [298]	train-mlogloss:0.49334	test-mlogloss:0.548719
# [299]	train-mlogloss:0.493098	test-mlogloss:0.548702
# [300]	train-mlogloss:0.492885	test-mlogloss:0.548649
# [301]	train-mlogloss:0.492692	test-mlogloss:0.548596
# [302]	train-mlogloss:0.492421	test-mlogloss:0.548424
# [303]	train-mlogloss:0.492186	test-mlogloss:0.548419
# [304]	train-mlogloss:0.49184	test-mlogloss:0.548341
# [305]	train-mlogloss:0.4916	test-mlogloss:0.548236
# [306]	train-mlogloss:0.491339	test-mlogloss:0.54808
# [307]	train-mlogloss:0.491152	test-mlogloss:0.548022
# [308]	train-mlogloss:0.490945	test-mlogloss:0.547978
# [309]	train-mlogloss:0.490716	test-mlogloss:0.547923
# [310]	train-mlogloss:0.490492	test-mlogloss:0.547783
# [311]	train-mlogloss:0.490208	test-mlogloss:0.547697
# [312]	train-mlogloss:0.489967	test-mlogloss:0.547604
# [313]	train-mlogloss:0.489764	test-mlogloss:0.547599
# [314]	train-mlogloss:0.489577	test-mlogloss:0.547482
# [315]	train-mlogloss:0.489333	test-mlogloss:0.547415
# [316]	train-mlogloss:0.489027	test-mlogloss:0.547325
# [317]	train-mlogloss:0.488739	test-mlogloss:0.547227
# [318]	train-mlogloss:0.488486	test-mlogloss:0.547151
# [319]	train-mlogloss:0.488245	test-mlogloss:0.547045
# [320]	train-mlogloss:0.488041	test-mlogloss:0.546978
# [321]	train-mlogloss:0.487766	test-mlogloss:0.546891
# [322]	train-mlogloss:0.487508	test-mlogloss:0.546841
# [323]	train-mlogloss:0.487236	test-mlogloss:0.546768
# [324]	train-mlogloss:0.486983	test-mlogloss:0.54671
# [325]	train-mlogloss:0.486772	test-mlogloss:0.54671
# [326]	train-mlogloss:0.486488	test-mlogloss:0.546751
# [327]	train-mlogloss:0.486227	test-mlogloss:0.546712
# [328]	train-mlogloss:0.486015	test-mlogloss:0.546696
# [329]	train-mlogloss:0.485702	test-mlogloss:0.546638
# [330]	train-mlogloss:0.485482	test-mlogloss:0.546617
# [331]	train-mlogloss:0.485303	test-mlogloss:0.546566
# [332]	train-mlogloss:0.485015	test-mlogloss:0.546439
# [333]	train-mlogloss:0.48468	test-mlogloss:0.546317
# [334]	train-mlogloss:0.48448	test-mlogloss:0.546187
# [335]	train-mlogloss:0.484232	test-mlogloss:0.546075
# [336]	train-mlogloss:0.483995	test-mlogloss:0.545978
# [337]	train-mlogloss:0.483772	test-mlogloss:0.545894
# [338]	train-mlogloss:0.48357	test-mlogloss:0.545797
# [339]	train-mlogloss:0.483304	test-mlogloss:0.545748
# [340]	train-mlogloss:0.48305	test-mlogloss:0.545618
# [341]	train-mlogloss:0.482835	test-mlogloss:0.545586
# [342]	train-mlogloss:0.482633	test-mlogloss:0.545502
# [343]	train-mlogloss:0.482465	test-mlogloss:0.54552
# [344]	train-mlogloss:0.482257	test-mlogloss:0.545492
# [345]	train-mlogloss:0.482037	test-mlogloss:0.545427
# [346]	train-mlogloss:0.481725	test-mlogloss:0.545325
# [347]	train-mlogloss:0.481452	test-mlogloss:0.545242
# [348]	train-mlogloss:0.481241	test-mlogloss:0.545189
# [349]	train-mlogloss:0.480985	test-mlogloss:0.545173
# [350]	train-mlogloss:0.480671	test-mlogloss:0.545094
# [351]	train-mlogloss:0.480441	test-mlogloss:0.545047
# [352]	train-mlogloss:0.480255	test-mlogloss:0.545127
# [353]	train-mlogloss:0.480045	test-mlogloss:0.545106
# [354]	train-mlogloss:0.479811	test-mlogloss:0.545088
# [355]	train-mlogloss:0.479604	test-mlogloss:0.545022
# [356]	train-mlogloss:0.479399	test-mlogloss:0.544968
# [357]	train-mlogloss:0.479068	test-mlogloss:0.544859
# [358]	train-mlogloss:0.478756	test-mlogloss:0.54478
# [359]	train-mlogloss:0.478533	test-mlogloss:0.544739
# [360]	train-mlogloss:0.478415	test-mlogloss:0.544693
# [361]	train-mlogloss:0.4782	test-mlogloss:0.544748
# [362]	train-mlogloss:0.477911	test-mlogloss:0.544593
# [363]	train-mlogloss:0.477718	test-mlogloss:0.544531
# [364]	train-mlogloss:0.477563	test-mlogloss:0.544495
# [365]	train-mlogloss:0.477399	test-mlogloss:0.544469
# [366]	train-mlogloss:0.477163	test-mlogloss:0.544448
# [367]	train-mlogloss:0.476919	test-mlogloss:0.544429
# [368]	train-mlogloss:0.476734	test-mlogloss:0.544328
# [369]	train-mlogloss:0.476475	test-mlogloss:0.544287
# [370]	train-mlogloss:0.476181	test-mlogloss:0.544203
# [371]	train-mlogloss:0.47596	test-mlogloss:0.544136

# %%
#features_to_use.append('manager_skill')
#categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
#features_to_use.extend(categorical)
#features_to_use.extend(['diff_price','diff_price_per_bed','diff_price_per_bath','diff_price_per_room'])

#====================================================================        
"""feature engineerings for the categorical features"""

train_set, test_set =manager_skill_eval(train_df,test_df,\
unrank_threshold = mini_ranking)


#fill substitute the small size values by their mean
for f in categorical:
    train_set,test_set  = singleValueConvert(train_set,test_set,f,mini_ranking)

    if train_set[f].dtype=='object':
        #print(f)
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(train_df[f])+list(test_df[f]))
        train_set[f] = lbl.transform(list(train_set[f].values))
        test_set[f] = lbl.transform(list(test_set[f].values))

addAvgDiff(train_set,test_set,nn=15)

#===================================================================

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=243)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point251-nndiff.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:123: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
