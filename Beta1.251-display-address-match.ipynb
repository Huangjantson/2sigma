# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss,accuracy_score
from sklearn.cross_validation import KFold
import re
import string
from collections import defaultdict, Counter

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, \
     seed_val=0, early_stop = 20,num_rounds=10000, eta = 0.1, max_depth = 6):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = eta
    param['max_depth'] = max_depth
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist,\
        early_stopping_rounds=early_stop)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    
    return street
    
#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column,minimum_size=5):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    return df1, df2

def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

# %%
#functions for features
def featureList(train_df,test_df,limit = 0.001):
    #acquiring the feature lists
    features_in_train = train_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    features_in_test = test_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    
    filtered_features_in_train = features_in_train[features_in_train > limit*len(train_df)]
    filtered_features_in_test = features_in_test[features_in_test > limit*len(test_df)]
    accept_list = set(filtered_features_in_train.index).union(set(filtered_features_in_test.index))
    return accept_list

def featureMapping(train_df,test_df,feature_list):
    for feature in feature_list:
        #add the feature column for both
        #if feature in the row, then set the value for (row,feature) to 1
        train_df['with_'+feature]=train_df['features'].apply(lambda x : 1 if feature in x else 0)
        test_df['with_'+feature]=test_df['features'].apply(lambda x : 1 if feature in x else 0)
    return

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  (train_df["price"]*1.0/train_df["bathrooms"]).replace(np.Inf,-1)
train_df["price_per_bed"] = (train_df["price"]*1.0/train_df["bedrooms"]).replace(np.Inf,-1)
train_df["bath_per_bed"] = (train_df["bathrooms"]*1.0/train_df["bedrooms"]).replace(np.Inf,-1)
train_df["price_per_room"] = (train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])).replace(np.Inf,-1)

test_df["price_per_bath"] =  (test_df["price"]*1.0/test_df["bathrooms"]).replace(np.Inf,-1)
test_df["price_per_bed"] = (test_df["price"]*1.0/test_df["bedrooms"]).replace(np.Inf,-1)
test_df["bath_per_bed"] = (test_df["bathrooms"]*1.0/test_df["bedrooms"]).replace(np.Inf,-1)
test_df["price_per_room"] = (test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])).replace(np.Inf,-1)

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
"""
new categorical data append and converting label dummies for future use
"""
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

# %%
#dealing with features

#preprocessing for features
train_df["features"] = train_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_') \
                                                            for i in x])
test_df["features"] = test_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_')\
                                                          for i in x])
#create the accept list
accept_list = list(featureList(train_df,test_df,limit = 0.001))

#map the feature to dummy slots
featureMapping(train_df,test_df,accept_list)
features_to_use.extend(map(lambda x : 'with_'+x,accept_list))

# %%
#use this one to generate the similarity between display and street address
train_df['detail_simi'] = map(similar,train_df["display_address"],train_df["street_address"])
train_df['inSameStreet'] = train_df['detail_simi'].apply(lambda x : 1 if x > 0.5 else 0)
test_df['detail_simi'] = map(similar,test_df["display_address"],test_df["street_address"])
test_df['inSameStreet'] = test_df['detail_simi'].apply(lambda x : 1 if x > 0.5 else 0)

features_to_use.append('inSameStreet')

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

train_df = train_df.fillna(-1)
test_df = test_df.fillna(-1)

# %%
features_to_use.append('manager_skill')
categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
features_to_use.extend(categorical)

# %%
cv_scores = []

mini_ranking = 15

eta = 0.1
md = 4
early = 64

for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #special feature engineering for the trainset
        
        
#====================================================================        
        """feature engineerings for the categorical features"""
        
        dev_set, val_set =manager_skill_eval(dev_set,val_set,\
        unrank_threshold = mini_ranking)
        
        
        #fill substitute the small size values by their mean
        for f in categorical:
            dev_set,val_set  = singleValueConvert(dev_set,val_set,f,mini_ranking)
        
            if dev_set[f].dtype=='object':
                #print(f)
                lbl = preprocessing.LabelEncoder()
                lbl.fit(list(dev_set[f])+list(val_set[f]))
                dev_set[f] = lbl.transform(list(dev_set[f].values))
                val_set[f] = lbl.transform(list(val_set[f].values))
        
#===================================================================
                
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        """
        runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, \
        seed_val=0, early_stop = 20,num_rounds=10000, eta = 0.1, max_depth = 6)
        """        
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,\
        feature_names=features_to_use,early_stop=100,
        num_rounds = 20000, eta = eta,max_depth = 7)
        
        #using rf for feature choosing
        #model = ensemble.RandomForestClassifier(500,random_state = 42,max_depth = 30\
        #                                        ,class_weight='balanced')
        #model.fit(dev_X,dev_y)
        #preds = model.predict_proba(val_X)
        #pred = model.predict(val_X)
            
        cv_scores.append(log_loss(val_y, preds))
        break
print cv_scores
#print accuracy_score(val_y,pred)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# [0]	train-mlogloss:1.03334	test-mlogloss:1.03657
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.976014	test-mlogloss:0.981768
# [2]	train-mlogloss:0.926441	test-mlogloss:0.934753
# [3]	train-mlogloss:0.884728	test-mlogloss:0.895334
# [4]	train-mlogloss:0.847608	test-mlogloss:0.860455
# [5]	train-mlogloss:0.815293	test-mlogloss:0.830604
# [6]	train-mlogloss:0.787764	test-mlogloss:0.804605
# [7]	train-mlogloss:0.763158	test-mlogloss:0.78179
# [8]	train-mlogloss:0.742325	test-mlogloss:0.761995
# [9]	train-mlogloss:0.722178	test-mlogloss:0.743503
# [10]	train-mlogloss:0.70373	test-mlogloss:0.726747
# [11]	train-mlogloss:0.686998	test-mlogloss:0.711836
# [12]	train-mlogloss:0.671849	test-mlogloss:0.698665
# [13]	train-mlogloss:0.658748	test-mlogloss:0.68697
# [14]	train-mlogloss:0.646415	test-mlogloss:0.676319
# [15]	train-mlogloss:0.635263	test-mlogloss:0.666661
# [16]	train-mlogloss:0.625802	test-mlogloss:0.658687
# [17]	train-mlogloss:0.616762	test-mlogloss:0.65124
# [18]	train-mlogloss:0.608069	test-mlogloss:0.644007
# [19]	train-mlogloss:0.600806	test-mlogloss:0.637996
# [20]	train-mlogloss:0.593901	test-mlogloss:0.63245
# [21]	train-mlogloss:0.587017	test-mlogloss:0.627151
# [22]	train-mlogloss:0.580695	test-mlogloss:0.622342
# [23]	train-mlogloss:0.574575	test-mlogloss:0.617751
# [24]	train-mlogloss:0.569785	test-mlogloss:0.614051
# [25]	train-mlogloss:0.564809	test-mlogloss:0.610259
# [26]	train-mlogloss:0.560329	test-mlogloss:0.607134
# [27]	train-mlogloss:0.556631	test-mlogloss:0.604315
# [28]	train-mlogloss:0.552936	test-mlogloss:0.601609
# [29]	train-mlogloss:0.54916	test-mlogloss:0.598784
# [30]	train-mlogloss:0.545569	test-mlogloss:0.596413
# [31]	train-mlogloss:0.542289	test-mlogloss:0.594078
# [32]	train-mlogloss:0.538925	test-mlogloss:0.591881
# [33]	train-mlogloss:0.535836	test-mlogloss:0.589979
# [34]	train-mlogloss:0.532819	test-mlogloss:0.587973
# [35]	train-mlogloss:0.529874	test-mlogloss:0.585923
# [36]	train-mlogloss:0.526796	test-mlogloss:0.584073
# [37]	train-mlogloss:0.524649	test-mlogloss:0.582778
# [38]	train-mlogloss:0.522538	test-mlogloss:0.581479
# [39]	train-mlogloss:0.520136	test-mlogloss:0.580404
# [40]	train-mlogloss:0.518041	test-mlogloss:0.579214
# [41]	train-mlogloss:0.51613	test-mlogloss:0.578109
# [42]	train-mlogloss:0.513914	test-mlogloss:0.576909
# [43]	train-mlogloss:0.512223	test-mlogloss:0.575826
# [44]	train-mlogloss:0.510339	test-mlogloss:0.574872
# [45]	train-mlogloss:0.50804	test-mlogloss:0.573534
# [46]	train-mlogloss:0.506192	test-mlogloss:0.572608
# [47]	train-mlogloss:0.504284	test-mlogloss:0.571536
# [48]	train-mlogloss:0.50262	test-mlogloss:0.570803
# [49]	train-mlogloss:0.500755	test-mlogloss:0.56985
# [50]	train-mlogloss:0.499168	test-mlogloss:0.569048
# [51]	train-mlogloss:0.497957	test-mlogloss:0.568407
# [52]	train-mlogloss:0.496432	test-mlogloss:0.567608
# [53]	train-mlogloss:0.494986	test-mlogloss:0.567081
# [54]	train-mlogloss:0.493089	test-mlogloss:0.566199
# [55]	train-mlogloss:0.491596	test-mlogloss:0.565509
# [56]	train-mlogloss:0.4898	test-mlogloss:0.564758
# [57]	train-mlogloss:0.48856	test-mlogloss:0.564101
# [58]	train-mlogloss:0.486573	test-mlogloss:0.563342
# [59]	train-mlogloss:0.485246	test-mlogloss:0.562459
# [60]	train-mlogloss:0.483498	test-mlogloss:0.561901
# [61]	train-mlogloss:0.481991	test-mlogloss:0.561339
# [62]	train-mlogloss:0.48031	test-mlogloss:0.560714
# [63]	train-mlogloss:0.478218	test-mlogloss:0.560022
# [64]	train-mlogloss:0.477134	test-mlogloss:0.559569
# [65]	train-mlogloss:0.475964	test-mlogloss:0.559104
# [66]	train-mlogloss:0.475161	test-mlogloss:0.558701
# [67]	train-mlogloss:0.474061	test-mlogloss:0.558246
# [68]	train-mlogloss:0.472961	test-mlogloss:0.557877
# [69]	train-mlogloss:0.471593	test-mlogloss:0.557476
# [70]	train-mlogloss:0.470312	test-mlogloss:0.556943
# [71]	train-mlogloss:0.468859	test-mlogloss:0.556523
# [72]	train-mlogloss:0.46759	test-mlogloss:0.556199
# [73]	train-mlogloss:0.466457	test-mlogloss:0.555883
# [74]	train-mlogloss:0.465134	test-mlogloss:0.55556
# [75]	train-mlogloss:0.463989	test-mlogloss:0.555152
# [76]	train-mlogloss:0.462919	test-mlogloss:0.554913
# [77]	train-mlogloss:0.461856	test-mlogloss:0.554492
# [78]	train-mlogloss:0.460152	test-mlogloss:0.553699
# [79]	train-mlogloss:0.458795	test-mlogloss:0.55345
# [80]	train-mlogloss:0.457661	test-mlogloss:0.553088
# [81]	train-mlogloss:0.456508	test-mlogloss:0.552855
# [82]	train-mlogloss:0.455532	test-mlogloss:0.552652
# [83]	train-mlogloss:0.454406	test-mlogloss:0.552241
# [84]	train-mlogloss:0.45319	test-mlogloss:0.551932
# [85]	train-mlogloss:0.452108	test-mlogloss:0.55163
# [86]	train-mlogloss:0.451055	test-mlogloss:0.551263
# [87]	train-mlogloss:0.449572	test-mlogloss:0.550726
# [88]	train-mlogloss:0.448481	test-mlogloss:0.550464
# [89]	train-mlogloss:0.446962	test-mlogloss:0.550167
# [90]	train-mlogloss:0.445698	test-mlogloss:0.549986
# [91]	train-mlogloss:0.444666	test-mlogloss:0.549728
# [92]	train-mlogloss:0.443536	test-mlogloss:0.549385
# [93]	train-mlogloss:0.442292	test-mlogloss:0.549042
# [94]	train-mlogloss:0.441195	test-mlogloss:0.548705
# [95]	train-mlogloss:0.440252	test-mlogloss:0.548392
# [96]	train-mlogloss:0.439506	test-mlogloss:0.548151
# [97]	train-mlogloss:0.438384	test-mlogloss:0.547982
# [98]	train-mlogloss:0.437274	test-mlogloss:0.547747
# [99]	train-mlogloss:0.436366	test-mlogloss:0.547683
# [100]	train-mlogloss:0.435301	test-mlogloss:0.54754
# [101]	train-mlogloss:0.434525	test-mlogloss:0.547247
# [102]	train-mlogloss:0.433489	test-mlogloss:0.546887
# [103]	train-mlogloss:0.432835	test-mlogloss:0.546764
# [104]	train-mlogloss:0.431556	test-mlogloss:0.546585
# [105]	train-mlogloss:0.429963	test-mlogloss:0.546003
# [106]	train-mlogloss:0.429194	test-mlogloss:0.545753
# [107]	train-mlogloss:0.428382	test-mlogloss:0.545446
# [108]	train-mlogloss:0.42735	test-mlogloss:0.545356
# [109]	train-mlogloss:0.426399	test-mlogloss:0.54525
# [110]	train-mlogloss:0.425565	test-mlogloss:0.545036
# [111]	train-mlogloss:0.424726	test-mlogloss:0.544862
# [112]	train-mlogloss:0.423925	test-mlogloss:0.544701
# [113]	train-mlogloss:0.422688	test-mlogloss:0.544585
# [114]	train-mlogloss:0.422171	test-mlogloss:0.544519
# [115]	train-mlogloss:0.420997	test-mlogloss:0.544393
# [116]	train-mlogloss:0.420084	test-mlogloss:0.544059
# [117]	train-mlogloss:0.419466	test-mlogloss:0.543951
# [118]	train-mlogloss:0.418468	test-mlogloss:0.543929
# [119]	train-mlogloss:0.417462	test-mlogloss:0.543712
# [120]	train-mlogloss:0.416481	test-mlogloss:0.543519
# [121]	train-mlogloss:0.415823	test-mlogloss:0.543537
# [122]	train-mlogloss:0.41478	test-mlogloss:0.543493
# [123]	train-mlogloss:0.413414	test-mlogloss:0.543242
# [124]	train-mlogloss:0.412283	test-mlogloss:0.543054
# [125]	train-mlogloss:0.411471	test-mlogloss:0.542974
# [126]	train-mlogloss:0.410912	test-mlogloss:0.543016
# [127]	train-mlogloss:0.41009	test-mlogloss:0.542997
# [128]	train-mlogloss:0.409361	test-mlogloss:0.542901
# [129]	train-mlogloss:0.408393	test-mlogloss:0.542897
# [130]	train-mlogloss:0.407506	test-mlogloss:0.542718
# [131]	train-mlogloss:0.406748	test-mlogloss:0.542866
# [132]	train-mlogloss:0.405728	test-mlogloss:0.542678
# [133]	train-mlogloss:0.404815	test-mlogloss:0.542371
# [134]	train-mlogloss:0.40389	test-mlogloss:0.54224
# [135]	train-mlogloss:0.403419	test-mlogloss:0.5422
# [136]	train-mlogloss:0.402678	test-mlogloss:0.5421
# [137]	train-mlogloss:0.401752	test-mlogloss:0.541873
# [138]	train-mlogloss:0.400655	test-mlogloss:0.541752
# [139]	train-mlogloss:0.400145	test-mlogloss:0.541764
# [140]	train-mlogloss:0.39904	test-mlogloss:0.541719
# [141]	train-mlogloss:0.397929	test-mlogloss:0.541619
# [142]	train-mlogloss:0.396991	test-mlogloss:0.541449
# [143]	train-mlogloss:0.396288	test-mlogloss:0.541461
# [144]	train-mlogloss:0.395364	test-mlogloss:0.541474
# [145]	train-mlogloss:0.394757	test-mlogloss:0.541489
# [146]	train-mlogloss:0.393964	test-mlogloss:0.541441
# [147]	train-mlogloss:0.393027	test-mlogloss:0.541398
# [148]	train-mlogloss:0.392345	test-mlogloss:0.541417
# [149]	train-mlogloss:0.391783	test-mlogloss:0.541334
# [150]	train-mlogloss:0.390774	test-mlogloss:0.541065
# [151]	train-mlogloss:0.389755	test-mlogloss:0.540936
# [152]	train-mlogloss:0.389056	test-mlogloss:0.54092
# [153]	train-mlogloss:0.388407	test-mlogloss:0.54084
# [154]	train-mlogloss:0.387678	test-mlogloss:0.540867
# [155]	train-mlogloss:0.386708	test-mlogloss:0.540856
# [156]	train-mlogloss:0.385589	test-mlogloss:0.540824
# [157]	train-mlogloss:0.384738	test-mlogloss:0.540759
# [158]	train-mlogloss:0.383981	test-mlogloss:0.540803
# [159]	train-mlogloss:0.383107	test-mlogloss:0.540825
# [160]	train-mlogloss:0.382425	test-mlogloss:0.540757
# [161]	train-mlogloss:0.381805	test-mlogloss:0.540865
# [162]	train-mlogloss:0.380662	test-mlogloss:0.540811
# [163]	train-mlogloss:0.379721	test-mlogloss:0.540798
# [164]	train-mlogloss:0.378999	test-mlogloss:0.540719
# [165]	train-mlogloss:0.378179	test-mlogloss:0.540707
# [166]	train-mlogloss:0.377669	test-mlogloss:0.540694
# [167]	train-mlogloss:0.37707	test-mlogloss:0.540621
# [168]	train-mlogloss:0.37635	test-mlogloss:0.540603
# [169]	train-mlogloss:0.375256	test-mlogloss:0.540504
# [170]	train-mlogloss:0.37451	test-mlogloss:0.540552
# [171]	train-mlogloss:0.373833	test-mlogloss:0.540393
# [172]	train-mlogloss:0.373026	test-mlogloss:0.540483
# [173]	train-mlogloss:0.37227	test-mlogloss:0.540199
# [174]	train-mlogloss:0.371548	test-mlogloss:0.54033
# [175]	train-mlogloss:0.370877	test-mlogloss:0.540218
# [176]	train-mlogloss:0.370381	test-mlogloss:0.540332
# [177]	train-mlogloss:0.370052	test-mlogloss:0.540302
# [178]	train-mlogloss:0.369198	test-mlogloss:0.540193
# [179]	train-mlogloss:0.368512	test-mlogloss:0.540127
# [180]	train-mlogloss:0.36788	test-mlogloss:0.540125
# [181]	train-mlogloss:0.367279	test-mlogloss:0.540255
# [182]	train-mlogloss:0.366676	test-mlogloss:0.540237
# [183]	train-mlogloss:0.366021	test-mlogloss:0.540256
# [184]	train-mlogloss:0.365492	test-mlogloss:0.540267
# [185]	train-mlogloss:0.364999	test-mlogloss:0.540227
# [186]	train-mlogloss:0.364225	test-mlogloss:0.540186
# [187]	train-mlogloss:0.363534	test-mlogloss:0.540281
# [188]	train-mlogloss:0.362872	test-mlogloss:0.540249
# [189]	train-mlogloss:0.362293	test-mlogloss:0.540313
# [190]	train-mlogloss:0.361879	test-mlogloss:0.540356
# [191]	train-mlogloss:0.36122	test-mlogloss:0.540338
# [192]	train-mlogloss:0.360449	test-mlogloss:0.540334
# [193]	train-mlogloss:0.359705	test-mlogloss:0.540299
# [194]	train-mlogloss:0.359066	test-mlogloss:0.540149
# [195]	train-mlogloss:0.358396	test-mlogloss:0.54003
# [196]	train-mlogloss:0.357753	test-mlogloss:0.539948
# [197]	train-mlogloss:0.356687	test-mlogloss:0.539877
# [198]	train-mlogloss:0.356078	test-mlogloss:0.539844
# [199]	train-mlogloss:0.355431	test-mlogloss:0.539798
# [200]	train-mlogloss:0.35497	test-mlogloss:0.539823
# [201]	train-mlogloss:0.354433	test-mlogloss:0.539834
# [202]	train-mlogloss:0.353761	test-mlogloss:0.539837
# [203]	train-mlogloss:0.353236	test-mlogloss:0.539862
# [204]	train-mlogloss:0.352807	test-mlogloss:0.539906
# [205]	train-mlogloss:0.352071	test-mlogloss:0.53986
# [206]	train-mlogloss:0.351275	test-mlogloss:0.539878
# [207]	train-mlogloss:0.350548	test-mlogloss:0.539805
# [208]	train-mlogloss:0.350147	test-mlogloss:0.5399
# [209]	train-mlogloss:0.349332	test-mlogloss:0.539882
# [210]	train-mlogloss:0.348639	test-mlogloss:0.539807
# [211]	train-mlogloss:0.34787	test-mlogloss:0.539781
# [212]	train-mlogloss:0.346849	test-mlogloss:0.539703
# [213]	train-mlogloss:0.346328	test-mlogloss:0.539765
# [214]	train-mlogloss:0.345704	test-mlogloss:0.539807
# [215]	train-mlogloss:0.344868	test-mlogloss:0.539805
# [216]	train-mlogloss:0.344052	test-mlogloss:0.539752
# [217]	train-mlogloss:0.343349	test-mlogloss:0.539854
# [218]	train-mlogloss:0.342641	test-mlogloss:0.539839
# [219]	train-mlogloss:0.342034	test-mlogloss:0.53979
# [220]	train-mlogloss:0.341476	test-mlogloss:0.539514
# [221]	train-mlogloss:0.340815	test-mlogloss:0.539479
# [222]	train-mlogloss:0.340157	test-mlogloss:0.539475
# [223]	train-mlogloss:0.339403	test-mlogloss:0.539463
# [224]	train-mlogloss:0.338959	test-mlogloss:0.53934
# [225]	train-mlogloss:0.338317	test-mlogloss:0.539375
# [226]	train-mlogloss:0.337616	test-mlogloss:0.539426
# [227]	train-mlogloss:0.337039	test-mlogloss:0.539389
# [228]	train-mlogloss:0.336611	test-mlogloss:0.539369
# [229]	train-mlogloss:0.335708	test-mlogloss:0.539431
# [230]	train-mlogloss:0.334793	test-mlogloss:0.53929
# [231]	train-mlogloss:0.334146	test-mlogloss:0.539196
# [232]	train-mlogloss:0.33353	test-mlogloss:0.539305
# [233]	train-mlogloss:0.332982	test-mlogloss:0.539324
# [234]	train-mlogloss:0.33245	test-mlogloss:0.539215
# [235]	train-mlogloss:0.331458	test-mlogloss:0.539262
# [236]	train-mlogloss:0.330775	test-mlogloss:0.539222
# [237]	train-mlogloss:0.32997	test-mlogloss:0.539194
# [238]	train-mlogloss:0.329348	test-mlogloss:0.539264
# [239]	train-mlogloss:0.328891	test-mlogloss:0.53927
# [240]	train-mlogloss:0.328298	test-mlogloss:0.53926
# [241]	train-mlogloss:0.327474	test-mlogloss:0.539326
# [242]	train-mlogloss:0.327113	test-mlogloss:0.539298
# [243]	train-mlogloss:0.326539	test-mlogloss:0.539294
# [244]	train-mlogloss:0.326184	test-mlogloss:0.539306
# [245]	train-mlogloss:0.325467	test-mlogloss:0.539328
# [246]	train-mlogloss:0.324834	test-mlogloss:0.539269
# [247]	train-mlogloss:0.324237	test-mlogloss:0.539336
# [248]	train-mlogloss:0.323814	test-mlogloss:0.539268
# [249]	train-mlogloss:0.32325	test-mlogloss:0.539199
# [250]	train-mlogloss:0.322553	test-mlogloss:0.539185
# [251]	train-mlogloss:0.321776	test-mlogloss:0.539118
# [252]	train-mlogloss:0.321351	test-mlogloss:0.539215
# [253]	train-mlogloss:0.320588	test-mlogloss:0.539108
# [254]	train-mlogloss:0.319971	test-mlogloss:0.539159
# [255]	train-mlogloss:0.319131	test-mlogloss:0.539129
# [256]	train-mlogloss:0.318399	test-mlogloss:0.539278
# [257]	train-mlogloss:0.317837	test-mlogloss:0.539245
# [258]	train-mlogloss:0.31732	test-mlogloss:0.53927
# [259]	train-mlogloss:0.316774	test-mlogloss:0.539222
# [260]	train-mlogloss:0.316085	test-mlogloss:0.539186
# [261]	train-mlogloss:0.315546	test-mlogloss:0.539229
# [262]	train-mlogloss:0.315006	test-mlogloss:0.539339
# [263]	train-mlogloss:0.314572	test-mlogloss:0.539342
# [264]	train-mlogloss:0.313863	test-mlogloss:0.539298
# [265]	train-mlogloss:0.313115	test-mlogloss:0.539411
# [266]	train-mlogloss:0.312432	test-mlogloss:0.539339
# [267]	train-mlogloss:0.311685	test-mlogloss:0.539347
# [268]	train-mlogloss:0.311102	test-mlogloss:0.539442
# [269]	train-mlogloss:0.31063	test-mlogloss:0.539462
# [270]	train-mlogloss:0.310044	test-mlogloss:0.539378
# [271]	train-mlogloss:0.309379	test-mlogloss:0.5394
# [272]	train-mlogloss:0.308919	test-mlogloss:0.539483
# [273]	train-mlogloss:0.308354	test-mlogloss:0.539546
# [274]	train-mlogloss:0.307662	test-mlogloss:0.539554
# [275]	train-mlogloss:0.306949	test-mlogloss:0.539539
# [276]	train-mlogloss:0.306218	test-mlogloss:0.539592
# [277]	train-mlogloss:0.305418	test-mlogloss:0.539551
# [278]	train-mlogloss:0.30459	test-mlogloss:0.539631
# [279]	train-mlogloss:0.303869	test-mlogloss:0.539549
# [280]	train-mlogloss:0.303316	test-mlogloss:0.539643
# [281]	train-mlogloss:0.302823	test-mlogloss:0.5397
# [282]	train-mlogloss:0.302398	test-mlogloss:0.539865
# [283]	train-mlogloss:0.301951	test-mlogloss:0.540043
# [284]	train-mlogloss:0.301229	test-mlogloss:0.540145
# [285]	train-mlogloss:0.300941	test-mlogloss:0.540126
# [286]	train-mlogloss:0.300376	test-mlogloss:0.540158
# [287]	train-mlogloss:0.29992	test-mlogloss:0.540158
# [288]	train-mlogloss:0.299498	test-mlogloss:0.54018
# [289]	train-mlogloss:0.299058	test-mlogloss:0.540188
# [290]	train-mlogloss:0.298659	test-mlogloss:0.540276
# [291]	train-mlogloss:0.298247	test-mlogloss:0.540355
# [292]	train-mlogloss:0.297567	test-mlogloss:0.540389
# [293]	train-mlogloss:0.296932	test-mlogloss:0.540433
# [294]	train-mlogloss:0.296292	test-mlogloss:0.540429
# [295]	train-mlogloss:0.295664	test-mlogloss:0.540616
# [296]	train-mlogloss:0.295104	test-mlogloss:0.540603
# [297]	train-mlogloss:0.294535	test-mlogloss:0.540654
# [298]	train-mlogloss:0.293982	test-mlogloss:0.540783
# [299]	train-mlogloss:0.29331	test-mlogloss:0.540758
# [300]	train-mlogloss:0.292835	test-mlogloss:0.540772
# [301]	train-mlogloss:0.292351	test-mlogloss:0.540831
# [302]	train-mlogloss:0.291925	test-mlogloss:0.540804
# [303]	train-mlogloss:0.291102	test-mlogloss:0.540953
# [304]	train-mlogloss:0.290415	test-mlogloss:0.541028
# [305]	train-mlogloss:0.290123	test-mlogloss:0.541114
# [306]	train-mlogloss:0.289567	test-mlogloss:0.541266
# [307]	train-mlogloss:0.289245	test-mlogloss:0.541302
# [308]	train-mlogloss:0.288737	test-mlogloss:0.541366
# [309]	train-mlogloss:0.288106	test-mlogloss:0.541492
# [310]	train-mlogloss:0.287512	test-mlogloss:0.541492
# [311]	train-mlogloss:0.287041	test-mlogloss:0.541499
# [312]	train-mlogloss:0.286379	test-mlogloss:0.54162
# [313]	train-mlogloss:0.285889	test-mlogloss:0.541588
# [314]	train-mlogloss:0.28542	test-mlogloss:0.541665
# [315]	train-mlogloss:0.284976	test-mlogloss:0.541694
# [316]	train-mlogloss:0.284633	test-mlogloss:0.541747
# [317]	train-mlogloss:0.284238	test-mlogloss:0.541727
# [318]	train-mlogloss:0.28391	test-mlogloss:0.541801
# [319]	train-mlogloss:0.283423	test-mlogloss:0.541875
# [320]	train-mlogloss:0.282871	test-mlogloss:0.541904
# [321]	train-mlogloss:0.282448	test-mlogloss:0.541934
# [322]	train-mlogloss:0.282051	test-mlogloss:0.541918
# [323]	train-mlogloss:0.281639	test-mlogloss:0.542009
# [324]	train-mlogloss:0.281237	test-mlogloss:0.542067
# [325]	train-mlogloss:0.280659	test-mlogloss:0.542076
# [326]	train-mlogloss:0.28024	test-mlogloss:0.542152
# [327]	train-mlogloss:0.279764	test-mlogloss:0.542213
# [328]	train-mlogloss:0.279441	test-mlogloss:0.542186
# [329]	train-mlogloss:0.278974	test-mlogloss:0.542257
# [330]	train-mlogloss:0.278597	test-mlogloss:0.542408
# [331]	train-mlogloss:0.277929	test-mlogloss:0.542501
# [332]	train-mlogloss:0.277591	test-mlogloss:0.542683
# [333]	train-mlogloss:0.2771	test-mlogloss:0.542846
# [334]	train-mlogloss:0.276471	test-mlogloss:0.542926
# [335]	train-mlogloss:0.276054	test-mlogloss:0.543011
# [336]	train-mlogloss:0.275761	test-mlogloss:0.542961
# [337]	train-mlogloss:0.275447	test-mlogloss:0.542907
# [338]	train-mlogloss:0.275028	test-mlogloss:0.542951
# [339]	train-mlogloss:0.274494	test-mlogloss:0.543043
# [340]	train-mlogloss:0.273842	test-mlogloss:0.543053
# [341]	train-mlogloss:0.273292	test-mlogloss:0.543104
# [342]	train-mlogloss:0.272619	test-mlogloss:0.543217
# [343]	train-mlogloss:0.272218	test-mlogloss:0.543247
# [344]	train-mlogloss:0.271771	test-mlogloss:0.543297
# [345]	train-mlogloss:0.271196	test-mlogloss:0.54325
# [346]	train-mlogloss:0.270589	test-mlogloss:0.543544
# [347]	train-mlogloss:0.270246	test-mlogloss:0.543643
# [348]	train-mlogloss:0.269772	test-mlogloss:0.543576
# [349]	train-mlogloss:0.269274	test-mlogloss:0.543583
# [350]	train-mlogloss:0.268674	test-mlogloss:0.543671
# [351]	train-mlogloss:0.268202	test-mlogloss:0.543706
# [352]	train-mlogloss:0.267637	test-mlogloss:0.54386
# [353]	train-mlogloss:0.267157	test-mlogloss:0.543849
# Stopping. Best iteration:
# [253]	train-mlogloss:0.320588	test-mlogloss:0.539108
#
# [0.54384922436108296]

# %%
#features_to_use.append('manager_skill')
#categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
#features_to_use.extend(categorical)
#features_to_use.extend(['diff_price','diff_price_per_bed','diff_price_per_bath','diff_price_per_room'])

#====================================================================        
"""feature engineerings for the categorical features"""

train_set, test_set =manager_skill_eval(train_df,test_df,\
unrank_threshold = mini_ranking)


#fill substitute the small size values by their mean
for f in categorical:
    train_set,test_set  = singleValueConvert(train_set,test_set,f,mini_ranking)

    if train_set[f].dtype=='object':
        #print(f)
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(train_df[f])+list(test_df[f]))
        train_set[f] = lbl.transform(list(train_set[f].values))
        test_set[f] = lbl.transform(list(test_set[f].values))

addAvgDiff(train_set,test_set,nn=15)

#===================================================================

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=243)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point251-nndiff.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:123: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
dev_set.columns
# Out:
# Index([      u'bathrooms',        u'bedrooms',     u'building_id',
#                u'created',     u'description', u'display_address',
#               u'features',  u'interest_level',        u'latitude',
#             u'listing_id',
#        ...
#             u'with_patio',     u'with_no_fee',  u'with_bike_room',
#            u'detail_simi',    u'inSameStreet',         u'ManHigh',
#                 u'ManLow',       u'ManMedium',           u'count',
#          u'manager_skill'],
#       dtype='object', length=123)

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
weight_list = []
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
    weight_list.append((key,weight[key]))
sorted(weight_list,key = lambda x:x[1],reverse = True)
# Out:
# [('listing_id', 0.08439382103167603),
#  ('price', 0.07902628329511378),
#  ('latitude', 0.07849708943376257),
#  ('longitude', 0.0742635385429529),
#  ('price_per_room', 0.07249955900511554),
#  ('num_description_words', 0.061991280901141546),
#  ('manager_skill', 0.05491016304210871),
#  ('price_per_bed', 0.046090265352921905),
#  ('manager_id', 0.044704281430335405),
#  ('created_day', 0.041629917092961724),
#  ('street_name', 0.03701837058690119),
#  ('building_id', 0.036161580525665905),
#  ('created_hour', 0.034775596603079405),
#  ('num_photos', 0.034573998941612276),
#  ('num_features', 0.03326361414207595),
#  ('display_address', 0.03149963460423859),
#  ('street_address', 0.017261799763122747),
#  ('bedrooms', 0.010079883073356348),
#  ('with_no_fee', 0.009903485119572612),
#  ('bath_per_bed', 0.007988307335634907),
#  ('bathrooms', 0.007610311720384044),
#  ('with_furnished', 0.005947131013280246),
#  ('with_hardwood_floors', 0.005543935690345992),
#  ('with_laundry_in_building', 0.004813144167527657),
#  ('created_month', 0.0044099488445934025),
#  ('with_laundry_in_unit', 0.003905954690925585),
#  ('with_cats_allowed', 0.003905954690925585),
#  ('with_pre_war', 0.003805155860192022),
#  ('inSameStreet', 0.003779956152508631),
#  ('with_dogs_allowed', 0.00375475644482524),
#  ('with_elevator', 0.0035027593679913312),
#  ('with_exclusive', 0.0032759619988408134),
#  ('with_dishwasher', 0.003124763752740468),
#  ('with_outdoor_space', 0.0030995640450570774),
#  ('with_fitness_center', 0.0028475669682231685),
#  ('with_doorman', 0.0027971675528563867),
#  ('with_dining_room', 0.002343572814555351),
#  ('with_roof_deck', 0.0023183731068719604),
#  ('with_reduced_fee', 0.0022679736915051786),
#  ('with_terrace', 0.002217574276138397),
#  ('with_common_outdoor_space', 0.0021419751530882243),
#  ('with_new_construction', 0.001965577199304488),
#  ('with_high_speed_internet', 0.0019403774916210972),
#  ('with_garden/patio', 0.0019403774916210972),
#  ('with_swimming_pool', 0.001789179245520752),
#  ('with_balcony', 0.001789179245520752),
#  ('with_loft', 0.001789179245520752),
#  ('with_private_outdoor_space', 0.0017387798301539703),
#  ('with_parking_space', 0.001562381876370234),
#  ('with_wheelchair_access', 0.0015371821686868431),
#  ('with_actual_apt._photos', 0.0012347856764861529),
#  ('with_simplex', 0.0011087871380691984),
#  ('with_multi_level', 0.000982788599652244),
#  ('with_storage', 0.0008315903535518988),
#  ('with_hardwood', 0.0008315903535518988),
#  ('with_prewar', 0.0007559912305017262),
#  ('with_short_term_allowed', 0.0007307915228183353),
#  ('with_fireplace', 0.0007307915228183353),
#  ('with_garage', 0.0005543935690345992),
#  ('with_renovated', 0.0004535947383010357),
#  ('with_dryer_in_unit', 0.00040319532293425395),
#  ('with_outdoor_areas', 0.0003779956152508631),
#  ('with_high_ceilings', 0.0003779956152508631),
#  ('with_high_ceiling', 0.0003779956152508631),
#  ('with_stainless_steel_appliances', 0.0003527959075674722),
#  ('with_live_in_super', 0.00032759619988408133),
#  ('with_green_building', 0.00032759619988408133),
#  ('with_on_site_laundry', 0.0003023964922006905),
#  ('with_newly_renovated', 0.0003023964922006905),
#  ('with_pets_on_approval', 0.0003023964922006905),
#  ('with_view', 0.0002519970768339087),
#  ('with_lowrise', 0.0002519970768339087),
#  ('with_residents_lounge', 0.0002519970768339087),
#  ('with_pool', 0.0002519970768339087),
#  ('with_eat_in_kitchen', 0.00022679736915051784),
#  ('with_duplex', 0.00022679736915051784),
#  ('with_light', 0.00020159766146712698),
#  ('with_publicoutdoor', 0.00020159766146712698),
#  ('with_no_pets', 0.00020159766146712698),
#  ('with_granite_kitchen', 0.00020159766146712698),
#  ('with_laundry', 0.0001763979537837361),
#  ('with_walk_in_closet(s)', 0.0001763979537837361),
#  ('with_central_a/c', 0.00015119824610034525),
#  ('with_laundry_room', 0.00015119824610034525),
#  ('with_washer/dryer', 0.00015119824610034525),
#  ('with_concierge', 0.00012599853841695435),
#  ('with_washer_in_unit', 0.00012599853841695435),
#  ('with_live_in_superintendent', 0.00012599853841695435),
#  ('with_on_site_garage', 0.00010079883073356349),
#  ('with_parking', 0.00010079883073356349),
#  ('with_gym', 7.559912305017262e-05),
#  ('with_gym/fitness', 7.559912305017262e-05),
#  ('with_roofdeck', 7.559912305017262e-05),
#  ('with_exposed_brick', 5.0399415366781744e-05),
#  ('with_childrens_playroom', 5.0399415366781744e-05),
#  ('with_common_parking/garage', 5.0399415366781744e-05),
#  ('with_valet', 5.0399415366781744e-05),
#  ('with_bike_room', 5.0399415366781744e-05),
#  ('with_highrise', 5.0399415366781744e-05),
#  ('with_patio', 5.0399415366781744e-05),
#  ('with_garden', 2.5199707683390872e-05),
#  ('with_private_balcony', 2.5199707683390872e-05),
#  ('with_common_roof_deck', 2.5199707683390872e-05),
#  ('with_luxury_building', 2.5199707683390872e-05)]

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
gain_list = []

total = sum(gain.values())
for key in gain:
    gain[key] = gain[key]*1.0/total
    gain_list.append((key,gain[key]))
sorted(gain_list,key = lambda x:x[1],reverse = True)
# Out:
# [('manager_skill', 0.049392727319142814),
#  ('with_simplex', 0.04136660999328723),
#  ('with_lowrise', 0.029874770980645254),
#  ('with_no_fee', 0.024893364742531798),
#  ('price', 0.01965290936412053),
#  ('building_id', 0.01895487074210514),
#  ('with_hardwood_floors', 0.018863977736613125),
#  ('with_hardwood', 0.01800210529058778),
#  ('price_per_room', 0.015516410813803495),
#  ('price_per_bed', 0.015484434926590396),
#  ('bathrooms', 0.015226203061178615),
#  ('with_furnished', 0.015194967200289218),
#  ('with_reduced_fee', 0.01405390899890974),
#  ('with_on_site_garage', 0.013220669724705125),
#  ('with_exclusive', 0.012864391643415943),
#  ('with_prewar', 0.012853004260313503),
#  ('created_hour', 0.01280027006240633),
#  ('with_actual_apt._photos', 0.012404827888959653),
#  ('with_laundry_in_building', 0.012261014408437573),
#  ('with_high_ceiling', 0.01201320100813396),
#  ('bedrooms', 0.011481638275033502),
#  ('num_photos', 0.011470492300623407),
#  ('latitude', 0.01097000961324589),
#  ('with_private_outdoor_space', 0.010944167684783328),
#  ('longitude', 0.010938950999621593),
#  ('with_stainless_steel_appliances', 0.010001405907513798),
#  ('with_short_term_allowed', 0.009893110998641914),
#  ('inSameStreet', 0.009689770058821691),
#  ('with_common_outdoor_space', 0.009602587094120147),
#  ('with_renovated', 0.009579541297965285),
#  ('street_address', 0.009481164018473725),
#  ('display_address', 0.009307630126902874),
#  ('with_washer_in_unit', 0.009181312735761421),
#  ('with_fireplace', 0.00915074100186616),
#  ('with_outdoor_areas', 0.009147301587932475),
#  ('num_features', 0.009145083713608322),
#  ('with_high_ceilings', 0.008962408807835958),
#  ('bath_per_bed', 0.008899439393424805),
#  ('with_laundry', 0.008837438929129632),
#  ('with_dryer_in_unit', 0.008774368300638817),
#  ('with_parking_space', 0.00876097322109931),
#  ('street_name', 0.008718837155152178),
#  ('with_laundry_in_unit', 0.008705529604439767),
#  ('manager_id', 0.00860536316740857),
#  ('with_fitness_center', 0.008587223525934632),
#  ('with_green_building', 0.008548545488632597),
#  ('with_doorman', 0.00850533536622296),
#  ('with_swimming_pool', 0.008457868748572416),
#  ('listing_id', 0.008390389727567947),
#  ('with_pre_war', 0.008277685647990972),
#  ('with_wheelchair_access', 0.008191022144210969),
#  ('with_dogs_allowed', 0.008165203631141758),
#  ('with_concierge', 0.008123362527107325),
#  ('with_high_speed_internet', 0.008093521344393175),
#  ('with_on_site_laundry', 0.008059433609640882),
#  ('num_description_words', 0.007963838373731543),
#  ('with_multi_level', 0.007842425740000764),
#  ('with_balcony', 0.007812833255772438),
#  ('with_outdoor_space', 0.00781207494208026),
#  ('with_walk_in_closet(s)', 0.007809510641631868),
#  ('with_common_parking/garage', 0.007740821597452517),
#  ('with_light', 0.007699159067807665),
#  ('with_roof_deck', 0.00769641323418997),
#  ('with_terrace', 0.0076620789103765945),
#  ('with_storage', 0.00749386318884803),
#  ('with_garden/patio', 0.007470491971629922),
#  ('with_cats_allowed', 0.007245998427276143),
#  ('with_dining_room', 0.007106622463099328),
#  ('with_loft', 0.007071210498920375),
#  ('with_central_a/c', 0.0070381260509247475),
#  ('with_granite_kitchen', 0.006985036669256223),
#  ('with_live_in_super', 0.0069015251687762165),
#  ('with_garage', 0.006862410775950264),
#  ('created_day', 0.006816942782813682),
#  ('with_pool', 0.006755582702054992),
#  ('with_publicoutdoor', 0.006721362504694648),
#  ('with_dishwasher', 0.006695238553408588),
#  ('with_elevator', 0.006584458463065714),
#  ('with_live_in_superintendent', 0.0065621164192489635),
#  ('with_new_construction', 0.006554283270510654),
#  ('with_newly_renovated', 0.006377694117936173),
#  ('created_month', 0.006374197525766293),
#  ('with_washer/dryer', 0.006362196103731714),
#  ('with_gym/fitness', 0.0062789830632000426),
#  ('with_residents_lounge', 0.006184393672956278),
#  ('with_valet', 0.0061753625830072625),
#  ('with_luxury_building', 0.006045933982249496),
#  ('with_duplex', 0.005996257730783722),
#  ('with_view', 0.005965254192737395),
#  ('with_laundry_room', 0.005343806664952403),
#  ('with_no_pets', 0.005325768202992523),
#  ('with_highrise', 0.005264161953796617),
#  ('with_pets_on_approval', 0.0051156319644839274),
#  ('with_eat_in_kitchen', 0.00504858024774104),
#  ('with_private_balcony', 0.004771848899304174),
#  ('with_bike_room', 0.0047698494583438165),
#  ('with_common_roof_deck', 0.0045258707259464345),
#  ('with_childrens_playroom', 0.004132536569924404),
#  ('with_gym', 0.0041107692600890035),
#  ('with_patio', 0.0036131963303941183),
#  ('with_parking', 0.0025846721665779534),
#  ('with_exposed_brick', 0.0009290491599243684),
#  ('with_roofdeck', 0.0007741346020464967),
#  ('with_garden', 0.000481927225954701)]

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
