# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
import re
import string

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.01
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    #nth -> n
    #nst -> n
    #nrd -> n
    #nnd -> n
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    

    return street
    
def getStreetNumber(address):
    #get building id in the front, return -1 if their isn't
    pattern = re.compile('^([\d-]*)([\s]+)')
    try:
        number = pattern.search(address).group(1)
        return int(number)
    except:
        return -1

#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    return df1, df2

# %%
def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

train_df["street_number"] = train_df["street_address"].apply(getStreetNumber)
test_df["street_number"] = test_df["street_address"].apply(getStreetNumber)

#features_to_use.append("street_number")

# %%
#dealing feature with categorical features 
"""
display_address 8826    
building_id        7585   =》many zeros in this feature
manager_id   3481
street_address 15358 =》will be 3800 if no numbers in it 
"""
categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
#running and getting the cv from xgboost
cv_scores = []
#K-FOLD already defined.If not ,use
#KF=KFold(len(train_X),5,shuffle=True,random_state = 42)
for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #apply the function for createing some featues
        dev_set, val_set =manager_skill_eval(dev_set,val_set)
        #features_to_use.extend(['ManHigh','ManLow', 'ManMedium','manager_skill'])
        features_to_use.append('manager_skill')
        
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# [0]	train-mlogloss:1.03253	test-mlogloss:1.03549
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.978559	test-mlogloss:0.983166
# [2]	train-mlogloss:0.929212	test-mlogloss:0.936377
# [3]	train-mlogloss:0.88844	test-mlogloss:0.897597
# [4]	train-mlogloss:0.854287	test-mlogloss:0.864752
# [5]	train-mlogloss:0.823735	test-mlogloss:0.836217
# [6]	train-mlogloss:0.795339	test-mlogloss:0.809205
# [7]	train-mlogloss:0.770389	test-mlogloss:0.78617
# [8]	train-mlogloss:0.747566	test-mlogloss:0.764999
# [9]	train-mlogloss:0.728947	test-mlogloss:0.747569
# [10]	train-mlogloss:0.711398	test-mlogloss:0.731564
# [11]	train-mlogloss:0.695337	test-mlogloss:0.71674
# [12]	train-mlogloss:0.681654	test-mlogloss:0.704101
# [13]	train-mlogloss:0.668332	test-mlogloss:0.692376
# [14]	train-mlogloss:0.656822	test-mlogloss:0.682102
# [15]	train-mlogloss:0.646447	test-mlogloss:0.672657
# [16]	train-mlogloss:0.637353	test-mlogloss:0.664023
# [17]	train-mlogloss:0.628911	test-mlogloss:0.656533
# [18]	train-mlogloss:0.620988	test-mlogloss:0.649907
# [19]	train-mlogloss:0.614203	test-mlogloss:0.64386
# [20]	train-mlogloss:0.607675	test-mlogloss:0.638256
# [21]	train-mlogloss:0.601538	test-mlogloss:0.633067
# [22]	train-mlogloss:0.596293	test-mlogloss:0.628585
# [23]	train-mlogloss:0.591015	test-mlogloss:0.623969
# [24]	train-mlogloss:0.586027	test-mlogloss:0.620163
# [25]	train-mlogloss:0.581392	test-mlogloss:0.616703
# [26]	train-mlogloss:0.577322	test-mlogloss:0.613512
# [27]	train-mlogloss:0.573529	test-mlogloss:0.610813
# [28]	train-mlogloss:0.570079	test-mlogloss:0.608398
# [29]	train-mlogloss:0.566916	test-mlogloss:0.6061
# [30]	train-mlogloss:0.563953	test-mlogloss:0.603864
# [31]	train-mlogloss:0.560855	test-mlogloss:0.601651
# [32]	train-mlogloss:0.557928	test-mlogloss:0.599586
# [33]	train-mlogloss:0.555038	test-mlogloss:0.597598
# [34]	train-mlogloss:0.552428	test-mlogloss:0.59587
# [35]	train-mlogloss:0.549926	test-mlogloss:0.594182
# [36]	train-mlogloss:0.547753	test-mlogloss:0.592882
# [37]	train-mlogloss:0.545478	test-mlogloss:0.591432
# [38]	train-mlogloss:0.543491	test-mlogloss:0.590134
# [39]	train-mlogloss:0.541366	test-mlogloss:0.588839
# [40]	train-mlogloss:0.539575	test-mlogloss:0.587605
# [41]	train-mlogloss:0.537522	test-mlogloss:0.586451
# [42]	train-mlogloss:0.535961	test-mlogloss:0.585592
# [43]	train-mlogloss:0.534271	test-mlogloss:0.584478
# [44]	train-mlogloss:0.532769	test-mlogloss:0.583506
# [45]	train-mlogloss:0.531432	test-mlogloss:0.582858
# [46]	train-mlogloss:0.529809	test-mlogloss:0.582023
# [47]	train-mlogloss:0.528543	test-mlogloss:0.581498
# [48]	train-mlogloss:0.527377	test-mlogloss:0.580968
# [49]	train-mlogloss:0.525972	test-mlogloss:0.580243
# [50]	train-mlogloss:0.524761	test-mlogloss:0.579814
# [51]	train-mlogloss:0.523473	test-mlogloss:0.579393
# [52]	train-mlogloss:0.521895	test-mlogloss:0.578511
# [53]	train-mlogloss:0.520925	test-mlogloss:0.578016
# [54]	train-mlogloss:0.51968	test-mlogloss:0.577375
# [55]	train-mlogloss:0.51813	test-mlogloss:0.576435
# [56]	train-mlogloss:0.516933	test-mlogloss:0.575775
# [57]	train-mlogloss:0.515718	test-mlogloss:0.575181
# [58]	train-mlogloss:0.514543	test-mlogloss:0.574601
# [59]	train-mlogloss:0.513172	test-mlogloss:0.57395
# [60]	train-mlogloss:0.511827	test-mlogloss:0.573323
# [61]	train-mlogloss:0.510853	test-mlogloss:0.572877
# [62]	train-mlogloss:0.509711	test-mlogloss:0.572585
# [63]	train-mlogloss:0.508568	test-mlogloss:0.57223
# [64]	train-mlogloss:0.507342	test-mlogloss:0.571769
# [65]	train-mlogloss:0.505959	test-mlogloss:0.571229
# [66]	train-mlogloss:0.504825	test-mlogloss:0.57076
# [67]	train-mlogloss:0.503782	test-mlogloss:0.570387
# [68]	train-mlogloss:0.502389	test-mlogloss:0.569938
# [69]	train-mlogloss:0.501413	test-mlogloss:0.569675
# [70]	train-mlogloss:0.500113	test-mlogloss:0.569097
# [71]	train-mlogloss:0.498843	test-mlogloss:0.568548
# [72]	train-mlogloss:0.497709	test-mlogloss:0.568216
# [73]	train-mlogloss:0.496706	test-mlogloss:0.567852
# [74]	train-mlogloss:0.495368	test-mlogloss:0.56725
# [75]	train-mlogloss:0.494487	test-mlogloss:0.566975
# [76]	train-mlogloss:0.493225	test-mlogloss:0.566473
# [77]	train-mlogloss:0.492159	test-mlogloss:0.566198
# [78]	train-mlogloss:0.491347	test-mlogloss:0.565971
# [79]	train-mlogloss:0.490695	test-mlogloss:0.565986
# [80]	train-mlogloss:0.489816	test-mlogloss:0.565628
# [81]	train-mlogloss:0.489115	test-mlogloss:0.565435
# [82]	train-mlogloss:0.488083	test-mlogloss:0.565242
# [83]	train-mlogloss:0.486891	test-mlogloss:0.564779
# [84]	train-mlogloss:0.486063	test-mlogloss:0.564542
# [85]	train-mlogloss:0.485081	test-mlogloss:0.56423
# [86]	train-mlogloss:0.484077	test-mlogloss:0.564007
# [87]	train-mlogloss:0.483385	test-mlogloss:0.56382
# [88]	train-mlogloss:0.482558	test-mlogloss:0.563394
# [89]	train-mlogloss:0.481619	test-mlogloss:0.562932
# [90]	train-mlogloss:0.480814	test-mlogloss:0.562713
# [91]	train-mlogloss:0.480056	test-mlogloss:0.562482
# [92]	train-mlogloss:0.478867	test-mlogloss:0.56215
# [93]	train-mlogloss:0.478072	test-mlogloss:0.56197
# [94]	train-mlogloss:0.477018	test-mlogloss:0.561673
# [95]	train-mlogloss:0.475882	test-mlogloss:0.561392
# [96]	train-mlogloss:0.475068	test-mlogloss:0.561179
# [97]	train-mlogloss:0.47448	test-mlogloss:0.561232
# [98]	train-mlogloss:0.473677	test-mlogloss:0.56088
# [99]	train-mlogloss:0.472818	test-mlogloss:0.560752
# [100]	train-mlogloss:0.471792	test-mlogloss:0.560404
# [101]	train-mlogloss:0.470863	test-mlogloss:0.560092
# [102]	train-mlogloss:0.469958	test-mlogloss:0.559804
# [103]	train-mlogloss:0.469103	test-mlogloss:0.559514
# [104]	train-mlogloss:0.467998	test-mlogloss:0.559269
# [105]	train-mlogloss:0.467385	test-mlogloss:0.5592
# [106]	train-mlogloss:0.466513	test-mlogloss:0.559136
# [107]	train-mlogloss:0.465649	test-mlogloss:0.559009
# [108]	train-mlogloss:0.465114	test-mlogloss:0.558826
# [109]	train-mlogloss:0.464282	test-mlogloss:0.558562
# [110]	train-mlogloss:0.463499	test-mlogloss:0.558485
# [111]	train-mlogloss:0.462923	test-mlogloss:0.558359
# [112]	train-mlogloss:0.462111	test-mlogloss:0.558241
# [113]	train-mlogloss:0.461319	test-mlogloss:0.55818
# [114]	train-mlogloss:0.460665	test-mlogloss:0.558073
# [115]	train-mlogloss:0.46008	test-mlogloss:0.558099
# [116]	train-mlogloss:0.459307	test-mlogloss:0.557906
# [117]	train-mlogloss:0.458456	test-mlogloss:0.557722
# [118]	train-mlogloss:0.45789	test-mlogloss:0.557681
# [119]	train-mlogloss:0.457172	test-mlogloss:0.55756
# [120]	train-mlogloss:0.456558	test-mlogloss:0.557438
# [121]	train-mlogloss:0.456207	test-mlogloss:0.55743
# [122]	train-mlogloss:0.455591	test-mlogloss:0.557319
# [123]	train-mlogloss:0.455068	test-mlogloss:0.557316
# [124]	train-mlogloss:0.454229	test-mlogloss:0.55728
# [125]	train-mlogloss:0.453504	test-mlogloss:0.557263
# [126]	train-mlogloss:0.45275	test-mlogloss:0.557052
# [127]	train-mlogloss:0.451856	test-mlogloss:0.556736
# [128]	train-mlogloss:0.451448	test-mlogloss:0.556664
# [129]	train-mlogloss:0.450928	test-mlogloss:0.556518
# [130]	train-mlogloss:0.450267	test-mlogloss:0.556423
# [131]	train-mlogloss:0.449657	test-mlogloss:0.556366
# [132]	train-mlogloss:0.449108	test-mlogloss:0.556219
# [133]	train-mlogloss:0.448148	test-mlogloss:0.556129
# [134]	train-mlogloss:0.44729	test-mlogloss:0.555836
# [135]	train-mlogloss:0.446395	test-mlogloss:0.555683
# [136]	train-mlogloss:0.445865	test-mlogloss:0.55558
# [137]	train-mlogloss:0.445175	test-mlogloss:0.555453
# [138]	train-mlogloss:0.444522	test-mlogloss:0.555381
# [139]	train-mlogloss:0.443505	test-mlogloss:0.555207
# [140]	train-mlogloss:0.442835	test-mlogloss:0.554884
# [141]	train-mlogloss:0.44202	test-mlogloss:0.554736
# [142]	train-mlogloss:0.441275	test-mlogloss:0.554754
# [143]	train-mlogloss:0.44066	test-mlogloss:0.554652
# [144]	train-mlogloss:0.440069	test-mlogloss:0.554651
# [145]	train-mlogloss:0.43921	test-mlogloss:0.554569
# [146]	train-mlogloss:0.438796	test-mlogloss:0.554567
# [147]	train-mlogloss:0.438066	test-mlogloss:0.554658
# [148]	train-mlogloss:0.437469	test-mlogloss:0.554523
# [149]	train-mlogloss:0.43675	test-mlogloss:0.554453
# [150]	train-mlogloss:0.436314	test-mlogloss:0.554269
# [151]	train-mlogloss:0.435655	test-mlogloss:0.554086
# [152]	train-mlogloss:0.435073	test-mlogloss:0.553941
# [153]	train-mlogloss:0.434428	test-mlogloss:0.553906
# [154]	train-mlogloss:0.43371	test-mlogloss:0.553914
# [155]	train-mlogloss:0.433277	test-mlogloss:0.553915
# [156]	train-mlogloss:0.432758	test-mlogloss:0.553938
# [157]	train-mlogloss:0.43214	test-mlogloss:0.55381
# [158]	train-mlogloss:0.431532	test-mlogloss:0.553777
# [159]	train-mlogloss:0.430954	test-mlogloss:0.553721
# [160]	train-mlogloss:0.430325	test-mlogloss:0.553634
# [161]	train-mlogloss:0.429668	test-mlogloss:0.553594
# [162]	train-mlogloss:0.428887	test-mlogloss:0.55346
# [163]	train-mlogloss:0.428209	test-mlogloss:0.553324
# [164]	train-mlogloss:0.427686	test-mlogloss:0.55331
# [165]	train-mlogloss:0.427103	test-mlogloss:0.553289
# [166]	train-mlogloss:0.426292	test-mlogloss:0.55317
# [167]	train-mlogloss:0.425647	test-mlogloss:0.553182
# [168]	train-mlogloss:0.42489	test-mlogloss:0.55316
# [169]	train-mlogloss:0.424313	test-mlogloss:0.553037
# [170]	train-mlogloss:0.423656	test-mlogloss:0.553106
# [171]	train-mlogloss:0.423205	test-mlogloss:0.553046
# [172]	train-mlogloss:0.422655	test-mlogloss:0.553066
# [173]	train-mlogloss:0.422087	test-mlogloss:0.552989
# [174]	train-mlogloss:0.421327	test-mlogloss:0.552947
# [175]	train-mlogloss:0.420951	test-mlogloss:0.552961
# [176]	train-mlogloss:0.420379	test-mlogloss:0.552916
# [177]	train-mlogloss:0.419923	test-mlogloss:0.552941
# [178]	train-mlogloss:0.41927	test-mlogloss:0.552922
# [179]	train-mlogloss:0.418649	test-mlogloss:0.552885
# [180]	train-mlogloss:0.417936	test-mlogloss:0.552917
# [181]	train-mlogloss:0.417143	test-mlogloss:0.552892
# [182]	train-mlogloss:0.416407	test-mlogloss:0.552859
# [183]	train-mlogloss:0.415825	test-mlogloss:0.552995
# [184]	train-mlogloss:0.415141	test-mlogloss:0.552945
# [185]	train-mlogloss:0.414566	test-mlogloss:0.552959
# [186]	train-mlogloss:0.413964	test-mlogloss:0.552761
# [187]	train-mlogloss:0.4135	test-mlogloss:0.552675
# [188]	train-mlogloss:0.412883	test-mlogloss:0.552578
# [189]	train-mlogloss:0.412296	test-mlogloss:0.552551
# [190]	train-mlogloss:0.411625	test-mlogloss:0.552586
# [191]	train-mlogloss:0.411053	test-mlogloss:0.552613
# [192]	train-mlogloss:0.410599	test-mlogloss:0.552619
# [193]	train-mlogloss:0.409887	test-mlogloss:0.552532
# [194]	train-mlogloss:0.409347	test-mlogloss:0.55257
# [195]	train-mlogloss:0.408815	test-mlogloss:0.552409
# [196]	train-mlogloss:0.40827	test-mlogloss:0.55228
# [197]	train-mlogloss:0.407524	test-mlogloss:0.552402
# [198]	train-mlogloss:0.407094	test-mlogloss:0.552376
# [199]	train-mlogloss:0.406594	test-mlogloss:0.552307
# [200]	train-mlogloss:0.405935	test-mlogloss:0.552277
# [201]	train-mlogloss:0.405527	test-mlogloss:0.552282
# [202]	train-mlogloss:0.404982	test-mlogloss:0.55245
# [203]	train-mlogloss:0.404564	test-mlogloss:0.55236
# [204]	train-mlogloss:0.404062	test-mlogloss:0.552356
# [205]	train-mlogloss:0.403343	test-mlogloss:0.552246
# [206]	train-mlogloss:0.402776	test-mlogloss:0.552292
# [207]	train-mlogloss:0.40208	test-mlogloss:0.552242
# [208]	train-mlogloss:0.401402	test-mlogloss:0.552126
# [209]	train-mlogloss:0.400856	test-mlogloss:0.552118
# [210]	train-mlogloss:0.400371	test-mlogloss:0.552044
# [211]	train-mlogloss:0.399847	test-mlogloss:0.55201
# [212]	train-mlogloss:0.399186	test-mlogloss:0.551985
# [213]	train-mlogloss:0.398641	test-mlogloss:0.552123
# [214]	train-mlogloss:0.398185	test-mlogloss:0.552223
# [215]	train-mlogloss:0.39758	test-mlogloss:0.552275
# [216]	train-mlogloss:0.397187	test-mlogloss:0.552277
# [217]	train-mlogloss:0.396744	test-mlogloss:0.552337
# [218]	train-mlogloss:0.396287	test-mlogloss:0.552367
# [219]	train-mlogloss:0.395773	test-mlogloss:0.552462
# [220]	train-mlogloss:0.395137	test-mlogloss:0.552432
# [221]	train-mlogloss:0.394598	test-mlogloss:0.552328
# [222]	train-mlogloss:0.394005	test-mlogloss:0.552344
# [223]	train-mlogloss:0.393518	test-mlogloss:0.552368
# [224]	train-mlogloss:0.393069	test-mlogloss:0.552381
# [225]	train-mlogloss:0.392618	test-mlogloss:0.552339
# [226]	train-mlogloss:0.392151	test-mlogloss:0.552183
# [227]	train-mlogloss:0.39176	test-mlogloss:0.552214
# [228]	train-mlogloss:0.391244	test-mlogloss:0.552183
# [229]	train-mlogloss:0.390642	test-mlogloss:0.552191
# [230]	train-mlogloss:0.390031	test-mlogloss:0.552228
# [231]	train-mlogloss:0.389484	test-mlogloss:0.552128
# [232]	train-mlogloss:0.388931	test-mlogloss:0.552116
# [233]	train-mlogloss:0.388313	test-mlogloss:0.552069
# [234]	train-mlogloss:0.387922	test-mlogloss:0.552126
# [235]	train-mlogloss:0.38742	test-mlogloss:0.552255
# [236]	train-mlogloss:0.386927	test-mlogloss:0.552237
# [237]	train-mlogloss:0.386554	test-mlogloss:0.552224
# [238]	train-mlogloss:0.386091	test-mlogloss:0.552241
# [239]	train-mlogloss:0.385488	test-mlogloss:0.552266
# [240]	train-mlogloss:0.385129	test-mlogloss:0.552221
# [241]	train-mlogloss:0.384749	test-mlogloss:0.552211
# [242]	train-mlogloss:0.384178	test-mlogloss:0.552212
# [243]	train-mlogloss:0.38369	test-mlogloss:0.552315
# [244]	train-mlogloss:0.383238	test-mlogloss:0.552383
# [245]	train-mlogloss:0.382901	test-mlogloss:0.552405
# [246]	train-mlogloss:0.382372	test-mlogloss:0.552408
# [247]	train-mlogloss:0.382045	test-mlogloss:0.55236
# [248]	train-mlogloss:0.381591	test-mlogloss:0.552331
# [249]	train-mlogloss:0.38131	test-mlogloss:0.552285
# [250]	train-mlogloss:0.380778	test-mlogloss:0.552477
# [251]	train-mlogloss:0.380331	test-mlogloss:0.55249
# [252]	train-mlogloss:0.379833	test-mlogloss:0.552483
# [253]	train-mlogloss:0.379173	test-mlogloss:0.55245
# [254]	train-mlogloss:0.378739	test-mlogloss:0.552391
# [255]	train-mlogloss:0.378119	test-mlogloss:0.552506
# [256]	train-mlogloss:0.37775	test-mlogloss:0.552469
# [257]	train-mlogloss:0.37725	test-mlogloss:0.552526
# [258]	train-mlogloss:0.376923	test-mlogloss:0.552604
# [259]	train-mlogloss:0.376351	test-mlogloss:0.552494
# [260]	train-mlogloss:0.375951	test-mlogloss:0.552541
# [261]	train-mlogloss:0.375553	test-mlogloss:0.552525
# [262]	train-mlogloss:0.37504	test-mlogloss:0.552429
# [263]	train-mlogloss:0.37462	test-mlogloss:0.552493
# [264]	train-mlogloss:0.374192	test-mlogloss:0.552476
# [265]	train-mlogloss:0.373736	test-mlogloss:0.552471
# [266]	train-mlogloss:0.373307	test-mlogloss:0.552542
# [267]	train-mlogloss:0.372874	test-mlogloss:0.552588
# [268]	train-mlogloss:0.37235	test-mlogloss:0.552516
# [269]	train-mlogloss:0.371929	test-mlogloss:0.552657
# [270]	train-mlogloss:0.371449	test-mlogloss:0.552665
# [271]	train-mlogloss:0.37098	test-mlogloss:0.552618
# [272]	train-mlogloss:0.370463	test-mlogloss:0.552498
# [273]	train-mlogloss:0.370024	test-mlogloss:0.552364
# [274]	train-mlogloss:0.369517	test-mlogloss:0.552357
# [275]	train-mlogloss:0.369142	test-mlogloss:0.552252
# [276]	train-mlogloss:0.368824	test-mlogloss:0.552155
# [277]	train-mlogloss:0.368418	test-mlogloss:0.552119
# [278]	train-mlogloss:0.367995	test-mlogloss:0.552103
# [279]	train-mlogloss:0.367525	test-mlogloss:0.55209
# [280]	train-mlogloss:0.36704	test-mlogloss:0.552078
# [281]	train-mlogloss:0.366559	test-mlogloss:0.552095
# [282]	train-mlogloss:0.366165	test-mlogloss:0.552094
# [283]	train-mlogloss:0.365591	test-mlogloss:0.55195
# [284]	train-mlogloss:0.364975	test-mlogloss:0.551917
# [285]	train-mlogloss:0.364541	test-mlogloss:0.552074
# [286]	train-mlogloss:0.364136	test-mlogloss:0.552009
# [287]	train-mlogloss:0.363647	test-mlogloss:0.552032
# [288]	train-mlogloss:0.363127	test-mlogloss:0.551915
# [289]	train-mlogloss:0.362781	test-mlogloss:0.551937
# [290]	train-mlogloss:0.362297	test-mlogloss:0.551885
# [291]	train-mlogloss:0.36186	test-mlogloss:0.551815
# [292]	train-mlogloss:0.361456	test-mlogloss:0.551834
# [293]	train-mlogloss:0.361203	test-mlogloss:0.551808
# [294]	train-mlogloss:0.360841	test-mlogloss:0.551841
# [295]	train-mlogloss:0.360301	test-mlogloss:0.55182
# [296]	train-mlogloss:0.359935	test-mlogloss:0.55192
# [297]	train-mlogloss:0.359487	test-mlogloss:0.551907
# [298]	train-mlogloss:0.359087	test-mlogloss:0.55193
# [299]	train-mlogloss:0.358601	test-mlogloss:0.551897
# [300]	train-mlogloss:0.358301	test-mlogloss:0.551881
# [301]	train-mlogloss:0.357912	test-mlogloss:0.551876
# [302]	train-mlogloss:0.357516	test-mlogloss:0.551929
# [303]	train-mlogloss:0.356993	test-mlogloss:0.551769
# [304]	train-mlogloss:0.356629	test-mlogloss:0.551869
# [305]	train-mlogloss:0.356111	test-mlogloss:0.551798
# [306]	train-mlogloss:0.355736	test-mlogloss:0.551805
# [307]	train-mlogloss:0.355351	test-mlogloss:0.551815
# [308]	train-mlogloss:0.354962	test-mlogloss:0.551766
# [309]	train-mlogloss:0.354443	test-mlogloss:0.551842
# [310]	train-mlogloss:0.353897	test-mlogloss:0.551923
# [311]	train-mlogloss:0.353401	test-mlogloss:0.551999
# [312]	train-mlogloss:0.352946	test-mlogloss:0.552009
# [313]	train-mlogloss:0.352449	test-mlogloss:0.552029
# [314]	train-mlogloss:0.352093	test-mlogloss:0.552101
# [315]	train-mlogloss:0.35178	test-mlogloss:0.552122
# [316]	train-mlogloss:0.351315	test-mlogloss:0.552111
# [317]	train-mlogloss:0.35095	test-mlogloss:0.552085
# [318]	train-mlogloss:0.350475	test-mlogloss:0.552084
# [319]	train-mlogloss:0.350182	test-mlogloss:0.55205
# [320]	train-mlogloss:0.349687	test-mlogloss:0.552016
# [321]	train-mlogloss:0.349167	test-mlogloss:0.552039
# [322]	train-mlogloss:0.348518	test-mlogloss:0.552071
# [323]	train-mlogloss:0.348099	test-mlogloss:0.552149
# [324]	train-mlogloss:0.347536	test-mlogloss:0.552157
# [325]	train-mlogloss:0.347146	test-mlogloss:0.552139
# [326]	train-mlogloss:0.346874	test-mlogloss:0.552178
# [327]	train-mlogloss:0.346382	test-mlogloss:0.552102
# [328]	train-mlogloss:0.345856	test-mlogloss:0.552118
# [329]	train-mlogloss:0.345337	test-mlogloss:0.552074
# [330]	train-mlogloss:0.344815	test-mlogloss:0.552029
# [331]	train-mlogloss:0.344503	test-mlogloss:0.551971
# [332]	train-mlogloss:0.344028	test-mlogloss:0.551992
# [333]	train-mlogloss:0.343541	test-mlogloss:0.552024
# [334]	train-mlogloss:0.343001	test-mlogloss:0.551949
# [335]	train-mlogloss:0.342491	test-mlogloss:0.551949
# [336]	train-mlogloss:0.342144	test-mlogloss:0.55188
# [337]	train-mlogloss:0.341661	test-mlogloss:0.551864
# [338]	train-mlogloss:0.341157	test-mlogloss:0.551763
# [339]	train-mlogloss:0.34077	test-mlogloss:0.551831
# [340]	train-mlogloss:0.340203	test-mlogloss:0.551938
# [341]	train-mlogloss:0.33976	test-mlogloss:0.551982
# [342]	train-mlogloss:0.339227	test-mlogloss:0.552022
# [343]	train-mlogloss:0.338886	test-mlogloss:0.552124
# [344]	train-mlogloss:0.338633	test-mlogloss:0.552176
# [345]	train-mlogloss:0.338191	test-mlogloss:0.552076
# [346]	train-mlogloss:0.337911	test-mlogloss:0.552243
# [347]	train-mlogloss:0.337524	test-mlogloss:0.552229
# [348]	train-mlogloss:0.337192	test-mlogloss:0.552284
# [349]	train-mlogloss:0.336819	test-mlogloss:0.552314
# [350]	train-mlogloss:0.336452	test-mlogloss:0.552303
# [351]	train-mlogloss:0.336056	test-mlogloss:0.552214
# [352]	train-mlogloss:0.335632	test-mlogloss:0.552355
# [353]	train-mlogloss:0.335241	test-mlogloss:0.552364
# [354]	train-mlogloss:0.334723	test-mlogloss:0.552454
# [355]	train-mlogloss:0.334418	test-mlogloss:0.55247
# [356]	train-mlogloss:0.334066	test-mlogloss:0.55247
# [357]	train-mlogloss:0.333468	test-mlogloss:0.55241
# [358]	train-mlogloss:0.333082	test-mlogloss:0.552411
# [359]	train-mlogloss:0.332683	test-mlogloss:0.552413
# [360]	train-mlogloss:0.332378	test-mlogloss:0.55248
# [361]	train-mlogloss:0.331896	test-mlogloss:0.552598
# [362]	train-mlogloss:0.331406	test-mlogloss:0.55271
# [363]	train-mlogloss:0.331094	test-mlogloss:0.552771
# [364]	train-mlogloss:0.330698	test-mlogloss:0.552871
# [365]	train-mlogloss:0.330278	test-mlogloss:0.55292
# [366]	train-mlogloss:0.329756	test-mlogloss:0.552842
# [367]	train-mlogloss:0.32944	test-mlogloss:0.552907
# [368]	train-mlogloss:0.329056	test-mlogloss:0.552971
# [369]	train-mlogloss:0.328638	test-mlogloss:0.55311
# [370]	train-mlogloss:0.328182	test-mlogloss:0.553182
# [371]	train-mlogloss:0.327822	test-mlogloss:0.553223
# [372]	train-mlogloss:0.327593	test-mlogloss:0.553263
# [373]	train-mlogloss:0.327226	test-mlogloss:0.553271
# [374]	train-mlogloss:0.326808	test-mlogloss:0.553228
# [375]	train-mlogloss:0.326405	test-mlogloss:0.553188
# [376]	train-mlogloss:0.326001	test-mlogloss:0.553196
# [377]	train-mlogloss:0.325746	test-mlogloss:0.553224
# [378]	train-mlogloss:0.325341	test-mlogloss:0.553236
# [379]	train-mlogloss:0.324969	test-mlogloss:0.553248
# [380]	train-mlogloss:0.324504	test-mlogloss:0.55332
# [381]	train-mlogloss:0.324151	test-mlogloss:0.553258
# [382]	train-mlogloss:0.32385	test-mlogloss:0.553304
# [383]	train-mlogloss:0.323386	test-mlogloss:0.553246
# [384]	train-mlogloss:0.322955	test-mlogloss:0.553256
# [385]	train-mlogloss:0.322545	test-mlogloss:0.553476
# [386]	train-mlogloss:0.322198	test-mlogloss:0.553462
# [387]	train-mlogloss:0.321869	test-mlogloss:0.553439
# [388]	train-mlogloss:0.321567	test-mlogloss:0.553459
# [389]	train-mlogloss:0.321221	test-mlogloss:0.553366
# [390]	train-mlogloss:0.320776	test-mlogloss:0.553531
# [391]	train-mlogloss:0.320379	test-mlogloss:0.553587
# [392]	train-mlogloss:0.3199	test-mlogloss:0.553516
# [393]	train-mlogloss:0.319416	test-mlogloss:0.55358
# [394]	train-mlogloss:0.318984	test-mlogloss:0.553593
# [395]	train-mlogloss:0.318652	test-mlogloss:0.553603
# [396]	train-mlogloss:0.318264	test-mlogloss:0.553716
# [397]	train-mlogloss:0.317999	test-mlogloss:0.553743
# [398]	train-mlogloss:0.317575	test-mlogloss:0.553859
# [399]	train-mlogloss:0.317129	test-mlogloss:0.553737
# [400]	train-mlogloss:0.316817	test-mlogloss:0.553712
# [401]	train-mlogloss:0.316432	test-mlogloss:0.553669
# [402]	train-mlogloss:0.316167	test-mlogloss:0.553696
# [403]	train-mlogloss:0.315768	test-mlogloss:0.553806
# [404]	train-mlogloss:0.315394	test-mlogloss:0.553842
# [405]	train-mlogloss:0.314921	test-mlogloss:0.553911
# [406]	train-mlogloss:0.31459	test-mlogloss:0.554
# [407]	train-mlogloss:0.314259	test-mlogloss:0.55404
# [408]	train-mlogloss:0.313834	test-mlogloss:0.553985
# [409]	train-mlogloss:0.313523	test-mlogloss:0.554178
# [410]	train-mlogloss:0.31333	test-mlogloss:0.554151
# [411]	train-mlogloss:0.312892	test-mlogloss:0.554175
# [412]	train-mlogloss:0.312468	test-mlogloss:0.554178
# [413]	train-mlogloss:0.312161	test-mlogloss:0.554221
# [414]	train-mlogloss:0.31183	test-mlogloss:0.554242
# [415]	train-mlogloss:0.311532	test-mlogloss:0.554197
# [416]	train-mlogloss:0.311272	test-mlogloss:0.554174
# [417]	train-mlogloss:0.310966	test-mlogloss:0.554231
# [418]	train-mlogloss:0.310545	test-mlogloss:0.554284
# [419]	train-mlogloss:0.310134	test-mlogloss:0.554303
# [420]	train-mlogloss:0.309794	test-mlogloss:0.554352
# [421]	train-mlogloss:0.309489	test-mlogloss:0.554454
# [422]	train-mlogloss:0.309181	test-mlogloss:0.554409
# [423]	train-mlogloss:0.308868	test-mlogloss:0.554409
# [424]	train-mlogloss:0.308521	test-mlogloss:0.554482
# [425]	train-mlogloss:0.308191	test-mlogloss:0.554454
# [426]	train-mlogloss:0.307607	test-mlogloss:0.554494
# [427]	train-mlogloss:0.307287	test-mlogloss:0.554469
# [428]	train-mlogloss:0.306969	test-mlogloss:0.554428
# [429]	train-mlogloss:0.306552	test-mlogloss:0.554501
# [430]	train-mlogloss:0.30622	test-mlogloss:0.554511
# [431]	train-mlogloss:0.30585	test-mlogloss:0.55447
# [432]	train-mlogloss:0.305442	test-mlogloss:0.554557
# [433]	train-mlogloss:0.305128	test-mlogloss:0.55466
# [434]	train-mlogloss:0.30482	test-mlogloss:0.554635
# [435]	train-mlogloss:0.304603	test-mlogloss:0.554563
# [436]	train-mlogloss:0.30422	test-mlogloss:0.554642
# [437]	train-mlogloss:0.303908	test-mlogloss:0.554641
# [438]	train-mlogloss:0.303629	test-mlogloss:0.554646
# Stopping. Best iteration:
# [338]	train-mlogloss:0.341157	test-mlogloss:0.551763
#
# [0.55464567746219717]

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
