# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
import re
import string

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    
    return street
    
#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column,minimum_size=5):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    return df1, df2

def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

#encoded by sorted value
def hcc_sorting(train_df,test_df,feature,label=None,randomize=None):
    """
    sort the hcc feature by their prior on label then encode
    the train df should be with its labels get dummied
    
    return the list of all the possible features in order
    """
    if label ==None:
        train_df['tempScore'] = 2*train_df['high']+train_df['medium']
    
    label = 'tempScore'
    #get dummies for the 
    grouped  = train_df.groupby(feature)[label].agg({'size':'size','mean':'mean'})
    #unrankedMean = grouped.ix[grouped['size']<unrank_threshold,'mean'].mean()
    #grouped.ix[grouped['size']<unrank_threshold,'mean'] = unrankedMean
    grouped = grouped.reset_index()

    #get the values for the test set
    test_groupBy=test_df[feature].value_counts().to_frame().reset_index()
    test_groupBy.columns = [feature,'testSize']

    #merge together and reset the mean
    totalFeature = grouped.merge(test_groupBy,on = feature, how='outer').fillna(0)

    rankedMean = np.mean(grouped['mean'])

    #reset those train size 0 to the ranked mean
    totalFeature.ix[totalFeature['size']==0,'mean']=rankedMean
    
    #add some random 
    if randomize : 
        totalFeature['mean'] *= np.random.uniform(1 - randomize, 1 + randomize, len(totalFeature))

    return list(totalFeature.sort('mean')[feature])

# %%
#functions for features
def featureList(train_df,test_df,limit = 0.01):
    #acquiring the feature lists
    features_in_train = train_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    features_in_train.sort(ascending  = False)
    features_in_test = test_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    features_in_test.sort(ascending  = False)
    
    filtered_features_in_train = features_in_train[features_in_train > limit*len(train_df)]
    filtered_features_in_test = features_in_test[features_in_test > limit*len(test_df)]
    accept_list = set(filtered_features_in_train.index).union(set(filtered_features_in_test.index))
    return accept_list

def featureMapping(train_df,test_df,feature_list):
    for feature in feature_list:
        #add the feature column for both
        #if feature in the row, then set the value for (row,feature) to 1
        train_df['with_'+feature]=train_df['features'].apply(lambda x : 1 if feature in x else 0)
        test_df['with_'+feature]=test_df['features'].apply(lambda x : 1 if feature in x else 0)
    return

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

# %%
#dealing feature with categorical features 
"""
display_address 8826    
building_id        7585   =》many zeros in this feature
manager_id   3481
street_address 15358 =》will be 3800 if no numbers in it 
"""
train_df =train_df.join(pd.get_dummies(train_df[u'interest_level']).astype(int))

categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
for f in categorical:
    #fill substitute the small size values by their mean
    train_df,test_df  = singleValueConvert(train_df,test_df,f)
    if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(hcc_sorting(train_df,test_df,f,randomize = 0.05))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)
# Out:
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:123: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
#dealing with features

#simple preprocessing
train_df["features"] = train_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_') \
                                                            for i in x])
test_df["features"] = test_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_')\
                                                          for i in x])

accept_list = featureList(train_df,test_df,limit = 0.05)
featureMapping(train_df,test_df,accept_list)

features_to_use.extend(map(lambda x : 'with_'+x,accept_list))
# Out:
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
#running and getting the cv from xgboost
cv_scores = []
#K-FOLD already defined.If not ,use
#KF=KFold(len(train_X),5,shuffle=True,random_state = 42)
features_to_use.append('manager_skill')

for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #apply the function for createing some featues
        dev_set, val_set =manager_skill_eval(dev_set,val_set)
        #features_to_use.extend(['ManHigh','ManLow', 'ManMedium','manager_skill'])
        
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# [0]	train-mlogloss:1.0311	test-mlogloss:1.03378
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.975418	test-mlogloss:0.980078
# [2]	train-mlogloss:0.926775	test-mlogloss:0.933647
# [3]	train-mlogloss:0.886439	test-mlogloss:0.894889
# [4]	train-mlogloss:0.850958	test-mlogloss:0.861054
# [5]	train-mlogloss:0.820711	test-mlogloss:0.831891
# [6]	train-mlogloss:0.793956	test-mlogloss:0.80675
# [7]	train-mlogloss:0.768128	test-mlogloss:0.782773
# [8]	train-mlogloss:0.745731	test-mlogloss:0.762107
# [9]	train-mlogloss:0.725356	test-mlogloss:0.743192
# [10]	train-mlogloss:0.7076	test-mlogloss:0.727099
# [11]	train-mlogloss:0.691836	test-mlogloss:0.712913
# [12]	train-mlogloss:0.677161	test-mlogloss:0.699883
# [13]	train-mlogloss:0.664874	test-mlogloss:0.68901
# [14]	train-mlogloss:0.653722	test-mlogloss:0.679155
# [15]	train-mlogloss:0.643421	test-mlogloss:0.670111
# [16]	train-mlogloss:0.633909	test-mlogloss:0.661591
# [17]	train-mlogloss:0.62573	test-mlogloss:0.654404
# [18]	train-mlogloss:0.617903	test-mlogloss:0.647719
# [19]	train-mlogloss:0.61064	test-mlogloss:0.641371
# [20]	train-mlogloss:0.604183	test-mlogloss:0.635712
# [21]	train-mlogloss:0.598204	test-mlogloss:0.630559
# [22]	train-mlogloss:0.592489	test-mlogloss:0.626063
# [23]	train-mlogloss:0.587079	test-mlogloss:0.621735
# [24]	train-mlogloss:0.58199	test-mlogloss:0.617693
# [25]	train-mlogloss:0.577644	test-mlogloss:0.614035
# [26]	train-mlogloss:0.57369	test-mlogloss:0.610961
# [27]	train-mlogloss:0.56985	test-mlogloss:0.608071
# [28]	train-mlogloss:0.566523	test-mlogloss:0.605622
# [29]	train-mlogloss:0.563219	test-mlogloss:0.603009
# [30]	train-mlogloss:0.560101	test-mlogloss:0.600618
# [31]	train-mlogloss:0.557112	test-mlogloss:0.598522
# [32]	train-mlogloss:0.554149	test-mlogloss:0.596538
# [33]	train-mlogloss:0.551543	test-mlogloss:0.594435
# [34]	train-mlogloss:0.549089	test-mlogloss:0.592741
# [35]	train-mlogloss:0.546746	test-mlogloss:0.591146
# [36]	train-mlogloss:0.543964	test-mlogloss:0.589215
# [37]	train-mlogloss:0.541785	test-mlogloss:0.587852
# [38]	train-mlogloss:0.539689	test-mlogloss:0.58662
# [39]	train-mlogloss:0.537515	test-mlogloss:0.585195
# [40]	train-mlogloss:0.535699	test-mlogloss:0.583871
# [41]	train-mlogloss:0.533747	test-mlogloss:0.582501
# [42]	train-mlogloss:0.531874	test-mlogloss:0.581174
# [43]	train-mlogloss:0.530316	test-mlogloss:0.580202
# [44]	train-mlogloss:0.528678	test-mlogloss:0.57916
# [45]	train-mlogloss:0.527255	test-mlogloss:0.57842
# [46]	train-mlogloss:0.525863	test-mlogloss:0.577741
# [47]	train-mlogloss:0.524625	test-mlogloss:0.577095
# [48]	train-mlogloss:0.523039	test-mlogloss:0.576201
# [49]	train-mlogloss:0.52146	test-mlogloss:0.575184
# [50]	train-mlogloss:0.520097	test-mlogloss:0.574458
# [51]	train-mlogloss:0.518695	test-mlogloss:0.573652
# [52]	train-mlogloss:0.517452	test-mlogloss:0.573034
# [53]	train-mlogloss:0.51632	test-mlogloss:0.572429
# [54]	train-mlogloss:0.514834	test-mlogloss:0.571735
# [55]	train-mlogloss:0.513615	test-mlogloss:0.571033
# [56]	train-mlogloss:0.51247	test-mlogloss:0.570447
# [57]	train-mlogloss:0.511597	test-mlogloss:0.570021
# [58]	train-mlogloss:0.510083	test-mlogloss:0.569309
# [59]	train-mlogloss:0.508955	test-mlogloss:0.568757
# [60]	train-mlogloss:0.507671	test-mlogloss:0.568274
# [61]	train-mlogloss:0.506506	test-mlogloss:0.567735
# [62]	train-mlogloss:0.505345	test-mlogloss:0.56714
# [63]	train-mlogloss:0.503989	test-mlogloss:0.566493
# [64]	train-mlogloss:0.502844	test-mlogloss:0.566244
# [65]	train-mlogloss:0.501512	test-mlogloss:0.565529
# [66]	train-mlogloss:0.500517	test-mlogloss:0.564852
# [67]	train-mlogloss:0.499078	test-mlogloss:0.564315
# [68]	train-mlogloss:0.497894	test-mlogloss:0.563826
# [69]	train-mlogloss:0.496465	test-mlogloss:0.563212
# [70]	train-mlogloss:0.495218	test-mlogloss:0.562664
# [71]	train-mlogloss:0.494144	test-mlogloss:0.562252
# [72]	train-mlogloss:0.493132	test-mlogloss:0.561646
# [73]	train-mlogloss:0.492042	test-mlogloss:0.561151
# [74]	train-mlogloss:0.490554	test-mlogloss:0.560437
# [75]	train-mlogloss:0.49002	test-mlogloss:0.560261
# [76]	train-mlogloss:0.489029	test-mlogloss:0.559953
# [77]	train-mlogloss:0.488184	test-mlogloss:0.559713
# [78]	train-mlogloss:0.48709	test-mlogloss:0.559309
# [79]	train-mlogloss:0.486098	test-mlogloss:0.559009
# [80]	train-mlogloss:0.485104	test-mlogloss:0.55882
# [81]	train-mlogloss:0.484443	test-mlogloss:0.558567
# [82]	train-mlogloss:0.483586	test-mlogloss:0.558351
# [83]	train-mlogloss:0.482702	test-mlogloss:0.558076
# [84]	train-mlogloss:0.481808	test-mlogloss:0.557616
# [85]	train-mlogloss:0.480614	test-mlogloss:0.55712
# [86]	train-mlogloss:0.479568	test-mlogloss:0.55657
# [87]	train-mlogloss:0.478852	test-mlogloss:0.556438
# [88]	train-mlogloss:0.47766	test-mlogloss:0.556159
# [89]	train-mlogloss:0.476655	test-mlogloss:0.55581
# [90]	train-mlogloss:0.475923	test-mlogloss:0.555537
# [91]	train-mlogloss:0.475237	test-mlogloss:0.555383
# [92]	train-mlogloss:0.474477	test-mlogloss:0.555264
# [93]	train-mlogloss:0.473419	test-mlogloss:0.555058
# [94]	train-mlogloss:0.47263	test-mlogloss:0.554862
# [95]	train-mlogloss:0.471528	test-mlogloss:0.554561
# [96]	train-mlogloss:0.470863	test-mlogloss:0.554409
# [97]	train-mlogloss:0.469869	test-mlogloss:0.554306
# [98]	train-mlogloss:0.469156	test-mlogloss:0.554083
# [99]	train-mlogloss:0.468345	test-mlogloss:0.553905
# [100]	train-mlogloss:0.467572	test-mlogloss:0.553622
# [101]	train-mlogloss:0.466457	test-mlogloss:0.553319
# [102]	train-mlogloss:0.465589	test-mlogloss:0.553082
# [103]	train-mlogloss:0.464782	test-mlogloss:0.552911
# [104]	train-mlogloss:0.46389	test-mlogloss:0.552803
# [105]	train-mlogloss:0.462939	test-mlogloss:0.552479
# [106]	train-mlogloss:0.462384	test-mlogloss:0.552402
# [107]	train-mlogloss:0.461755	test-mlogloss:0.55231
# [108]	train-mlogloss:0.461171	test-mlogloss:0.552085
# [109]	train-mlogloss:0.46045	test-mlogloss:0.551796
# [110]	train-mlogloss:0.459376	test-mlogloss:0.551406
# [111]	train-mlogloss:0.458358	test-mlogloss:0.551076
# [112]	train-mlogloss:0.457342	test-mlogloss:0.550706
# [113]	train-mlogloss:0.456559	test-mlogloss:0.550397
# [114]	train-mlogloss:0.455893	test-mlogloss:0.550273
# [115]	train-mlogloss:0.455063	test-mlogloss:0.550063
# [116]	train-mlogloss:0.454208	test-mlogloss:0.549904
# [117]	train-mlogloss:0.453325	test-mlogloss:0.549792
# [118]	train-mlogloss:0.452572	test-mlogloss:0.549802
# [119]	train-mlogloss:0.451783	test-mlogloss:0.54976
# [120]	train-mlogloss:0.451116	test-mlogloss:0.549596
# [121]	train-mlogloss:0.450143	test-mlogloss:0.549434
# [122]	train-mlogloss:0.449283	test-mlogloss:0.549334
# [123]	train-mlogloss:0.448731	test-mlogloss:0.549198
# [124]	train-mlogloss:0.447756	test-mlogloss:0.549092
# [125]	train-mlogloss:0.447243	test-mlogloss:0.54906
# [126]	train-mlogloss:0.446515	test-mlogloss:0.548798
# [127]	train-mlogloss:0.445823	test-mlogloss:0.548665
# [128]	train-mlogloss:0.44511	test-mlogloss:0.548604
# [129]	train-mlogloss:0.444331	test-mlogloss:0.54872
# [130]	train-mlogloss:0.443716	test-mlogloss:0.548704
# [131]	train-mlogloss:0.443246	test-mlogloss:0.548616
# [132]	train-mlogloss:0.442531	test-mlogloss:0.548605
# [133]	train-mlogloss:0.442127	test-mlogloss:0.548615
# [134]	train-mlogloss:0.441577	test-mlogloss:0.548478
# [135]	train-mlogloss:0.440988	test-mlogloss:0.548446
# [136]	train-mlogloss:0.440207	test-mlogloss:0.548351
# [137]	train-mlogloss:0.439591	test-mlogloss:0.548306
# [138]	train-mlogloss:0.438823	test-mlogloss:0.548236
# [139]	train-mlogloss:0.438316	test-mlogloss:0.548234
# [140]	train-mlogloss:0.437609	test-mlogloss:0.548045
# [141]	train-mlogloss:0.436939	test-mlogloss:0.547843
# [142]	train-mlogloss:0.435977	test-mlogloss:0.547695
# [143]	train-mlogloss:0.435049	test-mlogloss:0.547471
# [144]	train-mlogloss:0.434281	test-mlogloss:0.547279
# [145]	train-mlogloss:0.43379	test-mlogloss:0.547267
# [146]	train-mlogloss:0.433195	test-mlogloss:0.547214
# [147]	train-mlogloss:0.432532	test-mlogloss:0.547225
# [148]	train-mlogloss:0.432013	test-mlogloss:0.547125
# [149]	train-mlogloss:0.431414	test-mlogloss:0.547082
# [150]	train-mlogloss:0.430787	test-mlogloss:0.547
# [151]	train-mlogloss:0.430325	test-mlogloss:0.546979
# [152]	train-mlogloss:0.429513	test-mlogloss:0.546958
# [153]	train-mlogloss:0.42888	test-mlogloss:0.546856
# [154]	train-mlogloss:0.428322	test-mlogloss:0.546794
# [155]	train-mlogloss:0.427599	test-mlogloss:0.546716
# [156]	train-mlogloss:0.426754	test-mlogloss:0.546427
# [157]	train-mlogloss:0.426161	test-mlogloss:0.54634
# [158]	train-mlogloss:0.425364	test-mlogloss:0.54629
# [159]	train-mlogloss:0.424765	test-mlogloss:0.546212
# [160]	train-mlogloss:0.424119	test-mlogloss:0.546154
# [161]	train-mlogloss:0.423481	test-mlogloss:0.546068
# [162]	train-mlogloss:0.422642	test-mlogloss:0.545988
# [163]	train-mlogloss:0.422013	test-mlogloss:0.545863
# [164]	train-mlogloss:0.42114	test-mlogloss:0.545851
# [165]	train-mlogloss:0.420516	test-mlogloss:0.545832
# [166]	train-mlogloss:0.419863	test-mlogloss:0.545781
# [167]	train-mlogloss:0.419026	test-mlogloss:0.54559
# [168]	train-mlogloss:0.418359	test-mlogloss:0.54561
# [169]	train-mlogloss:0.417656	test-mlogloss:0.545569
# [170]	train-mlogloss:0.417128	test-mlogloss:0.545557
# [171]	train-mlogloss:0.416583	test-mlogloss:0.545586
# [172]	train-mlogloss:0.415959	test-mlogloss:0.545526
# [173]	train-mlogloss:0.415335	test-mlogloss:0.545554
# [174]	train-mlogloss:0.41453	test-mlogloss:0.54547
# [175]	train-mlogloss:0.413874	test-mlogloss:0.545429
# [176]	train-mlogloss:0.413517	test-mlogloss:0.545441
# [177]	train-mlogloss:0.413056	test-mlogloss:0.545426
# [178]	train-mlogloss:0.412379	test-mlogloss:0.545404
# [179]	train-mlogloss:0.411723	test-mlogloss:0.545146
# [180]	train-mlogloss:0.41142	test-mlogloss:0.545137
# [181]	train-mlogloss:0.410986	test-mlogloss:0.545186
# [182]	train-mlogloss:0.410507	test-mlogloss:0.545078
# [183]	train-mlogloss:0.409894	test-mlogloss:0.545106
# [184]	train-mlogloss:0.409393	test-mlogloss:0.545097
# [185]	train-mlogloss:0.408561	test-mlogloss:0.544912
# [186]	train-mlogloss:0.407967	test-mlogloss:0.544868
# [187]	train-mlogloss:0.407221	test-mlogloss:0.544863
# [188]	train-mlogloss:0.406535	test-mlogloss:0.544782
# [189]	train-mlogloss:0.406036	test-mlogloss:0.544648
# [190]	train-mlogloss:0.405377	test-mlogloss:0.544608
# [191]	train-mlogloss:0.404738	test-mlogloss:0.544463
# [192]	train-mlogloss:0.404078	test-mlogloss:0.544289
# [193]	train-mlogloss:0.403552	test-mlogloss:0.544351
# [194]	train-mlogloss:0.403167	test-mlogloss:0.544333
# [195]	train-mlogloss:0.402565	test-mlogloss:0.544351
# [196]	train-mlogloss:0.401966	test-mlogloss:0.544317
# [197]	train-mlogloss:0.401582	test-mlogloss:0.544219
# [198]	train-mlogloss:0.400971	test-mlogloss:0.54404
# [199]	train-mlogloss:0.400431	test-mlogloss:0.544039
# [200]	train-mlogloss:0.400015	test-mlogloss:0.544009
# [201]	train-mlogloss:0.399248	test-mlogloss:0.543911
# [202]	train-mlogloss:0.398721	test-mlogloss:0.543764
# [203]	train-mlogloss:0.398113	test-mlogloss:0.543803
# [204]	train-mlogloss:0.39756	test-mlogloss:0.543749
# [205]	train-mlogloss:0.396996	test-mlogloss:0.543715
# [206]	train-mlogloss:0.396293	test-mlogloss:0.543697
# [207]	train-mlogloss:0.395876	test-mlogloss:0.543536
# [208]	train-mlogloss:0.395145	test-mlogloss:0.543531
# [209]	train-mlogloss:0.39443	test-mlogloss:0.543437
# [210]	train-mlogloss:0.393868	test-mlogloss:0.543363
# [211]	train-mlogloss:0.393293	test-mlogloss:0.5433
# [212]	train-mlogloss:0.392816	test-mlogloss:0.543318
# [213]	train-mlogloss:0.392244	test-mlogloss:0.543303
# [214]	train-mlogloss:0.391663	test-mlogloss:0.543316
# [215]	train-mlogloss:0.391132	test-mlogloss:0.543301
# [216]	train-mlogloss:0.390532	test-mlogloss:0.543464
# [217]	train-mlogloss:0.39017	test-mlogloss:0.543334
# [218]	train-mlogloss:0.389553	test-mlogloss:0.543389
# [219]	train-mlogloss:0.38895	test-mlogloss:0.543298
# [220]	train-mlogloss:0.388551	test-mlogloss:0.543348
# [221]	train-mlogloss:0.388212	test-mlogloss:0.543264
# [222]	train-mlogloss:0.387787	test-mlogloss:0.543378
# [223]	train-mlogloss:0.387204	test-mlogloss:0.543222
# [224]	train-mlogloss:0.386735	test-mlogloss:0.543176
# [225]	train-mlogloss:0.386252	test-mlogloss:0.543127
# [226]	train-mlogloss:0.385845	test-mlogloss:0.543001
# [227]	train-mlogloss:0.385302	test-mlogloss:0.542956
# [228]	train-mlogloss:0.384607	test-mlogloss:0.542887
# [229]	train-mlogloss:0.383952	test-mlogloss:0.542852
# [230]	train-mlogloss:0.383453	test-mlogloss:0.542817
# [231]	train-mlogloss:0.383052	test-mlogloss:0.542814
# [232]	train-mlogloss:0.382436	test-mlogloss:0.542822
# [233]	train-mlogloss:0.38181	test-mlogloss:0.542766
# [234]	train-mlogloss:0.381303	test-mlogloss:0.542719
# [235]	train-mlogloss:0.380896	test-mlogloss:0.542786
# [236]	train-mlogloss:0.380308	test-mlogloss:0.542617
# [237]	train-mlogloss:0.379748	test-mlogloss:0.542577
# [238]	train-mlogloss:0.379157	test-mlogloss:0.542598
# [239]	train-mlogloss:0.378647	test-mlogloss:0.542643
# [240]	train-mlogloss:0.378031	test-mlogloss:0.542739
# [241]	train-mlogloss:0.377577	test-mlogloss:0.542697
# [242]	train-mlogloss:0.377068	test-mlogloss:0.542725
# [243]	train-mlogloss:0.376691	test-mlogloss:0.542751
# [244]	train-mlogloss:0.376254	test-mlogloss:0.542653
# [245]	train-mlogloss:0.375853	test-mlogloss:0.542719
# [246]	train-mlogloss:0.375521	test-mlogloss:0.542764
# [247]	train-mlogloss:0.374996	test-mlogloss:0.542666
# [248]	train-mlogloss:0.374511	test-mlogloss:0.542685
# [249]	train-mlogloss:0.373983	test-mlogloss:0.542619
# [250]	train-mlogloss:0.37355	test-mlogloss:0.542649
# [251]	train-mlogloss:0.372961	test-mlogloss:0.542762
# [252]	train-mlogloss:0.372418	test-mlogloss:0.542777
# [253]	train-mlogloss:0.371713	test-mlogloss:0.542719
# [254]	train-mlogloss:0.371407	test-mlogloss:0.542681
# [255]	train-mlogloss:0.370884	test-mlogloss:0.542736
# [256]	train-mlogloss:0.370379	test-mlogloss:0.542756
# [257]	train-mlogloss:0.369995	test-mlogloss:0.542745
# [258]	train-mlogloss:0.369593	test-mlogloss:0.542784
# [259]	train-mlogloss:0.36902	test-mlogloss:0.542769
# [260]	train-mlogloss:0.368454	test-mlogloss:0.542719
# [261]	train-mlogloss:0.367943	test-mlogloss:0.542721
# [262]	train-mlogloss:0.367374	test-mlogloss:0.542631
# [263]	train-mlogloss:0.367018	test-mlogloss:0.542567
# [264]	train-mlogloss:0.366613	test-mlogloss:0.542625
# [265]	train-mlogloss:0.366018	test-mlogloss:0.542588
# [266]	train-mlogloss:0.365707	test-mlogloss:0.54257
# [267]	train-mlogloss:0.365176	test-mlogloss:0.542477
# [268]	train-mlogloss:0.364709	test-mlogloss:0.542507
# [269]	train-mlogloss:0.36437	test-mlogloss:0.542558
# [270]	train-mlogloss:0.363747	test-mlogloss:0.542665
# [271]	train-mlogloss:0.363194	test-mlogloss:0.542647
# [272]	train-mlogloss:0.362552	test-mlogloss:0.542669
# [273]	train-mlogloss:0.362048	test-mlogloss:0.54266
# [274]	train-mlogloss:0.361694	test-mlogloss:0.542758
# [275]	train-mlogloss:0.361243	test-mlogloss:0.542922
# [276]	train-mlogloss:0.360773	test-mlogloss:0.542989
# [277]	train-mlogloss:0.360163	test-mlogloss:0.542905
# [278]	train-mlogloss:0.359602	test-mlogloss:0.542955
# [279]	train-mlogloss:0.359019	test-mlogloss:0.543053
# [280]	train-mlogloss:0.358453	test-mlogloss:0.543045
# [281]	train-mlogloss:0.357919	test-mlogloss:0.543028
# [282]	train-mlogloss:0.357495	test-mlogloss:0.542924
# [283]	train-mlogloss:0.356962	test-mlogloss:0.542902
# [284]	train-mlogloss:0.356541	test-mlogloss:0.542919
# [285]	train-mlogloss:0.356143	test-mlogloss:0.542959
# [286]	train-mlogloss:0.355614	test-mlogloss:0.54296
# [287]	train-mlogloss:0.355242	test-mlogloss:0.542859
# [288]	train-mlogloss:0.354866	test-mlogloss:0.542912
# [289]	train-mlogloss:0.354429	test-mlogloss:0.543003
# [290]	train-mlogloss:0.35404	test-mlogloss:0.543015
# [291]	train-mlogloss:0.353458	test-mlogloss:0.543247
# [292]	train-mlogloss:0.353113	test-mlogloss:0.543203
# [293]	train-mlogloss:0.352672	test-mlogloss:0.543099
# [294]	train-mlogloss:0.352204	test-mlogloss:0.543106
# [295]	train-mlogloss:0.351847	test-mlogloss:0.543051
# [296]	train-mlogloss:0.351302	test-mlogloss:0.543141
# [297]	train-mlogloss:0.350858	test-mlogloss:0.543197
# [298]	train-mlogloss:0.350351	test-mlogloss:0.543132
# [299]	train-mlogloss:0.349686	test-mlogloss:0.543148
# [300]	train-mlogloss:0.349337	test-mlogloss:0.543186
# [301]	train-mlogloss:0.348954	test-mlogloss:0.543235
# [302]	train-mlogloss:0.348538	test-mlogloss:0.543372
# [303]	train-mlogloss:0.348083	test-mlogloss:0.543363
# [304]	train-mlogloss:0.347627	test-mlogloss:0.543294
# [305]	train-mlogloss:0.347111	test-mlogloss:0.543234
# [306]	train-mlogloss:0.346658	test-mlogloss:0.54328
# [307]	train-mlogloss:0.346057	test-mlogloss:0.543293
# [308]	train-mlogloss:0.345533	test-mlogloss:0.543234
# [309]	train-mlogloss:0.345101	test-mlogloss:0.543281
# [310]	train-mlogloss:0.344635	test-mlogloss:0.54338
# [311]	train-mlogloss:0.344226	test-mlogloss:0.543401
# [312]	train-mlogloss:0.343851	test-mlogloss:0.543437
# [313]	train-mlogloss:0.343382	test-mlogloss:0.543421
# [314]	train-mlogloss:0.342892	test-mlogloss:0.543426
# [315]	train-mlogloss:0.342455	test-mlogloss:0.543459
# [316]	train-mlogloss:0.342131	test-mlogloss:0.543551
# [317]	train-mlogloss:0.341676	test-mlogloss:0.543628
# [318]	train-mlogloss:0.341173	test-mlogloss:0.543662
# [319]	train-mlogloss:0.340686	test-mlogloss:0.543641
# [320]	train-mlogloss:0.340284	test-mlogloss:0.543603
# [321]	train-mlogloss:0.339756	test-mlogloss:0.543668
# [322]	train-mlogloss:0.339249	test-mlogloss:0.543788
# [323]	train-mlogloss:0.338892	test-mlogloss:0.543704
# [324]	train-mlogloss:0.338384	test-mlogloss:0.543776
# [325]	train-mlogloss:0.338043	test-mlogloss:0.543757
# [326]	train-mlogloss:0.337698	test-mlogloss:0.543797
# [327]	train-mlogloss:0.337273	test-mlogloss:0.543764
# [328]	train-mlogloss:0.336815	test-mlogloss:0.543809
# [329]	train-mlogloss:0.336409	test-mlogloss:0.543876
# [330]	train-mlogloss:0.335888	test-mlogloss:0.543821
# [331]	train-mlogloss:0.335439	test-mlogloss:0.543837
# [332]	train-mlogloss:0.334983	test-mlogloss:0.543891
# [333]	train-mlogloss:0.33475	test-mlogloss:0.543996
# [334]	train-mlogloss:0.334242	test-mlogloss:0.544065
# [335]	train-mlogloss:0.333846	test-mlogloss:0.54412
# [336]	train-mlogloss:0.333493	test-mlogloss:0.544059
# [337]	train-mlogloss:0.33312	test-mlogloss:0.5441
# [338]	train-mlogloss:0.332748	test-mlogloss:0.544097
# [339]	train-mlogloss:0.33228	test-mlogloss:0.544174
# [340]	train-mlogloss:0.33192	test-mlogloss:0.544228
# [341]	train-mlogloss:0.331483	test-mlogloss:0.544226
# [342]	train-mlogloss:0.331188	test-mlogloss:0.544247
# [343]	train-mlogloss:0.330748	test-mlogloss:0.544267
# [344]	train-mlogloss:0.330242	test-mlogloss:0.544264
# [345]	train-mlogloss:0.329773	test-mlogloss:0.544406
# [346]	train-mlogloss:0.329444	test-mlogloss:0.544344
# [347]	train-mlogloss:0.329119	test-mlogloss:0.544419
# [348]	train-mlogloss:0.328777	test-mlogloss:0.544366
# [349]	train-mlogloss:0.328311	test-mlogloss:0.544325
# [350]	train-mlogloss:0.327797	test-mlogloss:0.54444
# [351]	train-mlogloss:0.32735	test-mlogloss:0.544391
# [352]	train-mlogloss:0.326905	test-mlogloss:0.54436
# [353]	train-mlogloss:0.326511	test-mlogloss:0.544383
# [354]	train-mlogloss:0.326133	test-mlogloss:0.544413
# [355]	train-mlogloss:0.325657	test-mlogloss:0.544496
# [356]	train-mlogloss:0.325242	test-mlogloss:0.54446
# [357]	train-mlogloss:0.324946	test-mlogloss:0.544452
# [358]	train-mlogloss:0.32447	test-mlogloss:0.544483
# [359]	train-mlogloss:0.323987	test-mlogloss:0.544554
# [360]	train-mlogloss:0.323617	test-mlogloss:0.544637
# [361]	train-mlogloss:0.323178	test-mlogloss:0.544702
# [362]	train-mlogloss:0.322771	test-mlogloss:0.544701
# [363]	train-mlogloss:0.322379	test-mlogloss:0.544711
# [364]	train-mlogloss:0.32187	test-mlogloss:0.544761
# [365]	train-mlogloss:0.321379	test-mlogloss:0.544724
# [366]	train-mlogloss:0.321029	test-mlogloss:0.544758
# [367]	train-mlogloss:0.320701	test-mlogloss:0.544791
# Stopping. Best iteration:
# [267]	train-mlogloss:0.365176	test-mlogloss:0.542477
#
# [0.54479146392744071]

# %%
#output the outcome - using xgboost
train_set, test_set =manager_skill_eval(train_df,test_df)
features_to_use.append('manager_skill')

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=285)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point2withHccSorted.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
