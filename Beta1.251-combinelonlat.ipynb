# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
import re
import string
from collections import defaultdict, Counter

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    
    return street
    
#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column,minimum_size=5):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= minimum_size, column] = -1
    return df1, df2

def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

#encoded by sorted value
def hcc_sorting(train_df,test_df,feature,label=None,randomize=None):
    """
    sort the hcc feature by their prior on label then encode
    the train df should be with its labels get dummied
    
    return the list of all the possible features in order
    """
    if label ==None:
        train_df['tempScore'] = 2*train_df['high']+train_df['medium']
    
    label = 'tempScore'
    #get dummies for the 
    grouped  = train_df.groupby(feature)[label].agg({'size':'size','mean':'mean'})
    #unrankedMean = grouped.ix[grouped['size']<unrank_threshold,'mean'].mean()
    #grouped.ix[grouped['size']<unrank_threshold,'mean'] = unrankedMean
    grouped = grouped.reset_index()

    #get the values for the test set
    test_groupBy=test_df[feature].value_counts().to_frame().reset_index()
    test_groupBy.columns = [feature,'testSize']

    #merge together and reset the mean
    totalFeature = grouped.merge(test_groupBy,on = feature, how='outer').fillna(0)

    rankedMean = np.mean(grouped['mean'])

    #reset those train size 0 to the ranked mean
    totalFeature.ix[totalFeature['size']==0,'mean']=rankedMean
    
    #add some random 
    if randomize : 
        totalFeature['mean'] *= np.random.uniform(1 - randomize, 1 + randomize, len(totalFeature))

    return list(totalFeature.sort('mean')[feature])

# %%
#functions for features
def featureList(train_df,test_df,limit = 0.01):
    #acquiring the feature lists
    features_in_train = train_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    features_in_train.sort(ascending  = False)
    features_in_test = test_df["features"].apply(pd.Series).unstack().reset_index(drop = True).dropna().value_counts()
    features_in_test.sort(ascending  = False)
    
    filtered_features_in_train = features_in_train[features_in_train > limit*len(train_df)]
    filtered_features_in_test = features_in_test[features_in_test > limit*len(test_df)]
    accept_list = set(filtered_features_in_train.index).union(set(filtered_features_in_test.index))
    return accept_list

def featureMapping(train_df,test_df,feature_list):
    for feature in feature_list:
        #add the feature column for both
        #if feature in the row, then set the value for (row,feature) to 1
        train_df['with_'+feature]=train_df['features'].apply(lambda x : 1 if feature in x else 0)
        test_df['with_'+feature]=test_df['features'].apply(lambda x : 1 if feature in x else 0)
    return

# %%
#central distance, see "rental-listing-ny-map" by Enrique Pérez Herrero
def setOutlierNan(df):
    for i in ['latitude', 'longitude']:
        Q1 = df[i].quantile(0.25)
        Q3 = df[i].quantile(0.75)
        IQR = Q3 - Q1
        upper = Q3 + 3*IQR
        lower = Q1 - 3*IQR
        df.ix[(df[i]>upper)|(df[i]<lower),i] = np.nan
    return 
 
#reset some of the ll feature to be combined 
def resetLatLon(train_df,test_df,based_df):
    
    notNull = based_df[~(based_df['latitude'].isnull()|based_df['longitude'].isnull())]
    meanList = notNull.groupby('building_id').mean().ix[:,['latitude','longitude']]
    #reset the meanList for next_step
    meanList.columns = ['mlat','mlon']
    meanList = meanList.reset_index()
    meanList = meanList[meanList['building_id']!='0']
    
    train_df = train_df.merge(meanList,on = 'building_id',how ='left')
    train_df.ix[~(train_df['mlon'].isnull()),'longitude']=train_df['mlon']
    train_df.ix[~(train_df['mlat'].isnull()),'latitude']=train_df['mlat']
    
    test_df = test_df.merge(meanList,on = 'building_id',how ='left')
    test_df.ix[~(test_df['mlon'].isnull()),'longitude']=test_df['mlon']
    test_df.ix[~(test_df['mlat'].isnull()),'latitude']=test_df['mlat']
    
    return

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
#new numerical processing
setOutlierNan(train_df)
setOutlierNan(test_df)

#for testing
#train_test = pd.concat([train_df.drop('interest_level',axis = 1),test_df])
#resetLatLon(train_df,test_df,train_test)

resetLatLon(train_df,test_df,train_df)

train_df = train_df.fillna(0)
test_df = test_df.fillna(0)

# %%
"""
new categorical data append and converting label dummies for future use
"""
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

train_df =train_df.join(pd.get_dummies(train_df[u'interest_level']).astype(int))

# %%
#dealing with features

#preprocessing for features
train_df["features"] = train_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_') \
                                                            for i in x])
test_df["features"] = test_df["features"].apply(lambda x:["_".join(i.split(" ")).lower().strip().replace('-','_')\
                                                          for i in x])
#create the accept list
accept_list = list(featureList(train_df,test_df,limit = 0.001))

#map the feature to dummy slots
featureMapping(train_df,test_df,accept_list)
features_to_use.extend(map(lambda x : 'with_'+x,accept_list))
# Out:
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
features_to_use.append('manager_skill')
categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
features_to_use.extend(categorical)
cv_scores = []

mini_ranking = 15

for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #special feature engineering for the trainset
        
        
#====================================================================        
        """feature engineerings for the categorical features"""
        
        dev_set, val_set =manager_skill_eval(dev_set,val_set,\
        unrank_threshold = mini_ranking)
        
        
        #fill substitute the small size values by their mean
        for f in categorical:
            dev_set,val_set  = singleValueConvert(dev_set,val_set,f,mini_ranking)
        
            if dev_set[f].dtype=='object':
                #print(f)
                lbl = preprocessing.LabelEncoder()
                lbl.fit(hcc_sorting(dev_set,val_set,f))
                dev_set[f] = lbl.transform(list(dev_set[f].values))
                val_set[f] = lbl.transform(list(val_set[f].values))
                
#===================================================================
                
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        break
print cv_scores
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:123: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# [0]	train-mlogloss:1.03371	test-mlogloss:1.03601
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:0.982311	test-mlogloss:0.986357
# [2]	train-mlogloss:0.934347	test-mlogloss:0.940504
# [3]	train-mlogloss:0.893211	test-mlogloss:0.900941
# [4]	train-mlogloss:0.856402	test-mlogloss:0.866228
# [5]	train-mlogloss:0.825102	test-mlogloss:0.836361
# [6]	train-mlogloss:0.79682	test-mlogloss:0.809505
# [7]	train-mlogloss:0.772308	test-mlogloss:0.786614
# [8]	train-mlogloss:0.75204	test-mlogloss:0.767324
# [9]	train-mlogloss:0.732651	test-mlogloss:0.749352
# [10]	train-mlogloss:0.71528	test-mlogloss:0.733136
# [11]	train-mlogloss:0.699285	test-mlogloss:0.718331
# [12]	train-mlogloss:0.685721	test-mlogloss:0.705619
# [13]	train-mlogloss:0.6728	test-mlogloss:0.693798
# [14]	train-mlogloss:0.661327	test-mlogloss:0.683124
# [15]	train-mlogloss:0.651157	test-mlogloss:0.674153
# [16]	train-mlogloss:0.641725	test-mlogloss:0.666112
# [17]	train-mlogloss:0.633025	test-mlogloss:0.658382
# [18]	train-mlogloss:0.624841	test-mlogloss:0.651009
# [19]	train-mlogloss:0.617998	test-mlogloss:0.645117
# [20]	train-mlogloss:0.611317	test-mlogloss:0.639259
# [21]	train-mlogloss:0.605046	test-mlogloss:0.634055
# [22]	train-mlogloss:0.599198	test-mlogloss:0.629094
# [23]	train-mlogloss:0.593907	test-mlogloss:0.624735
# [24]	train-mlogloss:0.58949	test-mlogloss:0.620912
# [25]	train-mlogloss:0.584832	test-mlogloss:0.617221
# [26]	train-mlogloss:0.580868	test-mlogloss:0.613731
# [27]	train-mlogloss:0.576812	test-mlogloss:0.610567
# [28]	train-mlogloss:0.573249	test-mlogloss:0.607877
# [29]	train-mlogloss:0.5696	test-mlogloss:0.60497
# [30]	train-mlogloss:0.566098	test-mlogloss:0.602473
# [31]	train-mlogloss:0.563003	test-mlogloss:0.600163
# [32]	train-mlogloss:0.560342	test-mlogloss:0.598311
# [33]	train-mlogloss:0.557373	test-mlogloss:0.596055
# [34]	train-mlogloss:0.55496	test-mlogloss:0.594412
# [35]	train-mlogloss:0.552641	test-mlogloss:0.59265
# [36]	train-mlogloss:0.550219	test-mlogloss:0.590926
# [37]	train-mlogloss:0.548309	test-mlogloss:0.58941
# [38]	train-mlogloss:0.545789	test-mlogloss:0.587686
# [39]	train-mlogloss:0.543442	test-mlogloss:0.585917
# [40]	train-mlogloss:0.541263	test-mlogloss:0.584494
# [41]	train-mlogloss:0.539135	test-mlogloss:0.582936
# [42]	train-mlogloss:0.53734	test-mlogloss:0.581798
# [43]	train-mlogloss:0.53525	test-mlogloss:0.580514
# [44]	train-mlogloss:0.533382	test-mlogloss:0.579564
# [45]	train-mlogloss:0.531341	test-mlogloss:0.578275
# [46]	train-mlogloss:0.529691	test-mlogloss:0.577262
# [47]	train-mlogloss:0.528109	test-mlogloss:0.576135
# [48]	train-mlogloss:0.526565	test-mlogloss:0.575286
# [49]	train-mlogloss:0.524756	test-mlogloss:0.574123
# [50]	train-mlogloss:0.523293	test-mlogloss:0.57338
# [51]	train-mlogloss:0.521899	test-mlogloss:0.572526
# [52]	train-mlogloss:0.520454	test-mlogloss:0.571712
# [53]	train-mlogloss:0.519276	test-mlogloss:0.571127
# [54]	train-mlogloss:0.517632	test-mlogloss:0.570326
# [55]	train-mlogloss:0.516445	test-mlogloss:0.569548
# [56]	train-mlogloss:0.515132	test-mlogloss:0.568825
# [57]	train-mlogloss:0.514116	test-mlogloss:0.568394
# [58]	train-mlogloss:0.512844	test-mlogloss:0.567688
# [59]	train-mlogloss:0.51148	test-mlogloss:0.566976
# [60]	train-mlogloss:0.510028	test-mlogloss:0.5662
# [61]	train-mlogloss:0.508739	test-mlogloss:0.565563
# [62]	train-mlogloss:0.507352	test-mlogloss:0.564824
# [63]	train-mlogloss:0.506313	test-mlogloss:0.564378
# [64]	train-mlogloss:0.505116	test-mlogloss:0.563752
# [65]	train-mlogloss:0.504074	test-mlogloss:0.56327
# [66]	train-mlogloss:0.502603	test-mlogloss:0.562683
# [67]	train-mlogloss:0.5015	test-mlogloss:0.562248
# [68]	train-mlogloss:0.50043	test-mlogloss:0.561845
# [69]	train-mlogloss:0.499455	test-mlogloss:0.561557
# [70]	train-mlogloss:0.498619	test-mlogloss:0.561313
# [71]	train-mlogloss:0.497331	test-mlogloss:0.560783
# [72]	train-mlogloss:0.49654	test-mlogloss:0.560592
# [73]	train-mlogloss:0.495195	test-mlogloss:0.559953
# [74]	train-mlogloss:0.494068	test-mlogloss:0.559664
# [75]	train-mlogloss:0.493017	test-mlogloss:0.559241
# [76]	train-mlogloss:0.491541	test-mlogloss:0.558648
# [77]	train-mlogloss:0.490502	test-mlogloss:0.558314
# [78]	train-mlogloss:0.489459	test-mlogloss:0.557823
# [79]	train-mlogloss:0.488321	test-mlogloss:0.55728
# [80]	train-mlogloss:0.487462	test-mlogloss:0.556946
# [81]	train-mlogloss:0.486737	test-mlogloss:0.556586
# [82]	train-mlogloss:0.485803	test-mlogloss:0.556281
# [83]	train-mlogloss:0.484941	test-mlogloss:0.556005
# [84]	train-mlogloss:0.484139	test-mlogloss:0.55564
# [85]	train-mlogloss:0.483246	test-mlogloss:0.555238
# [86]	train-mlogloss:0.482674	test-mlogloss:0.554978
# [87]	train-mlogloss:0.481778	test-mlogloss:0.55465
# [88]	train-mlogloss:0.480979	test-mlogloss:0.554404
# [89]	train-mlogloss:0.48013	test-mlogloss:0.554168
# [90]	train-mlogloss:0.479259	test-mlogloss:0.553926
# [91]	train-mlogloss:0.478256	test-mlogloss:0.553453
# [92]	train-mlogloss:0.477276	test-mlogloss:0.553204
# [93]	train-mlogloss:0.476597	test-mlogloss:0.553086
# [94]	train-mlogloss:0.475617	test-mlogloss:0.552766
# [95]	train-mlogloss:0.474799	test-mlogloss:0.552491
# [96]	train-mlogloss:0.474054	test-mlogloss:0.552336
# [97]	train-mlogloss:0.473407	test-mlogloss:0.552172
# [98]	train-mlogloss:0.472606	test-mlogloss:0.552088
# [99]	train-mlogloss:0.471997	test-mlogloss:0.552034
# [100]	train-mlogloss:0.471202	test-mlogloss:0.551855
# [101]	train-mlogloss:0.470222	test-mlogloss:0.551473
# [102]	train-mlogloss:0.469239	test-mlogloss:0.551103
# [103]	train-mlogloss:0.468713	test-mlogloss:0.550922
# [104]	train-mlogloss:0.467938	test-mlogloss:0.550607
# [105]	train-mlogloss:0.466958	test-mlogloss:0.550359
# [106]	train-mlogloss:0.466372	test-mlogloss:0.550242
# [107]	train-mlogloss:0.465555	test-mlogloss:0.550044
# [108]	train-mlogloss:0.464931	test-mlogloss:0.549938
# [109]	train-mlogloss:0.46437	test-mlogloss:0.549826
# [110]	train-mlogloss:0.463676	test-mlogloss:0.54954
# [111]	train-mlogloss:0.462825	test-mlogloss:0.549356
# [112]	train-mlogloss:0.461877	test-mlogloss:0.549133
# [113]	train-mlogloss:0.46098	test-mlogloss:0.549036
# [114]	train-mlogloss:0.460115	test-mlogloss:0.548583
# [115]	train-mlogloss:0.459402	test-mlogloss:0.548603
# [116]	train-mlogloss:0.458765	test-mlogloss:0.548418
# [117]	train-mlogloss:0.457846	test-mlogloss:0.548208
# [118]	train-mlogloss:0.457151	test-mlogloss:0.547967
# [119]	train-mlogloss:0.456624	test-mlogloss:0.547687
# [120]	train-mlogloss:0.455858	test-mlogloss:0.547575
# [121]	train-mlogloss:0.454901	test-mlogloss:0.547405
# [122]	train-mlogloss:0.454157	test-mlogloss:0.547114
# [123]	train-mlogloss:0.453273	test-mlogloss:0.546914
# [124]	train-mlogloss:0.452673	test-mlogloss:0.54679
# [125]	train-mlogloss:0.452097	test-mlogloss:0.54664
# [126]	train-mlogloss:0.451492	test-mlogloss:0.546503
# [127]	train-mlogloss:0.450893	test-mlogloss:0.546441
# [128]	train-mlogloss:0.450167	test-mlogloss:0.546233
# [129]	train-mlogloss:0.449794	test-mlogloss:0.546079
# [130]	train-mlogloss:0.449018	test-mlogloss:0.54585
# [131]	train-mlogloss:0.44842	test-mlogloss:0.545774
# [132]	train-mlogloss:0.447916	test-mlogloss:0.545689
# [133]	train-mlogloss:0.446943	test-mlogloss:0.54548
# [134]	train-mlogloss:0.446434	test-mlogloss:0.545253
# [135]	train-mlogloss:0.44574	test-mlogloss:0.544993
# [136]	train-mlogloss:0.44514	test-mlogloss:0.544864
# [137]	train-mlogloss:0.444547	test-mlogloss:0.544811
# [138]	train-mlogloss:0.444099	test-mlogloss:0.544791
# [139]	train-mlogloss:0.443398	test-mlogloss:0.544676
# [140]	train-mlogloss:0.442546	test-mlogloss:0.544582
# [141]	train-mlogloss:0.441947	test-mlogloss:0.54446
# [142]	train-mlogloss:0.441476	test-mlogloss:0.544384
# [143]	train-mlogloss:0.440786	test-mlogloss:0.544352
# [144]	train-mlogloss:0.440144	test-mlogloss:0.544381
# [145]	train-mlogloss:0.439525	test-mlogloss:0.544177
# [146]	train-mlogloss:0.438942	test-mlogloss:0.544241
# [147]	train-mlogloss:0.438261	test-mlogloss:0.544128
# [148]	train-mlogloss:0.437689	test-mlogloss:0.544019
# [149]	train-mlogloss:0.43699	test-mlogloss:0.543808
# [150]	train-mlogloss:0.43636	test-mlogloss:0.543705
# [151]	train-mlogloss:0.435948	test-mlogloss:0.543634
# [152]	train-mlogloss:0.435269	test-mlogloss:0.543597
# [153]	train-mlogloss:0.434648	test-mlogloss:0.543563
# [154]	train-mlogloss:0.433954	test-mlogloss:0.543369
# [155]	train-mlogloss:0.433264	test-mlogloss:0.543177
# [156]	train-mlogloss:0.432569	test-mlogloss:0.543061
# [157]	train-mlogloss:0.43178	test-mlogloss:0.542814
# [158]	train-mlogloss:0.431179	test-mlogloss:0.542696
# [159]	train-mlogloss:0.430653	test-mlogloss:0.542628
# [160]	train-mlogloss:0.430077	test-mlogloss:0.542556
# [161]	train-mlogloss:0.429233	test-mlogloss:0.542437
# [162]	train-mlogloss:0.428776	test-mlogloss:0.54245
# [163]	train-mlogloss:0.428366	test-mlogloss:0.542478
# [164]	train-mlogloss:0.42778	test-mlogloss:0.542464
# [165]	train-mlogloss:0.427131	test-mlogloss:0.542458
# [166]	train-mlogloss:0.426553	test-mlogloss:0.542391
# [167]	train-mlogloss:0.425865	test-mlogloss:0.542408
# [168]	train-mlogloss:0.425217	test-mlogloss:0.542387
# [169]	train-mlogloss:0.424631	test-mlogloss:0.542297
# [170]	train-mlogloss:0.424154	test-mlogloss:0.542282
# [171]	train-mlogloss:0.423351	test-mlogloss:0.542149
# [172]	train-mlogloss:0.422949	test-mlogloss:0.542201
# [173]	train-mlogloss:0.422422	test-mlogloss:0.542168
# [174]	train-mlogloss:0.421779	test-mlogloss:0.542048
# [175]	train-mlogloss:0.421251	test-mlogloss:0.541912
# [176]	train-mlogloss:0.420551	test-mlogloss:0.541722
# [177]	train-mlogloss:0.42003	test-mlogloss:0.541628
# [178]	train-mlogloss:0.419376	test-mlogloss:0.541524
# [179]	train-mlogloss:0.418619	test-mlogloss:0.541516
# [180]	train-mlogloss:0.418131	test-mlogloss:0.541494
# [181]	train-mlogloss:0.417473	test-mlogloss:0.541459
# [182]	train-mlogloss:0.41673	test-mlogloss:0.541379
# [183]	train-mlogloss:0.416166	test-mlogloss:0.541415
# [184]	train-mlogloss:0.415611	test-mlogloss:0.54126
# [185]	train-mlogloss:0.414979	test-mlogloss:0.541218
# [186]	train-mlogloss:0.414266	test-mlogloss:0.541161
# [187]	train-mlogloss:0.4137	test-mlogloss:0.541117
# [188]	train-mlogloss:0.413186	test-mlogloss:0.541033
# [189]	train-mlogloss:0.412635	test-mlogloss:0.541031
# [190]	train-mlogloss:0.412269	test-mlogloss:0.540926
# [191]	train-mlogloss:0.411903	test-mlogloss:0.540864
# [192]	train-mlogloss:0.411484	test-mlogloss:0.540845
# [193]	train-mlogloss:0.411082	test-mlogloss:0.540784
# [194]	train-mlogloss:0.410421	test-mlogloss:0.540643
# [195]	train-mlogloss:0.409848	test-mlogloss:0.540571
# [196]	train-mlogloss:0.408968	test-mlogloss:0.540316
# [197]	train-mlogloss:0.408468	test-mlogloss:0.540366
# [198]	train-mlogloss:0.40788	test-mlogloss:0.540289
# [199]	train-mlogloss:0.40737	test-mlogloss:0.540269
# [200]	train-mlogloss:0.406797	test-mlogloss:0.540208
# [201]	train-mlogloss:0.406367	test-mlogloss:0.540183
# [202]	train-mlogloss:0.405852	test-mlogloss:0.540152
# [203]	train-mlogloss:0.405533	test-mlogloss:0.540194
# [204]	train-mlogloss:0.404792	test-mlogloss:0.540156
# [205]	train-mlogloss:0.404317	test-mlogloss:0.540056
# [206]	train-mlogloss:0.404022	test-mlogloss:0.539942
# [207]	train-mlogloss:0.403608	test-mlogloss:0.539966
# [208]	train-mlogloss:0.403031	test-mlogloss:0.539915
# [209]	train-mlogloss:0.402446	test-mlogloss:0.539819
# [210]	train-mlogloss:0.401933	test-mlogloss:0.53978
# [211]	train-mlogloss:0.40147	test-mlogloss:0.539794
# [212]	train-mlogloss:0.40092	test-mlogloss:0.53974
# [213]	train-mlogloss:0.400415	test-mlogloss:0.539783
# [214]	train-mlogloss:0.39978	test-mlogloss:0.539738
# [215]	train-mlogloss:0.399272	test-mlogloss:0.539792
# [216]	train-mlogloss:0.398801	test-mlogloss:0.539671
# [217]	train-mlogloss:0.398126	test-mlogloss:0.539582
# [218]	train-mlogloss:0.397366	test-mlogloss:0.539337
# [219]	train-mlogloss:0.396673	test-mlogloss:0.539241
# [220]	train-mlogloss:0.396123	test-mlogloss:0.539296
# [221]	train-mlogloss:0.395606	test-mlogloss:0.539245
# [222]	train-mlogloss:0.395158	test-mlogloss:0.53917
# [223]	train-mlogloss:0.394673	test-mlogloss:0.539204
# [224]	train-mlogloss:0.393918	test-mlogloss:0.539043
# [225]	train-mlogloss:0.39354	test-mlogloss:0.538988
# [226]	train-mlogloss:0.393022	test-mlogloss:0.538897
# [227]	train-mlogloss:0.392536	test-mlogloss:0.539003
# [228]	train-mlogloss:0.392143	test-mlogloss:0.53894
# [229]	train-mlogloss:0.391709	test-mlogloss:0.538949
# [230]	train-mlogloss:0.391258	test-mlogloss:0.538884
# [231]	train-mlogloss:0.390791	test-mlogloss:0.538795
# [232]	train-mlogloss:0.390275	test-mlogloss:0.538694
# [233]	train-mlogloss:0.389725	test-mlogloss:0.538657
# [234]	train-mlogloss:0.389261	test-mlogloss:0.538497
# [235]	train-mlogloss:0.388876	test-mlogloss:0.538454
# [236]	train-mlogloss:0.388259	test-mlogloss:0.538451
# [237]	train-mlogloss:0.387707	test-mlogloss:0.538372
# [238]	train-mlogloss:0.387191	test-mlogloss:0.538252
# [239]	train-mlogloss:0.386766	test-mlogloss:0.538262
# [240]	train-mlogloss:0.386242	test-mlogloss:0.538266
# [241]	train-mlogloss:0.385939	test-mlogloss:0.538176
# [242]	train-mlogloss:0.385533	test-mlogloss:0.53806
# [243]	train-mlogloss:0.38494	test-mlogloss:0.538082
# [244]	train-mlogloss:0.384384	test-mlogloss:0.537942
# [245]	train-mlogloss:0.383963	test-mlogloss:0.537957
# [246]	train-mlogloss:0.383417	test-mlogloss:0.5379
# [247]	train-mlogloss:0.382941	test-mlogloss:0.53784
# [248]	train-mlogloss:0.382608	test-mlogloss:0.537789
# [249]	train-mlogloss:0.38203	test-mlogloss:0.537904
# [250]	train-mlogloss:0.381499	test-mlogloss:0.537937
# [251]	train-mlogloss:0.381018	test-mlogloss:0.537954
# [252]	train-mlogloss:0.380392	test-mlogloss:0.537806
# [253]	train-mlogloss:0.379847	test-mlogloss:0.537848
# [254]	train-mlogloss:0.379429	test-mlogloss:0.537889
# [255]	train-mlogloss:0.379153	test-mlogloss:0.537853
# [256]	train-mlogloss:0.378678	test-mlogloss:0.537932
# [257]	train-mlogloss:0.378314	test-mlogloss:0.537885
# [258]	train-mlogloss:0.377773	test-mlogloss:0.537871
# [259]	train-mlogloss:0.377419	test-mlogloss:0.537886
# [260]	train-mlogloss:0.377127	test-mlogloss:0.53797
# [261]	train-mlogloss:0.376822	test-mlogloss:0.538062
# [262]	train-mlogloss:0.376398	test-mlogloss:0.538037
# [263]	train-mlogloss:0.375782	test-mlogloss:0.538158
# [264]	train-mlogloss:0.375293	test-mlogloss:0.538191
# [265]	train-mlogloss:0.374796	test-mlogloss:0.538217
# [266]	train-mlogloss:0.374334	test-mlogloss:0.53822
# [267]	train-mlogloss:0.37398	test-mlogloss:0.538162
# [268]	train-mlogloss:0.373435	test-mlogloss:0.538079
# Stopping. Best iteration:
# [248]	train-mlogloss:0.382608	test-mlogloss:0.537789
#
# [0.53807865745603778]

# %%
#====================================================================        
"""feature engineerings for the categorical features"""

train_set, test_set =manager_skill_eval(train_df,test_df,\
unrank_threshold = mini_ranking)


#fill substitute the small size values by their mean
for f in categorical:
    train_set,test_set  = singleValueConvert(train_set,test_set,f,mini_ranking)

    if train_set[f].dtype=='object':
        #print(f)
        lbl = preprocessing.LabelEncoder()
        lbl.fit(hcc_sorting(train_set,test_set,f))
        train_set[f] = lbl.transform(list(train_set[f].values))
        test_set[f] = lbl.transform(list(test_set[f].values))
                
#===================================================================

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=243)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point251.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# C:\Users\dell\Anaconda2\lib\site-packages\ipykernel\__main__.py:123: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
