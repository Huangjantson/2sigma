# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
import re
import string

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    #nth -> n
    #nst -> n
    #nrd -> n
    #nnd -> n
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    

    return street
    
def getStreetNumber(address):
    #get building id in the front, return -1 if their isn't
    pattern = re.compile('^([\d-]*)([\s]+)')
    try:
        number = pattern.search(address).group(1)
        return int(number)
    except:
        return -1

#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    return df1, df2

# %%
def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room","price_per_bath"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

train_df["street_number"] = train_df["street_address"].apply(getStreetNumber)
test_df["street_number"] = test_df["street_address"].apply(getStreetNumber)

#features_to_use.append("street_number")

# %%
#dealing feature with categorical features 
"""
display_address 8826    
building_id        7585   =》many zeros in this feature
manager_id   3481
street_address 15358 =》will be 3800 if no numbers in it 
"""
categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
#output the outcome - using xgboost
train_set, test_set =manager_skill_eval(train_df,test_df)

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=300)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point21morenumerical.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')

# %%
#running and getting the cv from xgboost
cv_scores = []
#K-FOLD already defined.If not ,use
#KF=KFold(len(train_X),5,shuffle=True,random_state = 42)
for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #apply the function for createing some featues
        dev_set, val_set =manager_skill_eval(dev_set,val_set)
        #features_to_use.extend(['ManHigh','ManLow', 'ManMedium','manager_skill'])
        features_to_use.append('manager_skill')
        
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# [0]	train-mlogloss:1.03102	test-mlogloss:1.0336
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.976423	test-mlogloss:0.980401
# [2]	train-mlogloss:0.927999	test-mlogloss:0.934704
# [3]	train-mlogloss:0.885643	test-mlogloss:0.894405
# [4]	train-mlogloss:0.851632	test-mlogloss:0.861526
# [5]	train-mlogloss:0.819595	test-mlogloss:0.831538
# [6]	train-mlogloss:0.791363	test-mlogloss:0.805188
# [7]	train-mlogloss:0.768195	test-mlogloss:0.783174
# [8]	train-mlogloss:0.746231	test-mlogloss:0.762747
# [9]	train-mlogloss:0.726047	test-mlogloss:0.744182
# [10]	train-mlogloss:0.709605	test-mlogloss:0.728683
# [11]	train-mlogloss:0.693776	test-mlogloss:0.714327
# [12]	train-mlogloss:0.679702	test-mlogloss:0.701756
# [13]	train-mlogloss:0.66683	test-mlogloss:0.689942
# [14]	train-mlogloss:0.655268	test-mlogloss:0.679356
# [15]	train-mlogloss:0.644812	test-mlogloss:0.670119
# [16]	train-mlogloss:0.635624	test-mlogloss:0.662178
# [17]	train-mlogloss:0.627239	test-mlogloss:0.654855
# [18]	train-mlogloss:0.619299	test-mlogloss:0.648053
# [19]	train-mlogloss:0.612352	test-mlogloss:0.642461
# [20]	train-mlogloss:0.606094	test-mlogloss:0.637117
# [21]	train-mlogloss:0.599918	test-mlogloss:0.631844
# [22]	train-mlogloss:0.594634	test-mlogloss:0.627447
# [23]	train-mlogloss:0.589492	test-mlogloss:0.623208
# [24]	train-mlogloss:0.584724	test-mlogloss:0.61948
# [25]	train-mlogloss:0.580301	test-mlogloss:0.615665
# [26]	train-mlogloss:0.576486	test-mlogloss:0.612606
# [27]	train-mlogloss:0.572635	test-mlogloss:0.609923
# [28]	train-mlogloss:0.569025	test-mlogloss:0.607414
# [29]	train-mlogloss:0.565746	test-mlogloss:0.605033
# [30]	train-mlogloss:0.562645	test-mlogloss:0.602731
# [31]	train-mlogloss:0.559998	test-mlogloss:0.600784
# [32]	train-mlogloss:0.557056	test-mlogloss:0.598534
# [33]	train-mlogloss:0.5544	test-mlogloss:0.596714
# [34]	train-mlogloss:0.551938	test-mlogloss:0.594888
# [35]	train-mlogloss:0.54977	test-mlogloss:0.593447
# [36]	train-mlogloss:0.547581	test-mlogloss:0.592004
# [37]	train-mlogloss:0.545579	test-mlogloss:0.590705
# [38]	train-mlogloss:0.54395	test-mlogloss:0.589702
# [39]	train-mlogloss:0.541938	test-mlogloss:0.588556
# [40]	train-mlogloss:0.539853	test-mlogloss:0.587283
# [41]	train-mlogloss:0.538017	test-mlogloss:0.585993
# [42]	train-mlogloss:0.536001	test-mlogloss:0.584825
# [43]	train-mlogloss:0.533995	test-mlogloss:0.583856
# [44]	train-mlogloss:0.532624	test-mlogloss:0.583237
# [45]	train-mlogloss:0.530621	test-mlogloss:0.582134
# [46]	train-mlogloss:0.529088	test-mlogloss:0.581199
# [47]	train-mlogloss:0.52754	test-mlogloss:0.580423
# [48]	train-mlogloss:0.525943	test-mlogloss:0.579808
# [49]	train-mlogloss:0.524408	test-mlogloss:0.578855
# [50]	train-mlogloss:0.523096	test-mlogloss:0.578221
# [51]	train-mlogloss:0.522086	test-mlogloss:0.577759
# [52]	train-mlogloss:0.520332	test-mlogloss:0.576816
# [53]	train-mlogloss:0.519183	test-mlogloss:0.576214
# [54]	train-mlogloss:0.517736	test-mlogloss:0.575526
# [55]	train-mlogloss:0.516183	test-mlogloss:0.574856
# [56]	train-mlogloss:0.514761	test-mlogloss:0.574355
# [57]	train-mlogloss:0.513272	test-mlogloss:0.573836
# [58]	train-mlogloss:0.511775	test-mlogloss:0.573173
# [59]	train-mlogloss:0.510679	test-mlogloss:0.572692
# [60]	train-mlogloss:0.509326	test-mlogloss:0.57215
# [61]	train-mlogloss:0.5078	test-mlogloss:0.571566
# [62]	train-mlogloss:0.50653	test-mlogloss:0.570852
# [63]	train-mlogloss:0.505675	test-mlogloss:0.570701
# [64]	train-mlogloss:0.504227	test-mlogloss:0.570216
# [65]	train-mlogloss:0.502997	test-mlogloss:0.569686
# [66]	train-mlogloss:0.502235	test-mlogloss:0.569438
# [67]	train-mlogloss:0.500948	test-mlogloss:0.568832
# [68]	train-mlogloss:0.500153	test-mlogloss:0.568485
# [69]	train-mlogloss:0.499551	test-mlogloss:0.568497
# [70]	train-mlogloss:0.498689	test-mlogloss:0.568228
# [71]	train-mlogloss:0.49759	test-mlogloss:0.56772
# [72]	train-mlogloss:0.496153	test-mlogloss:0.567247
# [73]	train-mlogloss:0.495155	test-mlogloss:0.56682
# [74]	train-mlogloss:0.494118	test-mlogloss:0.566452
# [75]	train-mlogloss:0.492964	test-mlogloss:0.566128
# [76]	train-mlogloss:0.491775	test-mlogloss:0.565798
# [77]	train-mlogloss:0.490556	test-mlogloss:0.565381
# [78]	train-mlogloss:0.489372	test-mlogloss:0.564928
# [79]	train-mlogloss:0.488268	test-mlogloss:0.564692
# [80]	train-mlogloss:0.487177	test-mlogloss:0.564318
# [81]	train-mlogloss:0.486569	test-mlogloss:0.564133
# [82]	train-mlogloss:0.485841	test-mlogloss:0.563915
# [83]	train-mlogloss:0.484826	test-mlogloss:0.563479
# [84]	train-mlogloss:0.483913	test-mlogloss:0.563213
# [85]	train-mlogloss:0.482975	test-mlogloss:0.562868
# [86]	train-mlogloss:0.482072	test-mlogloss:0.562669
# [87]	train-mlogloss:0.481073	test-mlogloss:0.562291
# [88]	train-mlogloss:0.48029	test-mlogloss:0.562117
# [89]	train-mlogloss:0.479224	test-mlogloss:0.561855
# [90]	train-mlogloss:0.47847	test-mlogloss:0.561543
# [91]	train-mlogloss:0.477713	test-mlogloss:0.561392
# [92]	train-mlogloss:0.476899	test-mlogloss:0.56121
# [93]	train-mlogloss:0.475809	test-mlogloss:0.561101
# [94]	train-mlogloss:0.475136	test-mlogloss:0.56095
# [95]	train-mlogloss:0.474272	test-mlogloss:0.560586
# [96]	train-mlogloss:0.473422	test-mlogloss:0.560402
# [97]	train-mlogloss:0.472626	test-mlogloss:0.56014
# [98]	train-mlogloss:0.47199	test-mlogloss:0.559957
# [99]	train-mlogloss:0.471209	test-mlogloss:0.559809
# [100]	train-mlogloss:0.470373	test-mlogloss:0.559604
# [101]	train-mlogloss:0.469213	test-mlogloss:0.559229
# [102]	train-mlogloss:0.46865	test-mlogloss:0.55907
# [103]	train-mlogloss:0.467786	test-mlogloss:0.558914
# [104]	train-mlogloss:0.466722	test-mlogloss:0.558683
# [105]	train-mlogloss:0.465949	test-mlogloss:0.558625
# [106]	train-mlogloss:0.465237	test-mlogloss:0.558496
# [107]	train-mlogloss:0.464393	test-mlogloss:0.558427
# [108]	train-mlogloss:0.463513	test-mlogloss:0.558174
# [109]	train-mlogloss:0.462669	test-mlogloss:0.558082
# [110]	train-mlogloss:0.461754	test-mlogloss:0.557885
# [111]	train-mlogloss:0.460993	test-mlogloss:0.557865
# [112]	train-mlogloss:0.460086	test-mlogloss:0.557712
# [113]	train-mlogloss:0.459494	test-mlogloss:0.557651
# [114]	train-mlogloss:0.458635	test-mlogloss:0.557552
# [115]	train-mlogloss:0.457887	test-mlogloss:0.557403
# [116]	train-mlogloss:0.45739	test-mlogloss:0.557348
# [117]	train-mlogloss:0.456424	test-mlogloss:0.557165
# [118]	train-mlogloss:0.455828	test-mlogloss:0.55706
# [119]	train-mlogloss:0.455221	test-mlogloss:0.557016
# [120]	train-mlogloss:0.454252	test-mlogloss:0.556839
# [121]	train-mlogloss:0.453593	test-mlogloss:0.556766
# [122]	train-mlogloss:0.452827	test-mlogloss:0.556646
# [123]	train-mlogloss:0.451995	test-mlogloss:0.55658
# [124]	train-mlogloss:0.451538	test-mlogloss:0.55648
# [125]	train-mlogloss:0.450822	test-mlogloss:0.556398
# [126]	train-mlogloss:0.450257	test-mlogloss:0.556359
# [127]	train-mlogloss:0.449733	test-mlogloss:0.556291
# [128]	train-mlogloss:0.448955	test-mlogloss:0.555961
# [129]	train-mlogloss:0.448382	test-mlogloss:0.555788
# [130]	train-mlogloss:0.447735	test-mlogloss:0.555605
# [131]	train-mlogloss:0.446774	test-mlogloss:0.555551
# [132]	train-mlogloss:0.446238	test-mlogloss:0.555515
# [133]	train-mlogloss:0.445516	test-mlogloss:0.55534
# [134]	train-mlogloss:0.444645	test-mlogloss:0.555184
# [135]	train-mlogloss:0.443899	test-mlogloss:0.555106
# [136]	train-mlogloss:0.443455	test-mlogloss:0.555002
# [137]	train-mlogloss:0.442739	test-mlogloss:0.554975
# [138]	train-mlogloss:0.4421	test-mlogloss:0.554821
# [139]	train-mlogloss:0.441511	test-mlogloss:0.554709
# [140]	train-mlogloss:0.440913	test-mlogloss:0.554672
# [141]	train-mlogloss:0.440271	test-mlogloss:0.554573
# [142]	train-mlogloss:0.439682	test-mlogloss:0.554456
# [143]	train-mlogloss:0.43916	test-mlogloss:0.554397
# [144]	train-mlogloss:0.438586	test-mlogloss:0.554371
# [145]	train-mlogloss:0.437981	test-mlogloss:0.55433
# [146]	train-mlogloss:0.437238	test-mlogloss:0.554256
# [147]	train-mlogloss:0.436685	test-mlogloss:0.554176
# [148]	train-mlogloss:0.436136	test-mlogloss:0.554298
# [149]	train-mlogloss:0.435584	test-mlogloss:0.554231
# [150]	train-mlogloss:0.434998	test-mlogloss:0.554202
# [151]	train-mlogloss:0.434333	test-mlogloss:0.554236
# [152]	train-mlogloss:0.433517	test-mlogloss:0.554158
# [153]	train-mlogloss:0.433102	test-mlogloss:0.554233
# [154]	train-mlogloss:0.432561	test-mlogloss:0.554205
# [155]	train-mlogloss:0.43192	test-mlogloss:0.55418
# [156]	train-mlogloss:0.431399	test-mlogloss:0.554119
# [157]	train-mlogloss:0.430771	test-mlogloss:0.553965
# [158]	train-mlogloss:0.430209	test-mlogloss:0.553776
# [159]	train-mlogloss:0.429781	test-mlogloss:0.553789
# [160]	train-mlogloss:0.429116	test-mlogloss:0.553681
# [161]	train-mlogloss:0.42834	test-mlogloss:0.553567
# [162]	train-mlogloss:0.427706	test-mlogloss:0.553576
# [163]	train-mlogloss:0.426982	test-mlogloss:0.553451
# [164]	train-mlogloss:0.426267	test-mlogloss:0.553495
# [165]	train-mlogloss:0.425534	test-mlogloss:0.553526
# [166]	train-mlogloss:0.424751	test-mlogloss:0.553555
# [167]	train-mlogloss:0.424161	test-mlogloss:0.553522
# [168]	train-mlogloss:0.423714	test-mlogloss:0.553523
# [169]	train-mlogloss:0.423021	test-mlogloss:0.553409
# [170]	train-mlogloss:0.422594	test-mlogloss:0.553398
# [171]	train-mlogloss:0.421951	test-mlogloss:0.553383
# [172]	train-mlogloss:0.421245	test-mlogloss:0.553327
# [173]	train-mlogloss:0.420552	test-mlogloss:0.553253
# [174]	train-mlogloss:0.420045	test-mlogloss:0.553128
# [175]	train-mlogloss:0.419296	test-mlogloss:0.553109
# [176]	train-mlogloss:0.418689	test-mlogloss:0.553136
# [177]	train-mlogloss:0.417929	test-mlogloss:0.553094
# [178]	train-mlogloss:0.417015	test-mlogloss:0.553014
# [179]	train-mlogloss:0.416703	test-mlogloss:0.553059
# [180]	train-mlogloss:0.415975	test-mlogloss:0.552983
# [181]	train-mlogloss:0.415499	test-mlogloss:0.553006
# [182]	train-mlogloss:0.414876	test-mlogloss:0.552975
# [183]	train-mlogloss:0.414279	test-mlogloss:0.552912
# [184]	train-mlogloss:0.413452	test-mlogloss:0.552763
# [185]	train-mlogloss:0.413037	test-mlogloss:0.552739
# [186]	train-mlogloss:0.4126	test-mlogloss:0.552726
# [187]	train-mlogloss:0.411971	test-mlogloss:0.552647
# [188]	train-mlogloss:0.41156	test-mlogloss:0.552589
# [189]	train-mlogloss:0.411011	test-mlogloss:0.552403
# [190]	train-mlogloss:0.410402	test-mlogloss:0.552391
# [191]	train-mlogloss:0.409856	test-mlogloss:0.552332
# [192]	train-mlogloss:0.409328	test-mlogloss:0.552268
# [193]	train-mlogloss:0.40902	test-mlogloss:0.552193
# [194]	train-mlogloss:0.408366	test-mlogloss:0.552059
# [195]	train-mlogloss:0.407847	test-mlogloss:0.552069
# [196]	train-mlogloss:0.407356	test-mlogloss:0.552139
# [197]	train-mlogloss:0.406987	test-mlogloss:0.552223
# [198]	train-mlogloss:0.406374	test-mlogloss:0.552136
# [199]	train-mlogloss:0.405846	test-mlogloss:0.552087
# [200]	train-mlogloss:0.405273	test-mlogloss:0.552138
# [201]	train-mlogloss:0.404895	test-mlogloss:0.552208
# [202]	train-mlogloss:0.40438	test-mlogloss:0.552283
# [203]	train-mlogloss:0.40398	test-mlogloss:0.552257
# [204]	train-mlogloss:0.403429	test-mlogloss:0.552279
# [205]	train-mlogloss:0.403066	test-mlogloss:0.552333
# [206]	train-mlogloss:0.402458	test-mlogloss:0.552261
# [207]	train-mlogloss:0.401929	test-mlogloss:0.552208
# [208]	train-mlogloss:0.401172	test-mlogloss:0.552185
# [209]	train-mlogloss:0.400591	test-mlogloss:0.552118
# [210]	train-mlogloss:0.400128	test-mlogloss:0.552165
# [211]	train-mlogloss:0.399558	test-mlogloss:0.552097
# [212]	train-mlogloss:0.398885	test-mlogloss:0.552185
# [213]	train-mlogloss:0.398419	test-mlogloss:0.552121
# [214]	train-mlogloss:0.397789	test-mlogloss:0.55207
# [215]	train-mlogloss:0.397336	test-mlogloss:0.552086
# [216]	train-mlogloss:0.3969	test-mlogloss:0.55199
# [217]	train-mlogloss:0.396366	test-mlogloss:0.551886
# [218]	train-mlogloss:0.395702	test-mlogloss:0.551899
# [219]	train-mlogloss:0.395103	test-mlogloss:0.551708
# [220]	train-mlogloss:0.394581	test-mlogloss:0.551679
# [221]	train-mlogloss:0.394141	test-mlogloss:0.551715
# [222]	train-mlogloss:0.393492	test-mlogloss:0.551707
# [223]	train-mlogloss:0.39283	test-mlogloss:0.551559
# [224]	train-mlogloss:0.392267	test-mlogloss:0.551565
# [225]	train-mlogloss:0.391683	test-mlogloss:0.551556
# [226]	train-mlogloss:0.39113	test-mlogloss:0.551655
# [227]	train-mlogloss:0.390599	test-mlogloss:0.551715
# [228]	train-mlogloss:0.389974	test-mlogloss:0.551683
# [229]	train-mlogloss:0.389308	test-mlogloss:0.551525
# [230]	train-mlogloss:0.388677	test-mlogloss:0.551495
# [231]	train-mlogloss:0.388097	test-mlogloss:0.551623
# [232]	train-mlogloss:0.387538	test-mlogloss:0.551603
# [233]	train-mlogloss:0.38709	test-mlogloss:0.551568
# [234]	train-mlogloss:0.386517	test-mlogloss:0.551526
# [235]	train-mlogloss:0.385939	test-mlogloss:0.551509
# [236]	train-mlogloss:0.385452	test-mlogloss:0.551535
# [237]	train-mlogloss:0.384884	test-mlogloss:0.551494
# [238]	train-mlogloss:0.384421	test-mlogloss:0.551567
# [239]	train-mlogloss:0.383774	test-mlogloss:0.551504
# [240]	train-mlogloss:0.383313	test-mlogloss:0.551428
# [241]	train-mlogloss:0.382852	test-mlogloss:0.551468
# [242]	train-mlogloss:0.382441	test-mlogloss:0.5515
# [243]	train-mlogloss:0.381997	test-mlogloss:0.551421
# [244]	train-mlogloss:0.381528	test-mlogloss:0.551383
# [245]	train-mlogloss:0.381314	test-mlogloss:0.551294
# [246]	train-mlogloss:0.380826	test-mlogloss:0.551255
# [247]	train-mlogloss:0.380434	test-mlogloss:0.551299
# [248]	train-mlogloss:0.379851	test-mlogloss:0.551299
# [249]	train-mlogloss:0.379323	test-mlogloss:0.55137
# [250]	train-mlogloss:0.378827	test-mlogloss:0.551478
# [251]	train-mlogloss:0.378335	test-mlogloss:0.551578
# [252]	train-mlogloss:0.377818	test-mlogloss:0.551646
# [253]	train-mlogloss:0.37725	test-mlogloss:0.551656
# [254]	train-mlogloss:0.376716	test-mlogloss:0.551746
# [255]	train-mlogloss:0.376185	test-mlogloss:0.551594
# [256]	train-mlogloss:0.375656	test-mlogloss:0.55156
# [257]	train-mlogloss:0.375117	test-mlogloss:0.551565
# [258]	train-mlogloss:0.374535	test-mlogloss:0.551515
# [259]	train-mlogloss:0.374002	test-mlogloss:0.551505
# [260]	train-mlogloss:0.373512	test-mlogloss:0.551431
# [261]	train-mlogloss:0.372976	test-mlogloss:0.551437
# [262]	train-mlogloss:0.372563	test-mlogloss:0.55134
# [263]	train-mlogloss:0.372008	test-mlogloss:0.551264
# [264]	train-mlogloss:0.371443	test-mlogloss:0.551261
# [265]	train-mlogloss:0.371014	test-mlogloss:0.551182
# [266]	train-mlogloss:0.370475	test-mlogloss:0.551079
# [267]	train-mlogloss:0.36989	test-mlogloss:0.551148
# [268]	train-mlogloss:0.36949	test-mlogloss:0.551161
# [269]	train-mlogloss:0.368944	test-mlogloss:0.551174
# [270]	train-mlogloss:0.368298	test-mlogloss:0.551255
# [271]	train-mlogloss:0.367854	test-mlogloss:0.551196
# [272]	train-mlogloss:0.367248	test-mlogloss:0.551303
# [273]	train-mlogloss:0.36667	test-mlogloss:0.551335
# [274]	train-mlogloss:0.366199	test-mlogloss:0.55127
# [275]	train-mlogloss:0.365813	test-mlogloss:0.551181
# [276]	train-mlogloss:0.365242	test-mlogloss:0.551029
# [277]	train-mlogloss:0.364836	test-mlogloss:0.550972
# [278]	train-mlogloss:0.364399	test-mlogloss:0.550977
# [279]	train-mlogloss:0.364001	test-mlogloss:0.550983
# [280]	train-mlogloss:0.363469	test-mlogloss:0.550959
# [281]	train-mlogloss:0.362944	test-mlogloss:0.551021
# [282]	train-mlogloss:0.362483	test-mlogloss:0.550978
# [283]	train-mlogloss:0.361837	test-mlogloss:0.550884
# [284]	train-mlogloss:0.361408	test-mlogloss:0.550909
# [285]	train-mlogloss:0.360941	test-mlogloss:0.550874
# [286]	train-mlogloss:0.360621	test-mlogloss:0.550864
# [287]	train-mlogloss:0.360179	test-mlogloss:0.550748
# [288]	train-mlogloss:0.359831	test-mlogloss:0.550752
# [289]	train-mlogloss:0.359458	test-mlogloss:0.550753
# [290]	train-mlogloss:0.359014	test-mlogloss:0.550709
# [291]	train-mlogloss:0.358737	test-mlogloss:0.550716
# [292]	train-mlogloss:0.358291	test-mlogloss:0.550803
# [293]	train-mlogloss:0.35775	test-mlogloss:0.550643
# [294]	train-mlogloss:0.357163	test-mlogloss:0.550601
# [295]	train-mlogloss:0.356852	test-mlogloss:0.550552
# [296]	train-mlogloss:0.356525	test-mlogloss:0.550509
# [297]	train-mlogloss:0.356113	test-mlogloss:0.550551
# [298]	train-mlogloss:0.355713	test-mlogloss:0.550662
# [299]	train-mlogloss:0.355213	test-mlogloss:0.55064
# [300]	train-mlogloss:0.354824	test-mlogloss:0.55054
# [301]	train-mlogloss:0.354355	test-mlogloss:0.550536
# [302]	train-mlogloss:0.353851	test-mlogloss:0.550536
# [303]	train-mlogloss:0.353441	test-mlogloss:0.550628
# [304]	train-mlogloss:0.353027	test-mlogloss:0.550679
# [305]	train-mlogloss:0.352631	test-mlogloss:0.550618
# [306]	train-mlogloss:0.352147	test-mlogloss:0.550579
# [307]	train-mlogloss:0.351658	test-mlogloss:0.550704
# [308]	train-mlogloss:0.351224	test-mlogloss:0.550794
# [309]	train-mlogloss:0.350857	test-mlogloss:0.550863
# [310]	train-mlogloss:0.35045	test-mlogloss:0.550903
# [311]	train-mlogloss:0.350103	test-mlogloss:0.551004
# [312]	train-mlogloss:0.349786	test-mlogloss:0.551002
# [313]	train-mlogloss:0.349442	test-mlogloss:0.551171
# [314]	train-mlogloss:0.348834	test-mlogloss:0.551075
# [315]	train-mlogloss:0.348399	test-mlogloss:0.551123
# [316]	train-mlogloss:0.347967	test-mlogloss:0.551135
# [317]	train-mlogloss:0.347431	test-mlogloss:0.551039
# [318]	train-mlogloss:0.347028	test-mlogloss:0.551038
# [319]	train-mlogloss:0.346546	test-mlogloss:0.551047
# [320]	train-mlogloss:0.346011	test-mlogloss:0.550958
# [321]	train-mlogloss:0.345663	test-mlogloss:0.55099
# [322]	train-mlogloss:0.34516	test-mlogloss:0.550973
# [323]	train-mlogloss:0.344766	test-mlogloss:0.550891
# [324]	train-mlogloss:0.344237	test-mlogloss:0.550861
# [325]	train-mlogloss:0.343737	test-mlogloss:0.550853
# [326]	train-mlogloss:0.34328	test-mlogloss:0.550901
# [327]	train-mlogloss:0.342877	test-mlogloss:0.550943
# [328]	train-mlogloss:0.342447	test-mlogloss:0.551121
# [329]	train-mlogloss:0.34193	test-mlogloss:0.551093
# [330]	train-mlogloss:0.341616	test-mlogloss:0.551103
# [331]	train-mlogloss:0.341263	test-mlogloss:0.551083
# [332]	train-mlogloss:0.34077	test-mlogloss:0.55109
# [333]	train-mlogloss:0.340333	test-mlogloss:0.551059
# [334]	train-mlogloss:0.339841	test-mlogloss:0.551036
# [335]	train-mlogloss:0.339488	test-mlogloss:0.55103
# [336]	train-mlogloss:0.338971	test-mlogloss:0.550998
# [337]	train-mlogloss:0.338562	test-mlogloss:0.551055
# [338]	train-mlogloss:0.338193	test-mlogloss:0.550961
# [339]	train-mlogloss:0.337881	test-mlogloss:0.550966
# [340]	train-mlogloss:0.337346	test-mlogloss:0.550991
# [341]	train-mlogloss:0.337041	test-mlogloss:0.551039
# [342]	train-mlogloss:0.336549	test-mlogloss:0.551057
# [343]	train-mlogloss:0.336144	test-mlogloss:0.551109
# [344]	train-mlogloss:0.335959	test-mlogloss:0.551115
# [345]	train-mlogloss:0.335486	test-mlogloss:0.551049
# [346]	train-mlogloss:0.33512	test-mlogloss:0.551053
# [347]	train-mlogloss:0.334742	test-mlogloss:0.551124
# [348]	train-mlogloss:0.33432	test-mlogloss:0.551034
# [349]	train-mlogloss:0.333917	test-mlogloss:0.551109
# [350]	train-mlogloss:0.33345	test-mlogloss:0.551019
# [351]	train-mlogloss:0.333041	test-mlogloss:0.55108
# [352]	train-mlogloss:0.332613	test-mlogloss:0.551046
# [353]	train-mlogloss:0.332185	test-mlogloss:0.551089
# [354]	train-mlogloss:0.33174	test-mlogloss:0.551202
# [355]	train-mlogloss:0.331315	test-mlogloss:0.551112
# [356]	train-mlogloss:0.330922	test-mlogloss:0.551035
# [357]	train-mlogloss:0.330653	test-mlogloss:0.551064
# [358]	train-mlogloss:0.330171	test-mlogloss:0.551016
# [359]	train-mlogloss:0.329854	test-mlogloss:0.550989
# [360]	train-mlogloss:0.329427	test-mlogloss:0.551024
# [361]	train-mlogloss:0.329071	test-mlogloss:0.5512
# [362]	train-mlogloss:0.328779	test-mlogloss:0.551232
# [363]	train-mlogloss:0.328449	test-mlogloss:0.551249
# [364]	train-mlogloss:0.328129	test-mlogloss:0.551258
# [365]	train-mlogloss:0.327737	test-mlogloss:0.551231
# [366]	train-mlogloss:0.327318	test-mlogloss:0.55135
# [367]	train-mlogloss:0.326832	test-mlogloss:0.551417
# [368]	train-mlogloss:0.326415	test-mlogloss:0.551549
# [369]	train-mlogloss:0.326009	test-mlogloss:0.551573
# [370]	train-mlogloss:0.325541	test-mlogloss:0.55159
# [371]	train-mlogloss:0.32506	test-mlogloss:0.551551
# [372]	train-mlogloss:0.324615	test-mlogloss:0.551656
# [373]	train-mlogloss:0.324187	test-mlogloss:0.551858
# [374]	train-mlogloss:0.323629	test-mlogloss:0.551697
# [375]	train-mlogloss:0.32321	test-mlogloss:0.551787
# [376]	train-mlogloss:0.322924	test-mlogloss:0.551792
# [377]	train-mlogloss:0.322526	test-mlogloss:0.551816
# [378]	train-mlogloss:0.322078	test-mlogloss:0.551856
# [379]	train-mlogloss:0.321469	test-mlogloss:0.551821
# [380]	train-mlogloss:0.321095	test-mlogloss:0.551774
# [381]	train-mlogloss:0.320621	test-mlogloss:0.551748
# [382]	train-mlogloss:0.320254	test-mlogloss:0.551866
# [383]	train-mlogloss:0.319883	test-mlogloss:0.551853
# [384]	train-mlogloss:0.319499	test-mlogloss:0.551963
# [385]	train-mlogloss:0.319061	test-mlogloss:0.55201
# [386]	train-mlogloss:0.318849	test-mlogloss:0.552042
# [387]	train-mlogloss:0.318416	test-mlogloss:0.552161
# [388]	train-mlogloss:0.317968	test-mlogloss:0.552228
# [389]	train-mlogloss:0.31743	test-mlogloss:0.552185
# [390]	train-mlogloss:0.31706	test-mlogloss:0.552152
# [391]	train-mlogloss:0.316575	test-mlogloss:0.552103
# [392]	train-mlogloss:0.316272	test-mlogloss:0.552112
# [393]	train-mlogloss:0.315911	test-mlogloss:0.552142
# [394]	train-mlogloss:0.31551	test-mlogloss:0.552137
# [395]	train-mlogloss:0.315239	test-mlogloss:0.55216
# [396]	train-mlogloss:0.314926	test-mlogloss:0.552226
# Stopping. Best iteration:
# [296]	train-mlogloss:0.356525	test-mlogloss:0.550509
#
# [0.5522255412779673]

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
