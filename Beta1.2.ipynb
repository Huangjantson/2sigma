# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None,\
           seed_val=0, num_rounds=10000,watch_dict = None):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100,\
                         evals_result = )
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
def manager_skill_eval(train_df,test_df,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df.manager_id,pd.get_dummies(train_df.interest_level)], axis = 1).groupby('manager_id').mean()
     
    temp.columns = ['ManHigh','ManLow', 'ManMedium']
    
    print temp.columns
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    temp['manager_skill'] = temp['ManHigh']*2 + temp['ManMedium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    mean_values_total = temp.loc[:, ['ManHigh','ManLow', 'ManMedium','manager_skill']].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values.values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index(),how='left', left_on='manager_id', right_on='manager_id')
    new_manager_ixes = new_test_df['ManHigh'].isnull()
    new_test_df.loc[new_manager_ixes,['ManHigh','ManLow', 'ManMedium','manager_skill']] = mean_values_total.values           
    
    return new_train_df,new_test_df

# %%
#dealing feature with categorical features 
"""
display_address 8826    
building_id        7585   =》many zeros in this feature
manager_id   3481
street_address 15358 =》will be 3800 if no numbers in it 
"""
categorical = ["display_address", "manager_id", "building_id", "street_address"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
#output the outcome - using xgboost
train_set, test_set =manager_skill_eval(train_df,test_df)

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=350)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1_withManagerSkillandAveragePrice.csv", index=False)
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')

# %%
#running and getting the cv from xgboost
cv_scores = []
#K-FOLD already defined.If not ,use
#KF=KFold(len(train_X),5,shuffle=True,random_state = 42)
for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #apply the function for createing some featues
        dev_set, val_set =manager_skill_eval(dev_set,val_set)
        #features_to_use.extend(['ManHigh','ManLow', 'ManMedium','manager_skill'])
        features_to_use.append('manager_skill')
        
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# Index([u'ManHigh', u'ManLow', u'ManMedium'], dtype='object')
# [0]	train-mlogloss:1.03702	test-mlogloss:1.03881
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.978689	test-mlogloss:0.982902
# [2]	train-mlogloss:0.932898	test-mlogloss:0.938806
# [3]	train-mlogloss:0.889639	test-mlogloss:0.897675
# [4]	train-mlogloss:0.853041	test-mlogloss:0.863326
# [5]	train-mlogloss:0.824851	test-mlogloss:0.836011
# [6]	train-mlogloss:0.797258	test-mlogloss:0.809789
# [7]	train-mlogloss:0.773587	test-mlogloss:0.78721
# [8]	train-mlogloss:0.751293	test-mlogloss:0.766405
# [9]	train-mlogloss:0.731565	test-mlogloss:0.74778
# [10]	train-mlogloss:0.714858	test-mlogloss:0.732405
# [11]	train-mlogloss:0.698194	test-mlogloss:0.717159
# [12]	train-mlogloss:0.684444	test-mlogloss:0.704695
# [13]	train-mlogloss:0.671741	test-mlogloss:0.692872
# [14]	train-mlogloss:0.659529	test-mlogloss:0.682152
# [15]	train-mlogloss:0.648861	test-mlogloss:0.672763
# [16]	train-mlogloss:0.63984	test-mlogloss:0.664433
# [17]	train-mlogloss:0.630716	test-mlogloss:0.656754
# [18]	train-mlogloss:0.623335	test-mlogloss:0.650432
# [19]	train-mlogloss:0.616536	test-mlogloss:0.644729
# [20]	train-mlogloss:0.61009	test-mlogloss:0.63922
# [21]	train-mlogloss:0.604009	test-mlogloss:0.634254
# [22]	train-mlogloss:0.598484	test-mlogloss:0.629683
# [23]	train-mlogloss:0.593479	test-mlogloss:0.625475
# [24]	train-mlogloss:0.588279	test-mlogloss:0.621235
# [25]	train-mlogloss:0.583857	test-mlogloss:0.61779
# [26]	train-mlogloss:0.579729	test-mlogloss:0.61472
# [27]	train-mlogloss:0.575995	test-mlogloss:0.611805
# [28]	train-mlogloss:0.572417	test-mlogloss:0.609225
# [29]	train-mlogloss:0.56929	test-mlogloss:0.606716
# [30]	train-mlogloss:0.566275	test-mlogloss:0.604478
# [31]	train-mlogloss:0.563203	test-mlogloss:0.602191
# [32]	train-mlogloss:0.560185	test-mlogloss:0.600004
# [33]	train-mlogloss:0.55741	test-mlogloss:0.597825
# [34]	train-mlogloss:0.554735	test-mlogloss:0.596049
# [35]	train-mlogloss:0.552482	test-mlogloss:0.594722
# [36]	train-mlogloss:0.550558	test-mlogloss:0.59348
# [37]	train-mlogloss:0.54838	test-mlogloss:0.59199
# [38]	train-mlogloss:0.546282	test-mlogloss:0.590609
# [39]	train-mlogloss:0.544499	test-mlogloss:0.589446
# [40]	train-mlogloss:0.542589	test-mlogloss:0.588142
# [41]	train-mlogloss:0.54096	test-mlogloss:0.587161
# [42]	train-mlogloss:0.538818	test-mlogloss:0.585995
# [43]	train-mlogloss:0.537328	test-mlogloss:0.585196
# [44]	train-mlogloss:0.535505	test-mlogloss:0.584371
# [45]	train-mlogloss:0.534004	test-mlogloss:0.583778
# [46]	train-mlogloss:0.532259	test-mlogloss:0.582696
# [47]	train-mlogloss:0.530881	test-mlogloss:0.582238
# [48]	train-mlogloss:0.529387	test-mlogloss:0.581296
# [49]	train-mlogloss:0.527635	test-mlogloss:0.580346
# [50]	train-mlogloss:0.526358	test-mlogloss:0.579733
# [51]	train-mlogloss:0.524883	test-mlogloss:0.579117
# [52]	train-mlogloss:0.523328	test-mlogloss:0.578195
# [53]	train-mlogloss:0.52235	test-mlogloss:0.577504
# [54]	train-mlogloss:0.521077	test-mlogloss:0.576796
# [55]	train-mlogloss:0.519638	test-mlogloss:0.57611
# [56]	train-mlogloss:0.51823	test-mlogloss:0.575648
# [57]	train-mlogloss:0.517397	test-mlogloss:0.575287
# [58]	train-mlogloss:0.515832	test-mlogloss:0.574461
# [59]	train-mlogloss:0.514599	test-mlogloss:0.574134
# [60]	train-mlogloss:0.513093	test-mlogloss:0.573469
# [61]	train-mlogloss:0.512047	test-mlogloss:0.572865
# [62]	train-mlogloss:0.511123	test-mlogloss:0.572547
# [63]	train-mlogloss:0.509957	test-mlogloss:0.572027
# [64]	train-mlogloss:0.509165	test-mlogloss:0.571579
# [65]	train-mlogloss:0.507825	test-mlogloss:0.571067
# [66]	train-mlogloss:0.506858	test-mlogloss:0.570823
# [67]	train-mlogloss:0.505711	test-mlogloss:0.570296
# [68]	train-mlogloss:0.504353	test-mlogloss:0.569646
# [69]	train-mlogloss:0.503153	test-mlogloss:0.56922
# [70]	train-mlogloss:0.502225	test-mlogloss:0.569032
# [71]	train-mlogloss:0.501389	test-mlogloss:0.568865
# [72]	train-mlogloss:0.500394	test-mlogloss:0.568543
# [73]	train-mlogloss:0.499292	test-mlogloss:0.568193
# [74]	train-mlogloss:0.498336	test-mlogloss:0.567806
# [75]	train-mlogloss:0.497456	test-mlogloss:0.567557
# [76]	train-mlogloss:0.496538	test-mlogloss:0.567253
# [77]	train-mlogloss:0.495525	test-mlogloss:0.566729
# [78]	train-mlogloss:0.494814	test-mlogloss:0.566404
# [79]	train-mlogloss:0.493589	test-mlogloss:0.565972
# [80]	train-mlogloss:0.492558	test-mlogloss:0.56569
# [81]	train-mlogloss:0.491572	test-mlogloss:0.565483
# [82]	train-mlogloss:0.490657	test-mlogloss:0.565258
# [83]	train-mlogloss:0.489718	test-mlogloss:0.565111
# [84]	train-mlogloss:0.488647	test-mlogloss:0.565046
# [85]	train-mlogloss:0.487442	test-mlogloss:0.56471
# [86]	train-mlogloss:0.486467	test-mlogloss:0.56452
# [87]	train-mlogloss:0.48575	test-mlogloss:0.564321
# [88]	train-mlogloss:0.484646	test-mlogloss:0.56398
# [89]	train-mlogloss:0.483896	test-mlogloss:0.563844
# [90]	train-mlogloss:0.482967	test-mlogloss:0.563747
# [91]	train-mlogloss:0.482005	test-mlogloss:0.563595
# [92]	train-mlogloss:0.48127	test-mlogloss:0.563378
# [93]	train-mlogloss:0.480234	test-mlogloss:0.563229
# [94]	train-mlogloss:0.479271	test-mlogloss:0.562917
# [95]	train-mlogloss:0.478525	test-mlogloss:0.56276
# [96]	train-mlogloss:0.477691	test-mlogloss:0.562502
# [97]	train-mlogloss:0.476891	test-mlogloss:0.562398
# [98]	train-mlogloss:0.475922	test-mlogloss:0.562111
# [99]	train-mlogloss:0.475068	test-mlogloss:0.561835
# [100]	train-mlogloss:0.474109	test-mlogloss:0.561621
# [101]	train-mlogloss:0.473178	test-mlogloss:0.561437
# [102]	train-mlogloss:0.47233	test-mlogloss:0.561121
# [103]	train-mlogloss:0.471533	test-mlogloss:0.56089
# [104]	train-mlogloss:0.471022	test-mlogloss:0.560894
# [105]	train-mlogloss:0.470545	test-mlogloss:0.560736
# [106]	train-mlogloss:0.470022	test-mlogloss:0.560614
# [107]	train-mlogloss:0.46929	test-mlogloss:0.560504
# [108]	train-mlogloss:0.468286	test-mlogloss:0.560327
# [109]	train-mlogloss:0.467361	test-mlogloss:0.560105
# [110]	train-mlogloss:0.466726	test-mlogloss:0.560011
# [111]	train-mlogloss:0.46603	test-mlogloss:0.559749
# [112]	train-mlogloss:0.465352	test-mlogloss:0.559604
# [113]	train-mlogloss:0.464445	test-mlogloss:0.559325
# [114]	train-mlogloss:0.463934	test-mlogloss:0.5592
# [115]	train-mlogloss:0.463125	test-mlogloss:0.559075
# [116]	train-mlogloss:0.462379	test-mlogloss:0.558909
# [117]	train-mlogloss:0.461719	test-mlogloss:0.558719
# [118]	train-mlogloss:0.460954	test-mlogloss:0.558591
# [119]	train-mlogloss:0.460328	test-mlogloss:0.558502
# [120]	train-mlogloss:0.45994	test-mlogloss:0.558383
# [121]	train-mlogloss:0.459208	test-mlogloss:0.558244
# [122]	train-mlogloss:0.458377	test-mlogloss:0.557956
# [123]	train-mlogloss:0.4577	test-mlogloss:0.557862
# [124]	train-mlogloss:0.457077	test-mlogloss:0.557827
# [125]	train-mlogloss:0.4562	test-mlogloss:0.557755
# [126]	train-mlogloss:0.455345	test-mlogloss:0.557627
# [127]	train-mlogloss:0.454573	test-mlogloss:0.557507
# [128]	train-mlogloss:0.453933	test-mlogloss:0.557378
# [129]	train-mlogloss:0.453257	test-mlogloss:0.557271
# [130]	train-mlogloss:0.452579	test-mlogloss:0.557158
# [131]	train-mlogloss:0.452228	test-mlogloss:0.557242
# [132]	train-mlogloss:0.451516	test-mlogloss:0.557154
# [133]	train-mlogloss:0.450951	test-mlogloss:0.557111
# [134]	train-mlogloss:0.45017	test-mlogloss:0.556887
# [135]	train-mlogloss:0.449517	test-mlogloss:0.556776
# [136]	train-mlogloss:0.448853	test-mlogloss:0.556722
# [137]	train-mlogloss:0.448007	test-mlogloss:0.556582
# [138]	train-mlogloss:0.447282	test-mlogloss:0.556584
# [139]	train-mlogloss:0.446761	test-mlogloss:0.556454
# [140]	train-mlogloss:0.446333	test-mlogloss:0.556449
# [141]	train-mlogloss:0.445692	test-mlogloss:0.556232
# [142]	train-mlogloss:0.444868	test-mlogloss:0.556013
# [143]	train-mlogloss:0.444141	test-mlogloss:0.555881
# [144]	train-mlogloss:0.443509	test-mlogloss:0.555815
# [145]	train-mlogloss:0.442799	test-mlogloss:0.555822
# [146]	train-mlogloss:0.441977	test-mlogloss:0.555631
# [147]	train-mlogloss:0.441323	test-mlogloss:0.555511
# [148]	train-mlogloss:0.440913	test-mlogloss:0.555518
# [149]	train-mlogloss:0.440051	test-mlogloss:0.555473
# [150]	train-mlogloss:0.439385	test-mlogloss:0.555444
# [151]	train-mlogloss:0.438781	test-mlogloss:0.555581
# [152]	train-mlogloss:0.43823	test-mlogloss:0.555431
# [153]	train-mlogloss:0.43763	test-mlogloss:0.55538
# [154]	train-mlogloss:0.437011	test-mlogloss:0.555133
# [155]	train-mlogloss:0.436389	test-mlogloss:0.555165
# [156]	train-mlogloss:0.435732	test-mlogloss:0.554991
# [157]	train-mlogloss:0.435202	test-mlogloss:0.55496
# [158]	train-mlogloss:0.43441	test-mlogloss:0.554811
# [159]	train-mlogloss:0.433847	test-mlogloss:0.554781
# [160]	train-mlogloss:0.433251	test-mlogloss:0.554676
# [161]	train-mlogloss:0.432715	test-mlogloss:0.554663
# [162]	train-mlogloss:0.432076	test-mlogloss:0.554607
# [163]	train-mlogloss:0.43147	test-mlogloss:0.554501
# [164]	train-mlogloss:0.43074	test-mlogloss:0.554454
# [165]	train-mlogloss:0.430015	test-mlogloss:0.554482
# [166]	train-mlogloss:0.429476	test-mlogloss:0.554452
# [167]	train-mlogloss:0.429118	test-mlogloss:0.554488
# [168]	train-mlogloss:0.428394	test-mlogloss:0.554333
# [169]	train-mlogloss:0.427829	test-mlogloss:0.554193
# [170]	train-mlogloss:0.427523	test-mlogloss:0.554256
# [171]	train-mlogloss:0.426822	test-mlogloss:0.554256
# [172]	train-mlogloss:0.426181	test-mlogloss:0.554255
# [173]	train-mlogloss:0.425542	test-mlogloss:0.554031
# [174]	train-mlogloss:0.425006	test-mlogloss:0.553973
# [175]	train-mlogloss:0.424182	test-mlogloss:0.553775
# [176]	train-mlogloss:0.423737	test-mlogloss:0.553879
# [177]	train-mlogloss:0.423076	test-mlogloss:0.553763
# [178]	train-mlogloss:0.422355	test-mlogloss:0.553619
# [179]	train-mlogloss:0.421813	test-mlogloss:0.553545
# [180]	train-mlogloss:0.421216	test-mlogloss:0.553379
# [181]	train-mlogloss:0.420712	test-mlogloss:0.55335
# [182]	train-mlogloss:0.420107	test-mlogloss:0.553295
# [183]	train-mlogloss:0.419534	test-mlogloss:0.553202
# [184]	train-mlogloss:0.41893	test-mlogloss:0.553161
# [185]	train-mlogloss:0.4185	test-mlogloss:0.553299
# [186]	train-mlogloss:0.417849	test-mlogloss:0.55328
# [187]	train-mlogloss:0.417146	test-mlogloss:0.553253
# [188]	train-mlogloss:0.416376	test-mlogloss:0.553366
# [189]	train-mlogloss:0.415713	test-mlogloss:0.553466
# [190]	train-mlogloss:0.415017	test-mlogloss:0.553451
# [191]	train-mlogloss:0.414466	test-mlogloss:0.553392
# [192]	train-mlogloss:0.413825	test-mlogloss:0.553375
# [193]	train-mlogloss:0.413188	test-mlogloss:0.55341
# [194]	train-mlogloss:0.412634	test-mlogloss:0.553482
# [195]	train-mlogloss:0.412108	test-mlogloss:0.553563
# [196]	train-mlogloss:0.41153	test-mlogloss:0.553385
# [197]	train-mlogloss:0.411001	test-mlogloss:0.553446
# [198]	train-mlogloss:0.410442	test-mlogloss:0.553447
# [199]	train-mlogloss:0.40988	test-mlogloss:0.553282
# [200]	train-mlogloss:0.409393	test-mlogloss:0.553195
# [201]	train-mlogloss:0.408683	test-mlogloss:0.553126
# [202]	train-mlogloss:0.407952	test-mlogloss:0.552987
# [203]	train-mlogloss:0.407437	test-mlogloss:0.552953
# [204]	train-mlogloss:0.406866	test-mlogloss:0.553049
# [205]	train-mlogloss:0.406383	test-mlogloss:0.55292
# [206]	train-mlogloss:0.405888	test-mlogloss:0.552925
# [207]	train-mlogloss:0.405445	test-mlogloss:0.552914
# [208]	train-mlogloss:0.405016	test-mlogloss:0.552901
# [209]	train-mlogloss:0.404615	test-mlogloss:0.552884
# [210]	train-mlogloss:0.404106	test-mlogloss:0.552881
# [211]	train-mlogloss:0.403674	test-mlogloss:0.552937
# [212]	train-mlogloss:0.403244	test-mlogloss:0.552888
# [213]	train-mlogloss:0.402787	test-mlogloss:0.552921
# [214]	train-mlogloss:0.402243	test-mlogloss:0.552743
# [215]	train-mlogloss:0.401978	test-mlogloss:0.552803
# [216]	train-mlogloss:0.401385	test-mlogloss:0.552775
# [217]	train-mlogloss:0.400637	test-mlogloss:0.552666
# [218]	train-mlogloss:0.400092	test-mlogloss:0.552588
# [219]	train-mlogloss:0.399412	test-mlogloss:0.552572
# [220]	train-mlogloss:0.398932	test-mlogloss:0.552557
# [221]	train-mlogloss:0.398378	test-mlogloss:0.552501
# [222]	train-mlogloss:0.398092	test-mlogloss:0.55252
# [223]	train-mlogloss:0.397766	test-mlogloss:0.552562
# [224]	train-mlogloss:0.397261	test-mlogloss:0.552538
# [225]	train-mlogloss:0.396764	test-mlogloss:0.552536
# [226]	train-mlogloss:0.396195	test-mlogloss:0.552558
# [227]	train-mlogloss:0.395675	test-mlogloss:0.552549
# [228]	train-mlogloss:0.395145	test-mlogloss:0.552569
# [229]	train-mlogloss:0.394708	test-mlogloss:0.552517
# [230]	train-mlogloss:0.394371	test-mlogloss:0.552515
# [231]	train-mlogloss:0.393869	test-mlogloss:0.552458
# [232]	train-mlogloss:0.393483	test-mlogloss:0.552505
# [233]	train-mlogloss:0.392896	test-mlogloss:0.55253
# [234]	train-mlogloss:0.392261	test-mlogloss:0.552412
# [235]	train-mlogloss:0.391918	test-mlogloss:0.552336
# [236]	train-mlogloss:0.391551	test-mlogloss:0.552422
# [237]	train-mlogloss:0.39106	test-mlogloss:0.55234
# [238]	train-mlogloss:0.390602	test-mlogloss:0.552334
# [239]	train-mlogloss:0.389874	test-mlogloss:0.552195
# [240]	train-mlogloss:0.38927	test-mlogloss:0.552251
# [241]	train-mlogloss:0.388785	test-mlogloss:0.552183
# [242]	train-mlogloss:0.388331	test-mlogloss:0.552143
# [243]	train-mlogloss:0.387742	test-mlogloss:0.55215
# [244]	train-mlogloss:0.387232	test-mlogloss:0.552224
# [245]	train-mlogloss:0.386706	test-mlogloss:0.552196
# [246]	train-mlogloss:0.386121	test-mlogloss:0.552153
# [247]	train-mlogloss:0.385577	test-mlogloss:0.552322
# [248]	train-mlogloss:0.38504	test-mlogloss:0.552432
# [249]	train-mlogloss:0.384591	test-mlogloss:0.552375
# [250]	train-mlogloss:0.384016	test-mlogloss:0.55228
# [251]	train-mlogloss:0.383533	test-mlogloss:0.552285
# [252]	train-mlogloss:0.383188	test-mlogloss:0.552417
# [253]	train-mlogloss:0.382711	test-mlogloss:0.552415
# [254]	train-mlogloss:0.382226	test-mlogloss:0.552411
# [255]	train-mlogloss:0.381644	test-mlogloss:0.552303
# [256]	train-mlogloss:0.381215	test-mlogloss:0.552323
# [257]	train-mlogloss:0.380718	test-mlogloss:0.552353
# [258]	train-mlogloss:0.380154	test-mlogloss:0.55229
# [259]	train-mlogloss:0.379704	test-mlogloss:0.552243
# [260]	train-mlogloss:0.379245	test-mlogloss:0.552286
# [261]	train-mlogloss:0.37874	test-mlogloss:0.552193
# [262]	train-mlogloss:0.378317	test-mlogloss:0.552071
# [263]	train-mlogloss:0.377853	test-mlogloss:0.552046
# [264]	train-mlogloss:0.37727	test-mlogloss:0.552069
# [265]	train-mlogloss:0.376889	test-mlogloss:0.552081
# [266]	train-mlogloss:0.376325	test-mlogloss:0.552091
# [267]	train-mlogloss:0.375898	test-mlogloss:0.552014
# [268]	train-mlogloss:0.375396	test-mlogloss:0.552138
# [269]	train-mlogloss:0.37492	test-mlogloss:0.552034
# [270]	train-mlogloss:0.374356	test-mlogloss:0.552013
# [271]	train-mlogloss:0.373852	test-mlogloss:0.551863
# [272]	train-mlogloss:0.373368	test-mlogloss:0.55183
# [273]	train-mlogloss:0.372968	test-mlogloss:0.551922
# [274]	train-mlogloss:0.372633	test-mlogloss:0.551925
# [275]	train-mlogloss:0.372216	test-mlogloss:0.551945
# [276]	train-mlogloss:0.371729	test-mlogloss:0.551798
# [277]	train-mlogloss:0.371209	test-mlogloss:0.5517
# [278]	train-mlogloss:0.370645	test-mlogloss:0.551737
# [279]	train-mlogloss:0.370158	test-mlogloss:0.551787
# [280]	train-mlogloss:0.369735	test-mlogloss:0.551761
# [281]	train-mlogloss:0.369483	test-mlogloss:0.55184
# [282]	train-mlogloss:0.369013	test-mlogloss:0.551754
# [283]	train-mlogloss:0.368516	test-mlogloss:0.551856
# [284]	train-mlogloss:0.368045	test-mlogloss:0.551808
# [285]	train-mlogloss:0.367617	test-mlogloss:0.551888
# [286]	train-mlogloss:0.367143	test-mlogloss:0.551858
# [287]	train-mlogloss:0.36652	test-mlogloss:0.551879
# [288]	train-mlogloss:0.366158	test-mlogloss:0.551905
# [289]	train-mlogloss:0.365633	test-mlogloss:0.551889
# [290]	train-mlogloss:0.365103	test-mlogloss:0.551902
# [291]	train-mlogloss:0.364552	test-mlogloss:0.551823
# [292]	train-mlogloss:0.364019	test-mlogloss:0.551847
# [293]	train-mlogloss:0.363664	test-mlogloss:0.551892
# [294]	train-mlogloss:0.363208	test-mlogloss:0.551843
# [295]	train-mlogloss:0.362757	test-mlogloss:0.55195
# [296]	train-mlogloss:0.362355	test-mlogloss:0.551936
# [297]	train-mlogloss:0.361921	test-mlogloss:0.552014
# [298]	train-mlogloss:0.36131	test-mlogloss:0.551986
# [299]	train-mlogloss:0.360904	test-mlogloss:0.551886
# [300]	train-mlogloss:0.360537	test-mlogloss:0.551832
# [301]	train-mlogloss:0.360202	test-mlogloss:0.551846
# [302]	train-mlogloss:0.359895	test-mlogloss:0.551865
# [303]	train-mlogloss:0.359352	test-mlogloss:0.551819
# [304]	train-mlogloss:0.358893	test-mlogloss:0.551799
# [305]	train-mlogloss:0.358631	test-mlogloss:0.551791
# [306]	train-mlogloss:0.358245	test-mlogloss:0.551819
# [307]	train-mlogloss:0.357772	test-mlogloss:0.551895
# [308]	train-mlogloss:0.357182	test-mlogloss:0.551962
# [309]	train-mlogloss:0.356915	test-mlogloss:0.551827
# [310]	train-mlogloss:0.356539	test-mlogloss:0.551824
# [311]	train-mlogloss:0.35622	test-mlogloss:0.551765
# [312]	train-mlogloss:0.355856	test-mlogloss:0.551733
# [313]	train-mlogloss:0.355375	test-mlogloss:0.551771
# [314]	train-mlogloss:0.354913	test-mlogloss:0.551839
# [315]	train-mlogloss:0.354442	test-mlogloss:0.551756
# [316]	train-mlogloss:0.353845	test-mlogloss:0.551816
# [317]	train-mlogloss:0.353314	test-mlogloss:0.55176
# [318]	train-mlogloss:0.35287	test-mlogloss:0.551643
# [319]	train-mlogloss:0.352516	test-mlogloss:0.551632
# [320]	train-mlogloss:0.352168	test-mlogloss:0.551581
# [321]	train-mlogloss:0.351721	test-mlogloss:0.551612
# [322]	train-mlogloss:0.351172	test-mlogloss:0.55175
# [323]	train-mlogloss:0.350594	test-mlogloss:0.551844
# [324]	train-mlogloss:0.35023	test-mlogloss:0.551781
# [325]	train-mlogloss:0.349843	test-mlogloss:0.551788
# [326]	train-mlogloss:0.349423	test-mlogloss:0.551846
# [327]	train-mlogloss:0.348944	test-mlogloss:0.551838
# [328]	train-mlogloss:0.348569	test-mlogloss:0.55185
# [329]	train-mlogloss:0.348103	test-mlogloss:0.551884
# [330]	train-mlogloss:0.347718	test-mlogloss:0.551766
# [331]	train-mlogloss:0.347279	test-mlogloss:0.551803
# [332]	train-mlogloss:0.346895	test-mlogloss:0.551709
# [333]	train-mlogloss:0.346477	test-mlogloss:0.551694
# [334]	train-mlogloss:0.346153	test-mlogloss:0.551598
# [335]	train-mlogloss:0.34581	test-mlogloss:0.551618
# [336]	train-mlogloss:0.345395	test-mlogloss:0.551572
# [337]	train-mlogloss:0.345047	test-mlogloss:0.551549
# [338]	train-mlogloss:0.344638	test-mlogloss:0.551523
# [339]	train-mlogloss:0.344161	test-mlogloss:0.551412
# [340]	train-mlogloss:0.343753	test-mlogloss:0.551438
# [341]	train-mlogloss:0.343419	test-mlogloss:0.55139
# [342]	train-mlogloss:0.342957	test-mlogloss:0.551359
# [343]	train-mlogloss:0.342576	test-mlogloss:0.551408
# [344]	train-mlogloss:0.342222	test-mlogloss:0.551404
# [345]	train-mlogloss:0.341832	test-mlogloss:0.55152
# [346]	train-mlogloss:0.341517	test-mlogloss:0.551481
# [347]	train-mlogloss:0.341053	test-mlogloss:0.551494
# [348]	train-mlogloss:0.340568	test-mlogloss:0.551487
# [349]	train-mlogloss:0.340147	test-mlogloss:0.551544
# [350]	train-mlogloss:0.339856	test-mlogloss:0.55158
# [351]	train-mlogloss:0.339394	test-mlogloss:0.551451
# [352]	train-mlogloss:0.338987	test-mlogloss:0.551466
# [353]	train-mlogloss:0.338724	test-mlogloss:0.551577
# [354]	train-mlogloss:0.338187	test-mlogloss:0.551582
# [355]	train-mlogloss:0.337945	test-mlogloss:0.551592
# [356]	train-mlogloss:0.337648	test-mlogloss:0.551526
# [357]	train-mlogloss:0.337204	test-mlogloss:0.551507
# [358]	train-mlogloss:0.33677	test-mlogloss:0.551479
# [359]	train-mlogloss:0.336181	test-mlogloss:0.551536
# [360]	train-mlogloss:0.335604	test-mlogloss:0.551582
# [361]	train-mlogloss:0.335255	test-mlogloss:0.551533
# [362]	train-mlogloss:0.334844	test-mlogloss:0.551634
# [363]	train-mlogloss:0.334535	test-mlogloss:0.551605
# [364]	train-mlogloss:0.334128	test-mlogloss:0.551703
# [365]	train-mlogloss:0.333702	test-mlogloss:0.551691
# [366]	train-mlogloss:0.333237	test-mlogloss:0.551664
# [367]	train-mlogloss:0.332845	test-mlogloss:0.551673
# [368]	train-mlogloss:0.332394	test-mlogloss:0.551693
# [369]	train-mlogloss:0.332096	test-mlogloss:0.551711
# [370]	train-mlogloss:0.33172	test-mlogloss:0.551829
# [371]	train-mlogloss:0.331378	test-mlogloss:0.551872
# [372]	train-mlogloss:0.330945	test-mlogloss:0.5519
# [373]	train-mlogloss:0.330588	test-mlogloss:0.551968
# [374]	train-mlogloss:0.33021	test-mlogloss:0.552018
# [375]	train-mlogloss:0.329775	test-mlogloss:0.552043
# [376]	train-mlogloss:0.329327	test-mlogloss:0.552091
# [377]	train-mlogloss:0.328859	test-mlogloss:0.552073
# [378]	train-mlogloss:0.328332	test-mlogloss:0.552177
# [379]	train-mlogloss:0.327916	test-mlogloss:0.552212
# [380]	train-mlogloss:0.327461	test-mlogloss:0.552202
# [381]	train-mlogloss:0.327065	test-mlogloss:0.55222
# [382]	train-mlogloss:0.32664	test-mlogloss:0.552308
# [383]	train-mlogloss:0.326252	test-mlogloss:0.552445
# [384]	train-mlogloss:0.325961	test-mlogloss:0.55246
# [385]	train-mlogloss:0.325546	test-mlogloss:0.552466
# [386]	train-mlogloss:0.325261	test-mlogloss:0.552485
# [387]	train-mlogloss:0.324859	test-mlogloss:0.552659
# [388]	train-mlogloss:0.324464	test-mlogloss:0.552644
# [389]	train-mlogloss:0.324112	test-mlogloss:0.552773
# [390]	train-mlogloss:0.323839	test-mlogloss:0.552833
# [391]	train-mlogloss:0.323457	test-mlogloss:0.552887
# [392]	train-mlogloss:0.323064	test-mlogloss:0.552792
# [393]	train-mlogloss:0.3226	test-mlogloss:0.552856
# [394]	train-mlogloss:0.322195	test-mlogloss:0.55295
# [395]	train-mlogloss:0.321801	test-mlogloss:0.552983
# [396]	train-mlogloss:0.321378	test-mlogloss:0.552992
# [397]	train-mlogloss:0.321073	test-mlogloss:0.552995
# [398]	train-mlogloss:0.320669	test-mlogloss:0.552953
# [399]	train-mlogloss:0.320326	test-mlogloss:0.5529
# [400]	train-mlogloss:0.319944	test-mlogloss:0.552906
# [401]	train-mlogloss:0.319645	test-mlogloss:0.552956
# [402]	train-mlogloss:0.319387	test-mlogloss:0.552986
# [403]	train-mlogloss:0.318851	test-mlogloss:0.553025
# [404]	train-mlogloss:0.318443	test-mlogloss:0.553128
# [405]	train-mlogloss:0.318121	test-mlogloss:0.55326
# [406]	train-mlogloss:0.317703	test-mlogloss:0.553203
# [407]	train-mlogloss:0.317352	test-mlogloss:0.553244
# [408]	train-mlogloss:0.316965	test-mlogloss:0.553209
# [409]	train-mlogloss:0.31673	test-mlogloss:0.553207
# [410]	train-mlogloss:0.316363	test-mlogloss:0.553273
# [411]	train-mlogloss:0.316029	test-mlogloss:0.553396
# [412]	train-mlogloss:0.315635	test-mlogloss:0.553354
# [413]	train-mlogloss:0.315276	test-mlogloss:0.553336
# [414]	train-mlogloss:0.315018	test-mlogloss:0.553339
# [415]	train-mlogloss:0.314679	test-mlogloss:0.55334
# [416]	train-mlogloss:0.314343	test-mlogloss:0.55343
# [417]	train-mlogloss:0.313959	test-mlogloss:0.553449
# [418]	train-mlogloss:0.313596	test-mlogloss:0.553433
# [419]	train-mlogloss:0.313233	test-mlogloss:0.553442
# [420]	train-mlogloss:0.312684	test-mlogloss:0.553377
# [421]	train-mlogloss:0.312385	test-mlogloss:0.553364
# [422]	train-mlogloss:0.312018	test-mlogloss:0.553362
# [423]	train-mlogloss:0.311723	test-mlogloss:0.553384
# [424]	train-mlogloss:0.311312	test-mlogloss:0.553506
# [425]	train-mlogloss:0.310981	test-mlogloss:0.553571
# [426]	train-mlogloss:0.310545	test-mlogloss:0.553584
# [427]	train-mlogloss:0.31021	test-mlogloss:0.553461
# [428]	train-mlogloss:0.309806	test-mlogloss:0.553459
# [429]	train-mlogloss:0.309335	test-mlogloss:0.553598
# [430]	train-mlogloss:0.308876	test-mlogloss:0.553486
# [431]	train-mlogloss:0.30852	test-mlogloss:0.553565
# [432]	train-mlogloss:0.308171	test-mlogloss:0.5536
# [433]	train-mlogloss:0.307773	test-mlogloss:0.553606
# [434]	train-mlogloss:0.307468	test-mlogloss:0.553605
# [435]	train-mlogloss:0.307065	test-mlogloss:0.553511
# [436]	train-mlogloss:0.306682	test-mlogloss:0.553587
# [437]	train-mlogloss:0.306341	test-mlogloss:0.553603
# [438]	train-mlogloss:0.305914	test-mlogloss:0.553641
# [439]	train-mlogloss:0.30572	test-mlogloss:0.553666
# [440]	train-mlogloss:0.305333	test-mlogloss:0.553743
# [441]	train-mlogloss:0.304831	test-mlogloss:0.553929
# [442]	train-mlogloss:0.304481	test-mlogloss:0.553999
# Stopping. Best iteration:
# [342]	train-mlogloss:0.342957	test-mlogloss:0.551359
#
# [0.55399873793409238]

# %%
dev_set.columns
# Out:
# Index([            u'bathrooms',              u'bedrooms',
#                  u'building_id',               u'created',
#                  u'description',       u'display_address',
#                     u'features',        u'interest_level',
#                     u'latitude',            u'listing_id',
#                    u'longitude',            u'manager_id',
#                       u'photos',                 u'price',
#               u'street_address',            u'num_photos',
#                 u'num_features', u'num_description_words',
#                 u'created_year',         u'created_month',
#                  u'created_day',          u'created_hour'],
#       dtype='object')

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
