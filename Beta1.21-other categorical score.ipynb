# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn import  preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.cross_validation import KFold
import re
import string

# %%
#try xgboost
#fucntion from SRK
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=10000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y,feature_names=feature_names)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y,feature_names=feature_names)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=100)
    else:
        xgtest = xgb.DMatrix(test_X,feature_names=feature_names)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
#feature processing functions
#define punctutaion filter
def removePunctuation(x):
    #filter the head or tail blanks
    x = re.sub(r'^\s+',r' ',x)
    x = re.sub(r'\s+$',r' ',x)
    
    # Lowercasing all words
    x = x.lower()
    # Removing non ASCII chars, warning if you are dealing with other languages!!!!!!!!!!!!!!!
    x = re.sub(r'[^\x00-\x7f]',r' ',x)
    #change all the blank to space
    x = re.sub(r'\s',r' ',x)
    # Removing (replacing with empty spaces actually) all the punctuations
    removing = string.punctuation#.replace('-','')# except '-'
    removed = re.sub("["+removing+"]", "", x)
    #removing the line-changing
    #removed = re.sub('\\n'," ",removed)    
    return removed

#feature processing functions
def proecessStreet(address):
    #remove the building number
    pattern = re.compile('^[\d-]*[\s]+')
    street = removePunctuation(pattern.sub('',address))
    #sub the st to street
    pattern = re.compile('( st)$')
    street = pattern.sub(' street',street)
    #sub the ave to avenue
    pattern = re.compile('( ave)$')
    street = pattern.sub(' avenue',street)
    #nth -> n
    #nst -> n
    #nrd -> n
    #nnd -> n
    pattern = re.compile('(\d+)((th)|(st)|(rd)|(nd))')
    street = pattern.sub('\g<1>',street)
    #deal with the w 14 street => west 14 street
    pattern = re.compile('(w)(\s+)(\d+)')    
    street = pattern.sub('west \g<3>',street)
    #deal with the e....
    pattern = re.compile('(e)(\s+)(\d+)')    
    street = pattern.sub('east \g<3>',street)
    return street
    
def getStreetNumber(address):
    #get building id in the front, return -1 if their isn't
    pattern = re.compile('^([\d-]*)([\s]+)')
    try:
        number = pattern.search(address).group(1)
        return int(number)
    except:
        return -1

#from "this is a lit"s python version by rakhlin
def singleValueConvert(df1,df2,column):
    ps = df1[column].append(df2[column])
    grouped = ps.groupby(ps).size().to_frame().rename(columns={0: "size"})
    df1.loc[df1.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    df2.loc[df2.join(grouped, on=column, how="left")["size"] <= 1, column] = -1
    return df1, df2

# %%
def categorical_feature_scoring(train_df,test_df,feature,unrank_threshold = 10):

    target_num_map = {'High':2, 'Medium':1, 'Low':0}
    temp=pd.concat([train_df[feature],pd.get_dummies(train_df.interest_level)], axis = 1).groupby(feature).mean()
    print temp.columns
    
    temp['count'] = train_df.groupby('manager_id').count().iloc[:,1]
    
    new_feature = feature+'_score'
    
    temp[new_feature] = temp['high']*2 + temp['medium']
    
    #ixes of the managers with to few sample
    unranked_managers_ixes = temp['count']<unrank_threshold
    ranked_managers_ixes = ~unranked_managers_ixes
    
    #test for using rank or unrank part for the filling values
    mean_values = temp.loc[unranked_managers_ixes, new_feature].mean()
    mean_values_total = temp.loc[:,new_feature].mean()
    
    #reset their values to their average
    temp.loc[unranked_managers_ixes,new_feature] = mean_values
    
    #assign the features for the train set
    new_train_df = train_df.merge(temp.reset_index().ix[:,[feature,new_feature]],how='left',\
                                  left_on=feature, right_on=feature)
    
    #assign the features for the test/val set
    new_test_df = test_df.merge(temp.reset_index().ix[:,[feature,new_feature]],how='left',\
                                left_on=feature, right_on=feature)
    new_manager_ixes = new_test_df[new_feature].isnull()
    new_test_df.loc[new_manager_ixes,new_feature] = mean_values_total           
    
    return new_train_df,new_test_df

# %%
#lodaing data
data_path = "../../kaggleData/2sigma/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
#basic numerical features
features_to_use  = ["bathrooms", "bedrooms", "latitude", "longitude", "price"]

# %%
#some new numerical features related to the price
train_df["price_per_bath"] =  train_df["price"]*1.0/train_df["bathrooms"]
train_df["price_per_bed"] = train_df["price"]*1.0/train_df["bedrooms"]
train_df["bath_per_bed"] = train_df["bathrooms"]*1.0/train_df["bedrooms"]
train_df["price_per_room"] = train_df["price"]*1.0/(train_df["bedrooms"]+train_df["bathrooms"])

test_df["price_per_bath"] =  test_df["price"]*1.0/test_df["bathrooms"]
test_df["price_per_bed"] = test_df["price"]*1.0/test_df["bedrooms"]
test_df["bath_per_bed"] = test_df["bathrooms"]*1.0/test_df["bedrooms"]
test_df["price_per_room"] = test_df["price"]*1.0/(test_df["bedrooms"]+test_df["bathrooms"])

features_to_use.extend(["price_per_bed","bath_per_bed","price_per_room"])
#features_to_use.append('price_per_bed')

# %%
#some transfromed features
# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

# convert the created column to datetime object so as to extract more features 
train_df["created"] = pd.to_datetime(train_df["created"])
test_df["created"] = pd.to_datetime(test_df["created"])

# Let us extract some features like year, month, day, hour from date columns #
train_df["created_year"] = train_df["created"].dt.year
test_df["created_year"] = test_df["created"].dt.year
train_df["created_month"] = train_df["created"].dt.month
test_df["created_month"] = test_df["created"].dt.month
train_df["created_day"] = train_df["created"].dt.day
test_df["created_day"] = test_df["created"].dt.day
train_df["created_hour"] = train_df["created"].dt.hour
test_df["created_hour"] = test_df["created"].dt.hour

# adding all these new features to use list # "listing_id",
features_to_use.extend(["num_photos", "num_features", "num_description_words","created_year","listing_id", "created_month", "created_day", "created_hour"])

# %%
#new feature for the street_address, use them instead of the original one
train_df["street_name"] = train_df["street_address"].apply(proecessStreet)
test_df["street_name"] = test_df["street_address"].apply(proecessStreet)

train_df["street_number"] = train_df["street_address"].apply(getStreetNumber)
test_df["street_number"] = test_df["street_address"].apply(getStreetNumber)

#features_to_use.append("street_number")

# %%
#dealing feature with categorical features 
"""
display_address 8826    
building_id        7585   =》many zeros in this feature
manager_id   3481
street_address 15358 =》will be 3800 if no numbers in it 
"""
categorical = ["display_address", "manager_id", "building_id", "street_address","street_name"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
#prepare for training
target_num_map = {'high':0, 'medium':1, 'low':2}

train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

KF=KFold(len(train_df),5,shuffle=True,random_state = 42)

# %%
#output the outcome - using xgboost
train_set, test_set =manager_skill_eval(train_df,test_df)

train_X = train_set[features_to_use]
test_X = test_set[features_to_use]

train_X_m = train_X.as_matrix()
test_X_m = test_X.as_matrix()

preds, model = runXGB(train_X_m, train_y, test_X_m, num_rounds=340)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_beta1point2withStreetName.csv", index=False)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-12-e74111e93016> in <module>()
#       1 #output the outcome - using xgboost
# ----> 2 train_set, test_set =manager_skill_eval(train_df,test_df)
#       3
#       4 train_X = train_set[features_to_use]
#       5 test_X = test_set[features_to_use]
#
# NameError: name 'manager_skill_eval' is not defined

# %%
features_to_use.append('manager_id_score')
features_to_use.append('street_name_score')

#running and getting the cv from xgboost
cv_scores = []
#K-FOLD already defined.If not ,use
#KF=KFold(len(train_X),5,shuffle=True,random_state = 42)
for dev_index, val_index in KF:
        #split the orginal train set into dev_set and val_set
        dev_set, val_set = train_df.iloc[dev_index,:] , train_df.iloc[val_index,:] 
        
        #apply the function for createing some featues
        dev_set, val_set =categorical_feature_scoring(dev_set,val_set,'manager_id')
        dev_set, val_set =categorical_feature_scoring(dev_set,val_set,'street_name')
        #features_to_use.extend(['ManHigh','ManLow', 'ManMedium','manager_skill'])
        
        
        
        #filter the features
        dev_X, val_X = dev_set[features_to_use].as_matrix(), val_set[features_to_use].as_matrix()
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        
        preds, model = runXGB(dev_X, dev_y, val_X, val_y,feature_names=features_to_use)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# Index([u'high', u'low', u'medium'], dtype='object')
# Index([u'high', u'low', u'medium'], dtype='object')
# [0]	train-mlogloss:1.03209	test-mlogloss:1.03553
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 100 rounds.
# [1]	train-mlogloss:0.97614	test-mlogloss:0.982402
# [2]	train-mlogloss:0.926794	test-mlogloss:0.936809
# [3]	train-mlogloss:0.884491	test-mlogloss:0.897402
# [4]	train-mlogloss:0.847427	test-mlogloss:0.862713
# [5]	train-mlogloss:0.816599	test-mlogloss:0.834606
# [6]	train-mlogloss:0.789702	test-mlogloss:0.80945
# [7]	train-mlogloss:0.764583	test-mlogloss:0.785953
# [8]	train-mlogloss:0.744182	test-mlogloss:0.767616
# [9]	train-mlogloss:0.725133	test-mlogloss:0.750509
# [10]	train-mlogloss:0.707549	test-mlogloss:0.734601
# [11]	train-mlogloss:0.691847	test-mlogloss:0.720607
# [12]	train-mlogloss:0.677562	test-mlogloss:0.708497
# [13]	train-mlogloss:0.664883	test-mlogloss:0.697369
# [14]	train-mlogloss:0.652972	test-mlogloss:0.687221
# [15]	train-mlogloss:0.641707	test-mlogloss:0.677671
# [16]	train-mlogloss:0.631763	test-mlogloss:0.669452
# [17]	train-mlogloss:0.62276	test-mlogloss:0.662089
# [18]	train-mlogloss:0.614734	test-mlogloss:0.655748
# [19]	train-mlogloss:0.6077	test-mlogloss:0.650752
# [20]	train-mlogloss:0.601319	test-mlogloss:0.645632
# [21]	train-mlogloss:0.595172	test-mlogloss:0.640926
# [22]	train-mlogloss:0.589847	test-mlogloss:0.637014
# [23]	train-mlogloss:0.58496	test-mlogloss:0.633192
# [24]	train-mlogloss:0.580297	test-mlogloss:0.629765
# [25]	train-mlogloss:0.575554	test-mlogloss:0.625789
# [26]	train-mlogloss:0.571585	test-mlogloss:0.62345
# [27]	train-mlogloss:0.567411	test-mlogloss:0.620325
# [28]	train-mlogloss:0.564034	test-mlogloss:0.618016
# [29]	train-mlogloss:0.560699	test-mlogloss:0.616006
# [30]	train-mlogloss:0.55748	test-mlogloss:0.613724
# [31]	train-mlogloss:0.554434	test-mlogloss:0.611929
# [32]	train-mlogloss:0.551258	test-mlogloss:0.609626
# [33]	train-mlogloss:0.548734	test-mlogloss:0.607904
# [34]	train-mlogloss:0.546301	test-mlogloss:0.606484
# [35]	train-mlogloss:0.544076	test-mlogloss:0.605344
# [36]	train-mlogloss:0.541783	test-mlogloss:0.603908
# [37]	train-mlogloss:0.539779	test-mlogloss:0.602716
# [38]	train-mlogloss:0.538015	test-mlogloss:0.602043
# [39]	train-mlogloss:0.53622	test-mlogloss:0.601467
# [40]	train-mlogloss:0.533749	test-mlogloss:0.599926
# [41]	train-mlogloss:0.531966	test-mlogloss:0.598986
# [42]	train-mlogloss:0.530149	test-mlogloss:0.598511
# [43]	train-mlogloss:0.527999	test-mlogloss:0.597272
# [44]	train-mlogloss:0.526599	test-mlogloss:0.596975
# [45]	train-mlogloss:0.524667	test-mlogloss:0.595902
# [46]	train-mlogloss:0.52269	test-mlogloss:0.594684
# [47]	train-mlogloss:0.520966	test-mlogloss:0.59379
# [48]	train-mlogloss:0.519366	test-mlogloss:0.593252
# [49]	train-mlogloss:0.517887	test-mlogloss:0.592379
# [50]	train-mlogloss:0.516597	test-mlogloss:0.592122
# [51]	train-mlogloss:0.515544	test-mlogloss:0.591944
# [52]	train-mlogloss:0.51381	test-mlogloss:0.59103
# [53]	train-mlogloss:0.512757	test-mlogloss:0.590972
# [54]	train-mlogloss:0.511382	test-mlogloss:0.590572
# [55]	train-mlogloss:0.509994	test-mlogloss:0.590378
# [56]	train-mlogloss:0.508396	test-mlogloss:0.589844
# [57]	train-mlogloss:0.507126	test-mlogloss:0.589238
# [58]	train-mlogloss:0.505863	test-mlogloss:0.588706
# [59]	train-mlogloss:0.504664	test-mlogloss:0.588497
# [60]	train-mlogloss:0.503472	test-mlogloss:0.588328
# [61]	train-mlogloss:0.501998	test-mlogloss:0.587925
# [62]	train-mlogloss:0.500935	test-mlogloss:0.587483
# [63]	train-mlogloss:0.499921	test-mlogloss:0.587236
# [64]	train-mlogloss:0.498632	test-mlogloss:0.586861
# [65]	train-mlogloss:0.497774	test-mlogloss:0.586714
# [66]	train-mlogloss:0.49649	test-mlogloss:0.586351
# [67]	train-mlogloss:0.495442	test-mlogloss:0.585902
# [68]	train-mlogloss:0.494585	test-mlogloss:0.585564
# [69]	train-mlogloss:0.494006	test-mlogloss:0.585909
# [70]	train-mlogloss:0.493001	test-mlogloss:0.585614
# [71]	train-mlogloss:0.49173	test-mlogloss:0.585159
# [72]	train-mlogloss:0.490364	test-mlogloss:0.584588
# [73]	train-mlogloss:0.48914	test-mlogloss:0.584251
# [74]	train-mlogloss:0.488395	test-mlogloss:0.584095
# [75]	train-mlogloss:0.487427	test-mlogloss:0.583662
# [76]	train-mlogloss:0.486833	test-mlogloss:0.583795
# [77]	train-mlogloss:0.4855	test-mlogloss:0.58315
# [78]	train-mlogloss:0.484294	test-mlogloss:0.582788
# [79]	train-mlogloss:0.483251	test-mlogloss:0.582353
# [80]	train-mlogloss:0.481966	test-mlogloss:0.581914
# [81]	train-mlogloss:0.48128	test-mlogloss:0.581854
# [82]	train-mlogloss:0.480281	test-mlogloss:0.581532
# [83]	train-mlogloss:0.479128	test-mlogloss:0.581059
# [84]	train-mlogloss:0.478485	test-mlogloss:0.580887
# [85]	train-mlogloss:0.477578	test-mlogloss:0.580707
# [86]	train-mlogloss:0.476464	test-mlogloss:0.580515
# [87]	train-mlogloss:0.475459	test-mlogloss:0.580273
# [88]	train-mlogloss:0.474766	test-mlogloss:0.58023
# [89]	train-mlogloss:0.473619	test-mlogloss:0.579987
# [90]	train-mlogloss:0.472636	test-mlogloss:0.579826
# [91]	train-mlogloss:0.471788	test-mlogloss:0.579647
# [92]	train-mlogloss:0.47082	test-mlogloss:0.579478
# [93]	train-mlogloss:0.470016	test-mlogloss:0.579384
# [94]	train-mlogloss:0.469166	test-mlogloss:0.579261
# [95]	train-mlogloss:0.468155	test-mlogloss:0.579196
# [96]	train-mlogloss:0.467102	test-mlogloss:0.578932
# [97]	train-mlogloss:0.466389	test-mlogloss:0.578994
# [98]	train-mlogloss:0.465659	test-mlogloss:0.578878
# [99]	train-mlogloss:0.46472	test-mlogloss:0.578837
# [100]	train-mlogloss:0.463822	test-mlogloss:0.578761
# [101]	train-mlogloss:0.462959	test-mlogloss:0.578846
# [102]	train-mlogloss:0.46219	test-mlogloss:0.578632
# [103]	train-mlogloss:0.461635	test-mlogloss:0.578588
# [104]	train-mlogloss:0.460548	test-mlogloss:0.578262
# [105]	train-mlogloss:0.459901	test-mlogloss:0.578173
# [106]	train-mlogloss:0.459279	test-mlogloss:0.578264
# [107]	train-mlogloss:0.458377	test-mlogloss:0.57798
# [108]	train-mlogloss:0.45718	test-mlogloss:0.577521
# [109]	train-mlogloss:0.456437	test-mlogloss:0.577407
# [110]	train-mlogloss:0.455745	test-mlogloss:0.577401
# [111]	train-mlogloss:0.454877	test-mlogloss:0.577278
# [112]	train-mlogloss:0.454156	test-mlogloss:0.57729
# [113]	train-mlogloss:0.453063	test-mlogloss:0.576984
# [114]	train-mlogloss:0.452237	test-mlogloss:0.576826
# [115]	train-mlogloss:0.451492	test-mlogloss:0.576785
# [116]	train-mlogloss:0.450804	test-mlogloss:0.576609
# [117]	train-mlogloss:0.449915	test-mlogloss:0.576403
# [118]	train-mlogloss:0.449278	test-mlogloss:0.576231
# [119]	train-mlogloss:0.448547	test-mlogloss:0.576219
# [120]	train-mlogloss:0.447449	test-mlogloss:0.575935
# [121]	train-mlogloss:0.44682	test-mlogloss:0.575835
# [122]	train-mlogloss:0.446057	test-mlogloss:0.575702
# [123]	train-mlogloss:0.445278	test-mlogloss:0.575488
# [124]	train-mlogloss:0.444749	test-mlogloss:0.575397
# [125]	train-mlogloss:0.444109	test-mlogloss:0.575245
# [126]	train-mlogloss:0.443615	test-mlogloss:0.575234
# [127]	train-mlogloss:0.443058	test-mlogloss:0.575177
# [128]	train-mlogloss:0.442388	test-mlogloss:0.575098
# [129]	train-mlogloss:0.441923	test-mlogloss:0.574932
# [130]	train-mlogloss:0.440981	test-mlogloss:0.574962
# [131]	train-mlogloss:0.440017	test-mlogloss:0.574599
# [132]	train-mlogloss:0.439228	test-mlogloss:0.574589
# [133]	train-mlogloss:0.438358	test-mlogloss:0.574388
# [134]	train-mlogloss:0.437624	test-mlogloss:0.57431
# [135]	train-mlogloss:0.437039	test-mlogloss:0.574488
# [136]	train-mlogloss:0.436558	test-mlogloss:0.574302
# [137]	train-mlogloss:0.435711	test-mlogloss:0.574088
# [138]	train-mlogloss:0.435061	test-mlogloss:0.574199
# [139]	train-mlogloss:0.434513	test-mlogloss:0.574463
# [140]	train-mlogloss:0.433855	test-mlogloss:0.57436
# [141]	train-mlogloss:0.433071	test-mlogloss:0.574329
# [142]	train-mlogloss:0.432314	test-mlogloss:0.574144
# [143]	train-mlogloss:0.431923	test-mlogloss:0.574386
# [144]	train-mlogloss:0.431126	test-mlogloss:0.574245
# [145]	train-mlogloss:0.430485	test-mlogloss:0.574116
# [146]	train-mlogloss:0.429927	test-mlogloss:0.574158
# [147]	train-mlogloss:0.429364	test-mlogloss:0.57413
# [148]	train-mlogloss:0.428909	test-mlogloss:0.574385
# [149]	train-mlogloss:0.428312	test-mlogloss:0.574346
# [150]	train-mlogloss:0.427696	test-mlogloss:0.574324
# [151]	train-mlogloss:0.426908	test-mlogloss:0.57415
# [152]	train-mlogloss:0.426033	test-mlogloss:0.574079
# [153]	train-mlogloss:0.425329	test-mlogloss:0.57389
# [154]	train-mlogloss:0.424693	test-mlogloss:0.573775
# [155]	train-mlogloss:0.423968	test-mlogloss:0.573609
# [156]	train-mlogloss:0.423354	test-mlogloss:0.573386
# [157]	train-mlogloss:0.422737	test-mlogloss:0.573296
# [158]	train-mlogloss:0.421897	test-mlogloss:0.573239
# [159]	train-mlogloss:0.42144	test-mlogloss:0.573303
# [160]	train-mlogloss:0.420567	test-mlogloss:0.573151
# [161]	train-mlogloss:0.419761	test-mlogloss:0.572997
# [162]	train-mlogloss:0.418976	test-mlogloss:0.572738
# [163]	train-mlogloss:0.418364	test-mlogloss:0.57267
# [164]	train-mlogloss:0.417625	test-mlogloss:0.57266
# [165]	train-mlogloss:0.417013	test-mlogloss:0.572796
# [166]	train-mlogloss:0.416547	test-mlogloss:0.572668
# [167]	train-mlogloss:0.415977	test-mlogloss:0.572477
# [168]	train-mlogloss:0.415506	test-mlogloss:0.572441
# [169]	train-mlogloss:0.415136	test-mlogloss:0.572629
# [170]	train-mlogloss:0.414625	test-mlogloss:0.572637
# [171]	train-mlogloss:0.414078	test-mlogloss:0.572957
# [172]	train-mlogloss:0.413551	test-mlogloss:0.572967
# [173]	train-mlogloss:0.412645	test-mlogloss:0.573016
# [174]	train-mlogloss:0.412076	test-mlogloss:0.573045
# [175]	train-mlogloss:0.411413	test-mlogloss:0.573184
# [176]	train-mlogloss:0.410704	test-mlogloss:0.573184
# [177]	train-mlogloss:0.410085	test-mlogloss:0.573318
# [178]	train-mlogloss:0.409605	test-mlogloss:0.573233
# [179]	train-mlogloss:0.409286	test-mlogloss:0.573243
# [180]	train-mlogloss:0.408794	test-mlogloss:0.573499
# [181]	train-mlogloss:0.408142	test-mlogloss:0.573571
# [182]	train-mlogloss:0.407498	test-mlogloss:0.573631
# [183]	train-mlogloss:0.406867	test-mlogloss:0.573599
# [184]	train-mlogloss:0.406366	test-mlogloss:0.573718
# [185]	train-mlogloss:0.405959	test-mlogloss:0.573728
# [186]	train-mlogloss:0.405481	test-mlogloss:0.573773
# [187]	train-mlogloss:0.404978	test-mlogloss:0.573769
# [188]	train-mlogloss:0.404549	test-mlogloss:0.573797
# [189]	train-mlogloss:0.403796	test-mlogloss:0.573744
# [190]	train-mlogloss:0.40301	test-mlogloss:0.573629
# [191]	train-mlogloss:0.402357	test-mlogloss:0.57372
# [192]	train-mlogloss:0.401812	test-mlogloss:0.573585
# [193]	train-mlogloss:0.401207	test-mlogloss:0.573661
# [194]	train-mlogloss:0.400433	test-mlogloss:0.573494
# [195]	train-mlogloss:0.399972	test-mlogloss:0.573364
# [196]	train-mlogloss:0.399477	test-mlogloss:0.573406
# [197]	train-mlogloss:0.399024	test-mlogloss:0.573315
# [198]	train-mlogloss:0.398519	test-mlogloss:0.573253
# [199]	train-mlogloss:0.398228	test-mlogloss:0.573493
# [200]	train-mlogloss:0.397642	test-mlogloss:0.573519
# [201]	train-mlogloss:0.397219	test-mlogloss:0.573712
# [202]	train-mlogloss:0.396535	test-mlogloss:0.573775
# [203]	train-mlogloss:0.396356	test-mlogloss:0.574049
# [204]	train-mlogloss:0.395805	test-mlogloss:0.574012
# [205]	train-mlogloss:0.395487	test-mlogloss:0.574004
# [206]	train-mlogloss:0.394605	test-mlogloss:0.573994
# [207]	train-mlogloss:0.393971	test-mlogloss:0.574021
# [208]	train-mlogloss:0.393625	test-mlogloss:0.573933
# [209]	train-mlogloss:0.393103	test-mlogloss:0.574067
# [210]	train-mlogloss:0.392321	test-mlogloss:0.573947
# [211]	train-mlogloss:0.391787	test-mlogloss:0.574017
# [212]	train-mlogloss:0.39115	test-mlogloss:0.574312
# [213]	train-mlogloss:0.390672	test-mlogloss:0.574277
# [214]	train-mlogloss:0.390029	test-mlogloss:0.574154
# [215]	train-mlogloss:0.389541	test-mlogloss:0.574117
# [216]	train-mlogloss:0.389194	test-mlogloss:0.574077
# [217]	train-mlogloss:0.388658	test-mlogloss:0.574158
# [218]	train-mlogloss:0.388126	test-mlogloss:0.574248
# [219]	train-mlogloss:0.38751	test-mlogloss:0.574192
# [220]	train-mlogloss:0.387068	test-mlogloss:0.57412
# [221]	train-mlogloss:0.386665	test-mlogloss:0.574159
# [222]	train-mlogloss:0.386097	test-mlogloss:0.574123
# [223]	train-mlogloss:0.385456	test-mlogloss:0.574127
# [224]	train-mlogloss:0.38489	test-mlogloss:0.574057
# [225]	train-mlogloss:0.384269	test-mlogloss:0.574038
# [226]	train-mlogloss:0.383777	test-mlogloss:0.574141
# [227]	train-mlogloss:0.383238	test-mlogloss:0.574095
# [228]	train-mlogloss:0.382611	test-mlogloss:0.57416
# [229]	train-mlogloss:0.381992	test-mlogloss:0.574041
# [230]	train-mlogloss:0.381479	test-mlogloss:0.574091
# [231]	train-mlogloss:0.380868	test-mlogloss:0.574148
# [232]	train-mlogloss:0.380355	test-mlogloss:0.574168
# [233]	train-mlogloss:0.379863	test-mlogloss:0.574128
# [234]	train-mlogloss:0.379413	test-mlogloss:0.574137
# [235]	train-mlogloss:0.37885	test-mlogloss:0.574229
# [236]	train-mlogloss:0.378433	test-mlogloss:0.574202
# [237]	train-mlogloss:0.377656	test-mlogloss:0.574141
# [238]	train-mlogloss:0.377158	test-mlogloss:0.574126
# [239]	train-mlogloss:0.376761	test-mlogloss:0.574123
# [240]	train-mlogloss:0.376242	test-mlogloss:0.574084
# [241]	train-mlogloss:0.375927	test-mlogloss:0.574068
# [242]	train-mlogloss:0.375604	test-mlogloss:0.574054
# [243]	train-mlogloss:0.375174	test-mlogloss:0.574046
# [244]	train-mlogloss:0.374492	test-mlogloss:0.573853
# [245]	train-mlogloss:0.373876	test-mlogloss:0.573896
# [246]	train-mlogloss:0.373261	test-mlogloss:0.573862
# [247]	train-mlogloss:0.372949	test-mlogloss:0.573941
# [248]	train-mlogloss:0.372428	test-mlogloss:0.573873
# [249]	train-mlogloss:0.371783	test-mlogloss:0.573845
# [250]	train-mlogloss:0.371041	test-mlogloss:0.573803
# [251]	train-mlogloss:0.370517	test-mlogloss:0.573889
# [252]	train-mlogloss:0.369934	test-mlogloss:0.574018
# [253]	train-mlogloss:0.369323	test-mlogloss:0.573946
# [254]	train-mlogloss:0.368736	test-mlogloss:0.573927
# [255]	train-mlogloss:0.368203	test-mlogloss:0.57392
# [256]	train-mlogloss:0.367781	test-mlogloss:0.573891
# [257]	train-mlogloss:0.367363	test-mlogloss:0.573787
# [258]	train-mlogloss:0.366616	test-mlogloss:0.573831
# [259]	train-mlogloss:0.366194	test-mlogloss:0.573805
# [260]	train-mlogloss:0.365482	test-mlogloss:0.573731
# [261]	train-mlogloss:0.364976	test-mlogloss:0.573791
# [262]	train-mlogloss:0.364526	test-mlogloss:0.57393
# [263]	train-mlogloss:0.363998	test-mlogloss:0.573961
# [264]	train-mlogloss:0.363565	test-mlogloss:0.574187
# [265]	train-mlogloss:0.363158	test-mlogloss:0.5742
# [266]	train-mlogloss:0.362631	test-mlogloss:0.574181
# [267]	train-mlogloss:0.362184	test-mlogloss:0.574245
# [268]	train-mlogloss:0.361676	test-mlogloss:0.574315
# Stopping. Best iteration:
# [168]	train-mlogloss:0.415506	test-mlogloss:0.572441
#
# [0.57431456339472409]

# %%
dev_set.building_id_score
# Out:
# 0        0.587451
# 1        0.750000
# 2        0.587451
# 3        0.538462
# 4        1.100000
# 5        0.105508
# 6        0.105508
# 7        0.105508
# 8        0.342857
# 9        0.105508
# 10       0.105508
# 11       0.205882
# 12       0.571429
# 13       0.105508
# 14       0.000000
# 15       0.000000
# 16       0.470588
# 17       1.250000
# 18       0.587451
# 19       0.133333
# 20       0.677419
# 21       0.587451
# 22       0.555556
# 23       0.338983
# 24       2.000000
# 25       0.183333
# 26       0.587451
# 27       0.444444
# 28       0.043478
# 29       0.333333
#            ...
# 39451    0.705882
# 39452    0.607143
# 39453    0.587451
# 39454    0.105508
# 39455    0.000000
# 39456    0.800000
# 39457    1.000000
# 39458    0.105508
# 39459    0.239583
# 39460    0.105508
# 39461    0.494186
# 39462    0.105508
# 39463    0.470588
# 39464    0.105508
# 39465    0.000000
# 39466    0.105508
# 39467    0.750000
# 39468    0.545455
# 39469    1.000000
# 39470    0.000000
# 39471    0.441860
# 39472    0.250000
# 39473    0.000000
# 39474    0.105508
# 39475    0.587451
# 39476    0.587451
# 39477    0.000000
# 39478    0.407407
# 39479    0.258621
# 39480    0.714286
# Name: building_id_score, dtype: float64

# %%
#ananlysis by the feature importance by weight
weight = model.get_score()
total = sum(weight.values())
for key in weight:
    weight[key] = weight[key]*1.0/total
weight
# Out:
# {'bathrooms': 0.010285346346753424,
#  'bedrooms': 0.030466314219872576,
#  'building_id': 0.06857462383082553,
#  'created_day': 0.046309475396502646,
#  'created_hour': 0.04346278975193168,
#  'created_month': 0.006015317879896977,
#  'display_address': 0.0806899823776603,
#  'latitude': 0.09202589128371967,
#  'listing_id': 0.09887149247661652,
#  'longitude': 0.07911413853870138,
#  'manager_id': 0.09904093805069812,
#  'num_description_words': 0.0829605530703538,
#  'num_features': 0.04493696624644164,
#  'num_photos': 0.04109055171478921,
#  'price': 0.0970753693913515,
#  'street_address': 0.07908024942388504}

# %%
#ananlysis by the feature importance by gain
gain = model.get_score(importance_type='gain')
total = sum(gain.values())
#for key in gain:
#    gain[key] = gain[key]*1.0/total
gain

# %%
#ananlysis by the feature importance by coverage
cover = model.get_score(importance_type='cover')
total = sum(cover.values())
for key in cover:
    cover[key] = cover[key]*1.0/total
cover
# Out:
# {'bathrooms': 0.15003324661763429,
#  'bedrooms': 0.11847222747849985,
#  'building_id': 0.05966144646752775,
#  'created_day': 0.027908091350767217,
#  'created_hour': 0.04913703475375256,
#  'created_month': 0.015463921187964249,
#  'display_address': 0.051917534421511584,
#  'latitude': 0.062329192852910546,
#  'listing_id': 0.05823796559748455,
#  'longitude': 0.05796867229011468,
#  'manager_id': 0.0658834209429622,
#  'num_description_words': 0.04385875263322271,
#  'num_features': 0.05493240649113651,
#  'num_photos': 0.053803480057786596,
#  'price': 0.07955324745771991,
#  'street_address': 0.050839359399004566}
